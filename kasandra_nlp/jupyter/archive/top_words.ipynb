# %% [markdown]
# # 100 самых популярных слов

# %%
import json
news = []
with open('/data/kasandra/news-4965.json', encoding="utf8") as f:
    for line in f:
        news.append(json.loads(line))

list(map(lambda w: w['title'], news[:5]))
# Out:
# ['На Алтае заработала первая в РФ система контроля космического пространства',
#  'ЛНР: Действия украинских диверсантов — одна из версий покушения на Плотницкого',
#  'Bild не публикует результаты России в медальном зачёте Олимпиады',
#  'Глава ЛНР связал покушение на свою жизнь с украинскими спецслужбами',
#  'Мэра города в США арестовали за попытку расплатиться наркотиками за секс с мужчинами']

# %%
stopwords = []

with open('../main/python/res/stopwords.txt', mode="r", encoding="utf8") as file:
    for line in file:
        stopwords.append(line.replace('\n', ''))

# %%
from pymystem3 import Mystem
import re

mystem = Mystem(entire_input=False)

# Оставляем только русские слова
r = re.compile('^[А-ЯЙа-яй]*$')

def lemmatize(text):
    return list(filter(r.match, mystem.lemmatize(text)))

# %%
newsContent = list(map(lambda n: lemmatize(n['content']), news))

lemmes = []
for lems in newsContent:
    lemmes.extend(lems)
    
lemmes = list(filter(lambda w: w not in stopwords, lemmes))

# %%
from collections import Counter
counter = Counter(lemmes)

# %% [markdown]
# ## total words

# %%
len(counter)
# Out:
# 42614

# %% [markdown]
# ## 100 top words

# %%
counter.most_common(100)
# Out:
# [('год', 11379),
#  ('россия', 10767),
#  ('новость', 9702),
#  ('российский', 6227),
#  ('человек', 5998),
#  ('страна', 5888),
#  ('москва', 5558),
#  ('заявлять', 5311),
#  ('сообщать', 5062),
#  ('мочь', 4901),
#  ('сша', 4168),
#  ('становиться', 4024),
#  ('время', 3957),
#  ('слово', 3911),
#  ('президент', 3807),
#  ('украина', 3363),
#  ('отмечать', 3296),
#  ('решение', 3040),
#  ('турция', 2962),
#  ('июль', 2921),
#  ('первый', 2773),
#  ('самый', 2724),
#  ('военный', 2682),
#  ('ранее', 2635),
#  ('принимать', 2623),
#  ('глава', 2605),
#  ('отношение', 2586),
#  ('данные', 2508),
#  ('новый', 2505),
#  ('вопрос', 2455),
#  ('международный', 2444),
#  ('дело', 2423),
#  ('должный', 2412),
#  ('результат', 2363),
#  ('май', 2314),
#  ('получать', 2287),
#  ('день', 2252),
#  ('проходить', 2208),
#  ('место', 2110),
#  ('представитель', 2084),
#  ('сторона', 2081),
#  ('сборная', 2074),
#  ('происходить', 2063),
#  ('игра', 2025),
#  ('город', 2023),
#  ('против', 2020),
#  ('власть', 2008),
#  ('ес', 1973),
#  ('считать', 1949),
#  ('находиться', 1940),
#  ('мир', 1938),
#  ('государство', 1936),
#  ('приводить', 1932),
#  ('американский', 1916),
#  ('полиция', 1906),
#  ('спорт', 1869),
#  ('являться', 1809),
#  ('европа', 1798),
#  ('агентство', 1796),
#  ('июнь', 1780),
#  ('говорить', 1766),
#  ('рф', 1752),
#  ('работа', 1743),
#  ('олимпийский', 1702),
#  ('число', 1699),
#  ('последний', 1699),
#  ('поддерживать', 1696),
#  ('спортсмен', 1691),
#  ('самолет', 1660),
#  ('называть', 1659),
#  ('ситуация', 1639),
#  ('группа', 1631),
#  ('тысяча', 1621),
#  ('сила', 1616),
#  ('информация', 1613),
#  ('данный', 1612),
#  ('несколько', 1598),
#  ('безопасность', 1569),
#  ('нато', 1561),
#  ('ребенок', 1559),
#  ('июла', 1552),
#  ('погибать', 1532),
#  ('участие', 1525),
#  ('санкция', 1507),
#  ('случай', 1496),
#  ('украинский', 1495),
#  ('рассказывать', 1491),
#  ('организация', 1478),
#  ('сообщение', 1467),
#  ('мнение', 1461),
#  ('проводить', 1456),
#  ('сми', 1451),
#  ('партия', 1446),
#  ('компания', 1440),
#  ('журналист', 1435),
#  ('выступать', 1425),
#  ('действие', 1425),
#  ('путин', 1419),
#  ('сделать', 1416),
#  ('территория', 1415)]

# %% [markdown]
# ## 1000 least words

# %%
counter.most_common()[:-1000-1:-1]
# Out:
# [('лавровый', 1),
#  ('выбродить', 1),
#  ('сухобок', 1),
#  ('перенаселенный', 1),
#  ('фрахт', 1),
#  ('темирбек', 1),
#  ('лохалит', 1),
#  ('стерильный', 1),
#  ('взмах', 1),
#  ('облеплять', 1),
#  ('мэв', 1),
#  ('лоскут', 1),
#  ('мимино', 1),
#  ('проказа', 1),
#  ('ММГ', 1),
#  ('комагатакэ', 1),
#  ('куратова', 1),
#  ('лисина', 1),
#  ('затылок', 1),
#  ('яшма', 1),
#  ('служивый', 1),
#  ('савчук', 1),
#  ('унасура', 1),
#  ('вагинальный', 1),
#  ('тактически', 1),
#  ('смиренно', 1),
#  ('алькатрас', 1),
#  ('лафайетт', 1),
#  ('завалейк', 1),
#  ('вивисекция', 1),
#  ('щитовидный', 1),
#  ('амиэль', 1),
#  ('экзальтация', 1),
#  ('фоновый', 1),
#  ('алавит', 1),
#  ('дюрвангер', 1),
#  ('беспрекословно', 1),
#  ('теплоходный', 1),
#  ('дьяков', 1),
#  ('ратеновский', 1),
#  ('митрофанович', 1),
#  ('сокольник', 1),
#  ('созидательный', 1),
#  ('айзенберг', 1),
#  ('моррис', 1),
#  ('джодхпур', 1),
#  ('ревальвировать', 1),
#  ('пищать', 1),
#  ('жилберто', 1),
#  ('незамедлительность', 1),
#  ('магнетит', 1),
#  ('пошатнуть', 1),
#  ('техмаш', 1),
#  ('бритва', 1),
#  ('установочный', 1),
#  ('эсперанто', 1),
#  ('старков', 1),
#  ('бескислородный', 1),
#  ('кайманов', 1),
#  ('зеленополье', 1),
#  ('неправовой', 1),
#  ('брно', 1),
#  ('венчурный', 1),
#  ('юнш', 1),
#  ('коннеля', 1),
#  ('бехзод', 1),
#  ('саенко', 1),
#  ('вкатить', 1),
#  ('альмодовар', 1),
#  ('честолюбивый', 1),
#  ('выплачиваться', 1),
#  ('рекомбинантный', 1),
#  ('излом', 1),
#  ('дискредитироваться', 1),
#  ('вервье', 1),
#  ('деревцо', 1),
#  ('танцпол', 1),
#  ('медклиника', 1),
#  ('переламываться', 1),
#  ('рувд', 1),
#  ('чувственность', 1),
#  ('мордвинов', 1),
#  ('тейчер', 1),
#  ('неспешный', 1),
#  ('тестостеронов', 1),
#  ('втаптывать', 1),
#  ('самарканд', 1),
#  ('пфайффер', 1),
#  ('священномученик', 1),
#  ('вагенкхнет', 1),
#  ('родич', 1),
#  ('тяготиться', 1),
#  ('многообразие', 1),
#  ('зоря', 1),
#  ('брюшной', 1),
#  ('туйчибоев', 1),
#  ('амплитуда', 1),
#  ('иллинойский', 1),
#  ('немировский', 1),
#  ('опоминаться', 1),
#  ('сжигаться', 1),
#  ('ФСТ', 1),
#  ('карандашный', 1),
#  ('побратымить', 1),
#  ('вспучиваться', 1),
#  ('флайерз', 1),
#  ('спецпродукция', 1),
#  ('савустьян', 1),
#  ('поледний', 1),
#  ('фастфуда', 1),
#  ('нагрянуть', 1),
#  ('бузила', 1),
#  ('даниловна', 1),
#  ('закусывать', 1),
#  ('двухдиапазонный', 1),
#  ('сгруппировывать', 1),
#  ('тадуссак', 1),
#  ('угадываться', 1),
#  ('нечетко', 1),
#  ('аликсио', 1),
#  ('забредать', 1),
#  ('круиз', 1),
#  ('армаан', 1),
#  ('меланоцитарный', 1),
#  ('трения', 1),
#  ('жамбылский', 1),
#  ('маккилви', 1),
#  ('моргнуть', 1),
#  ('хитроумный', 1),
#  ('рекламка', 1),
#  ('реять', 1),
#  ('насморк', 1),
#  ('мактум', 1),
#  ('романтизм', 1),
#  ('хаменей', 1),
#  ('кондукторша', 1),
#  ('бернадский', 1),
#  ('черепашка', 1),
#  ('выделываться', 1),
#  ('рентный', 1),
#  ('розмовля', 1),
#  ('урбана', 1),
#  ('лаланда', 1),
#  ('статский', 1),
#  ('подгорный', 1),
#  ('ричмондский', 1),
#  ('росийский', 1),
#  ('тунгусский', 1),
#  ('строфа', 1),
#  ('бирюзов', 1),
#  ('бортпроводница', 1),
#  ('великодный', 1),
#  ('труненков', 1),
#  ('автомобилестроитель', 1),
#  ('каховский', 1),
#  ('альбертский', 1),
#  ('мульт', 1),
#  ('варга', 1),
#  ('родительница', 1),
#  ('отвыкать', 1),
#  ('рогожкин', 1),
#  ('раскулачивать', 1),
#  ('штольня', 1),
#  ('меловой', 1),
#  ('ротава', 1),
#  ('съедобность', 1),
#  ('микронный', 1),
#  ('юон', 1),
#  ('порицать', 1),
#  ('декриминализация', 1),
#  ('линчепинг', 1),
#  ('канистра', 1),
#  ('иньест', 1),
#  ('системма', 1),
#  ('конструкт', 1),
#  ('непредоставление', 1),
#  ('самоуспокаиваться', 1),
#  ('карауин', 1),
#  ('сманеврировать', 1),
#  ('сутенер', 1),
#  ('переходной', 1),
#  ('гуджарат', 1),
#  ('вымывание', 1),
#  ('калькуляция', 1),
#  ('ассия', 1),
#  ('бенчмарка', 1),
#  ('барановская', 1),
#  ('незаконченность', 1),
#  ('кочарова', 1),
#  ('аманпур', 1),
#  ('возглавляетбелградский', 1),
#  ('понос', 1),
#  ('политотдел', 1),
#  ('траффик', 1),
#  ('халифа', 1),
#  ('заряжаться', 1),
#  ('баграмян', 1),
#  ('углядеть', 1),
#  ('этцель', 1),
#  ('скальпель', 1),
#  ('шуллер', 1),
#  ('хирад', 1),
#  ('лотос', 1),
#  ('жимолость', 1),
#  ('истурис', 1),
#  ('ирга', 1),
#  ('бронислав', 1),
#  ('идрис', 1),
#  ('суженая', 1),
#  ('бордовый', 1),
#  ('панкова', 1),
#  ('айка', 1),
#  ('звукооператор', 1),
#  ('проведывать', 1),
#  ('метаморфоза', 1),
#  ('опекун', 1),
#  ('доронг', 1),
#  ('антоновский', 1),
#  ('эва', 1),
#  ('неглименский', 1),
#  ('белькачинский', 1),
#  ('вечность', 1),
#  ('велопарковка', 1),
#  ('переназначение', 1),
#  ('КПЦ', 1),
#  ('танака', 1),
#  ('крестовина', 1),
#  ('кеменс', 1),
#  ('гудмундур', 1),
#  ('хетланд', 1),
#  ('кортизол', 1),
#  ('цзэдун', 1),
#  ('бронефутболка', 1),
#  ('жонглер', 1),
#  ('классификатор', 1),
#  ('кальюранд', 1),
#  ('обескровливать', 1),
#  ('беккет', 1),
#  ('хафсос', 1),
#  ('семиэтажный', 1),
#  ('берекель', 1),
#  ('пятиться', 1),
#  ('андреяикрамов', 1),
#  ('шестилетие', 1),
#  ('филиппо', 1),
#  ('поскальзываться', 1),
#  ('гребчиха', 1),
#  ('майна', 1),
#  ('леймар', 1),
#  ('нажитое', 1),
#  ('бадиа', 1),
#  ('разбежка', 1),
#  ('казбек', 1),
#  ('шановний', 1),
#  ('наохис', 1),
#  ('лизюкова', 1),
#  ('наболевший', 1),
#  ('госбанк', 1),
#  ('куэк', 1),
#  ('дайвер', 1),
#  ('разогрев', 1),
#  ('стенограмма', 1),
#  ('центральноазиатский', 1),
#  ('необстрелянный', 1),
#  ('белградский', 1),
#  ('заманивание', 1),
#  ('странствовать', 1),
#  ('берегитесебать', 1),
#  ('безграмотный', 1),
#  ('водопадный', 1),
#  ('аннаполис', 1),
#  ('фортум', 1),
#  ('недобитый', 1),
#  ('дрэг', 1),
#  ('цукур', 1),
#  ('рыдван', 1),
#  ('мусафир', 1),
#  ('фмба', 1),
#  ('цветисто', 1),
#  ('восполнять', 1),
#  ('факультативный', 1),
#  ('лапоть', 1),
#  ('тиффани', 1),
#  ('геополитик', 1),
#  ('лесоперерабатывающий', 1),
#  ('индукционный', 1),
#  ('рефный', 1),
#  ('игор', 1),
#  ('релевантный', 1),
#  ('клятвенный', 1),
#  ('аджика', 1),
#  ('чудской', 1),
#  ('турпен', 1),
#  ('сев', 1),
#  ('долгосрочно', 1),
#  ('майлинда', 1),
#  ('богомоев', 1),
#  ('тырса', 1),
#  ('поотвинчивать', 1),
#  ('рудрапур', 1),
#  ('овидиу', 1),
#  ('стереоэффект', 1),
#  ('неутешный', 1),
#  ('ивдель', 1),
#  ('маскировочный', 1),
#  ('перепасовка', 1),
#  ('вчетвером', 1),
#  ('нестерильный', 1),
#  ('иоанна', 1),
#  ('петлевой', 1),
#  ('перепачкать', 1),
#  ('картить', 1),
#  ('вахаевна', 1),
#  ('извинительный', 1),
#  ('просушка', 1),
#  ('видеоперформанс', 1),
#  ('бразитальянец', 1),
#  ('осетровый', 1),
#  ('стилизация', 1),
#  ('товарность', 1),
#  ('дадли', 1),
#  ('антирелигиозный', 1),
#  ('мухтар', 1),
#  ('светопоглощающий', 1),
#  ('толорай', 1),
#  ('алонсо', 1),
#  ('романенко', 1),
#  ('калгари', 1),
#  ('покстопа', 1),
#  ('пироговский', 1),
#  ('сефер', 1),
#  ('этил', 1),
#  ('канцероген', 1),
#  ('сверхуверенно', 1),
#  ('хэднотт', 1),
#  ('мессенждер', 1),
#  ('анел', 1),
#  ('аграмонт', 1),
#  ('спин', 1),
#  ('энергетически', 1),
#  ('безвольный', 1),
#  ('управа', 1),
#  ('минцев', 1),
#  ('дияль', 1),
#  ('неготовый', 1),
#  ('таверна', 1),
#  ('гипп', 1),
#  ('обживать', 1),
#  ('примитивно', 1),
#  ('мукилтео', 1),
#  ('уединенный', 1),
#  ('галерный', 1),
#  ('монгол', 1),
#  ('бердибек', 1),
#  ('адана', 1),
#  ('крысина', 1),
#  ('возможное', 1),
#  ('сыалахский', 1),
#  ('капоэйр', 1),
#  ('огузхан', 1),
#  ('пыльно', 1),
#  ('общеопасный', 1),
#  ('параховский', 1),
#  ('утолять', 1),
#  ('шагреневый', 1),
#  ('робер', 1),
#  ('есмантович', 1),
#  ('майос', 1),
#  ('неокологический', 1),
#  ('скрыпник', 1),
#  ('асгар', 1),
#  ('мамсурова', 1),
#  ('бурков', 1),
#  ('одуванчик', 1),
#  ('пеликан', 1),
#  ('небоеспособный', 1),
#  ('фламинго', 1),
#  ('деметрис', 1),
#  ('богач', 1),
#  ('физиономия', 1),
#  ('богден', 1),
#  ('камео', 1),
#  ('корысть', 1),
#  ('байерт', 1),
#  ('мальдивы', 1),
#  ('фентон', 1),
#  ('скумбрия', 1),
#  ('долбануть', 1),
#  ('раскольничий', 1),
#  ('препинание', 1),
#  ('проецирование', 1),
#  ('эльзас', 1),
#  ('насиф', 1),
#  ('тюрингия', 1),
#  ('темпераментный', 1),
#  ('сотый', 1),
#  ('эликсир', 1),
#  ('согласованно', 1),
#  ('резанов', 1),
#  ('чтов', 1),
#  ('неприятельский', 1),
#  ('истборн', 1),
#  ('прибирать', 1),
#  ('лефорт', 1),
#  ('науменко', 1),
#  ('уступ', 1),
#  ('конашенкова', 1),
#  ('взбадривать', 1),
#  ('туткаспийск', 1),
#  ('партиец', 1),
#  ('бьеррегард', 1),
#  ('гиртц', 1),
#  ('куртлак', 1),
#  ('самовыражение', 1),
#  ('зримый', 1),
#  ('ауфа', 1),
#  ('распробовать', 1),
#  ('упреждение', 1),
#  ('чакветадзе', 1),
#  ('фермин', 1),
#  ('литания', 1),
#  ('кинематографичный', 1),
#  ('ефективний', 1),
#  ('интерконтинентальный', 1),
#  ('поименно', 1),
#  ('безухов', 1),
#  ('пьетро', 1),
#  ('рейсинг', 1),
#  ('мысленный', 1),
#  ('алхимик', 1),
#  ('райна', 1),
#  ('выползовой', 1),
#  ('засечный', 1),
#  ('самоутверждаться', 1),
#  ('взыскательный', 1),
#  ('мухаджир', 1),
#  ('ежесезонно', 1),
#  ('деревообрабатывающий', 1),
#  ('смешить', 1),
#  ('звенеть', 1),
#  ('эмиратец', 1),
#  ('своевольный', 1),
#  ('энрий', 1),
#  ('рифма', 1),
#  ('завоеватель', 1),
#  ('рябиновый', 1),
#  ('молдаван', 1),
#  ('заведовать', 1),
#  ('ретроманьяк', 1),
#  ('якубов', 1),
#  ('кулеша', 1),
#  ('серебрянников', 1),
#  ('кубит', 1),
#  ('курбанова', 1),
#  ('загреметь', 1),
#  ('пятитысячный', 1),
#  ('североафриканец', 1),
#  ('сельхозорганизация', 1),
#  ('автохама', 1),
#  ('авиаполк', 1),
#  ('недовольно', 1),
#  ('пинчбек', 1),
#  ('промчаться', 1),
#  ('канадиенс', 1),
#  ('благовещение', 1),
#  ('дега', 1),
#  ('обвисать', 1),
#  ('нечистокровный', 1),
#  ('марион', 1),
#  ('бунтовать', 1),
#  ('билокси', 1),
#  ('мироносица', 1),
#  ('вылизывать', 1),
#  ('подонок', 1),
#  ('светоносный', 1),
#  ('валуева', 1),
#  ('вакульчик', 1),
#  ('разносортица', 1),
#  ('луговской', 1),
#  ('садкув', 1),
#  ('пармский', 1),
#  ('грановский', 1),
#  ('начинание', 1),
#  ('рамси', 1),
#  ('полуфиналистка', 1),
#  ('канатоходец', 1),
#  ('почалисить', 1),
#  ('упиваться', 1),
#  ('дейв', 1),
#  ('кадимейн', 1),
#  ('талда', 1),
#  ('одиночник', 1),
#  ('однодневка', 1),
#  ('куртулмуша', 1),
#  ('макеева', 1),
#  ('гассан', 1),
#  ('пакиао', 1),
#  ('мпа', 1),
#  ('мальвинский', 1),
#  ('гонсало', 1),
#  ('грохнуть', 1),
#  ('гульчехра', 1),
#  ('абсурдистский', 1),
#  ('лагас', 1),
#  ('прочитываться', 1),
#  ('арахноландий', 1),
#  ('селевк', 1),
#  ('почтительно', 1),
#  ('орлиный', 1),
#  ('недурственный', 1),
#  ('костюмер', 1),
#  ('ковалевская', 1),
#  ('куди', 1),
#  ('ярослава', 1),
#  ('начальствовать', 1),
#  ('налбандян', 1),
#  ('гарридо', 1),
#  ('саламех', 1),
#  ('маринато', 1),
#  ('нерешительность', 1),
#  ('недальновидность', 1),
#  ('политопрос', 1),
#  ('росад', 1),
#  ('умирт', 1),
#  ('хельта', 1),
#  ('чудодейственный', 1),
#  ('минервин', 1),
#  ('передохнуть', 1),
#  ('декларирование', 1),
#  ('запоминание', 1),
#  ('облпрокуратура', 1),
#  ('гомеопатия', 1),
#  ('рассохин', 1),
#  ('билялетдинов', 1),
#  ('переходать', 1),
#  ('постмейнстримовский', 1),
#  ('комплекция', 1),
#  ('шпионить', 1),
#  ('малярный', 1),
#  ('штандка', 1),
#  ('ролл', 1),
#  ('биофизик', 1),
#  ('хамдуня', 1),
#  ('неполяризованный', 1),
#  ('атеф', 1),
#  ('отапливаться', 1),
#  ('компримировать', 1),
#  ('блелие', 1),
#  ('посиливать', 1),
#  ('натурализация', 1),
#  ('пограннаряд', 1),
#  ('атитнская', 1),
#  ('томпкинсвилл', 1),
#  ('потрепанный', 1),
#  ('одержимость', 1),
#  ('грозоопасный', 1),
#  ('хронометраж', 1),
#  ('хишам', 1),
#  ('доисламский', 1),
#  ('малайзиец', 1),
#  ('отметаться', 1),
#  ('налоговик', 1),
#  ('зазырыть', 1),
#  ('пал', 1),
#  ('колодный', 1),
#  ('ларец', 1),
#  ('утомляться', 1),
#  ('сылин', 1),
#  ('нобуо', 1),
#  ('крысолов', 1),
#  ('хайль', 1),
#  ('вантовый', 1),
#  ('директорство', 1),
#  ('марьинка', 1),
#  ('госуниверситет', 1),
#  ('ильнара', 1),
#  ('лорена', 1),
#  ('сухобоков', 1),
#  ('бровь', 1),
#  ('магнит', 1),
#  ('флегматичный', 1),
#  ('информированность', 1),
#  ('падавать', 1),
#  ('нереализуемый', 1),
#  ('ковалаев', 1),
#  ('простреливать', 1),
#  ('упрашивать', 1),
#  ('малоаппетитный', 1),
#  ('аргунов', 1),
#  ('варгас', 1),
#  ('мисгрейв', 1),
#  ('кордайский', 1),
#  ('эльбаз', 1),
#  ('взбунтоваться', 1),
#  ('альманах', 1),
#  ('вибха', 1),
#  ('приподымать', 1),
#  ('ЗРПК', 1),
#  ('воздержавшийся', 1),
#  ('джудит', 1),
#  ('асмус', 1),
#  ('квест', 1),
#  ('гусст', 1),
#  ('сталевар', 1),
#  ('каганат', 1),
#  ('гиа', 1),
#  ('гастролировать', 1),
#  ('мачеревиа', 1),
#  ('азим', 1),
#  ('софроний', 1),
#  ('элджин', 1),
#  ('электроопора', 1),
#  ('эшфорд', 1),
#  ('цюаньчжоу', 1),
#  ('лимерик', 1),
#  ('шт', 1),
#  ('двухфактороной', 1),
#  ('эйвеня', 1),
#  ('межпоколенческий', 1),
#  ('всуе', 1),
#  ('вхи', 1),
#  ('нидерландец', 1),
#  ('мунир', 1),
#  ('саченко', 1),
#  ('футенм', 1),
#  ('ардзинб', 1),
#  ('капюто', 1),
#  ('квартальнов', 1),
#  ('урозбой', 1),
#  ('информатизация', 1),
#  ('люфт', 1),
#  ('путивко', 1),
#  ('венчик', 1),
#  ('конвеер', 1),
#  ('обкусать', 1),
#  ('эндоскопический', 1),
#  ('цэнки', 1),
#  ('хайруллин', 1),
#  ('вячать', 1),
#  ('аникеева', 1),
#  ('наслег', 1),
#  ('плутониевый', 1),
#  ('медейрос', 1),
#  ('сургут', 1),
#  ('сяоси', 1),
#  ('мазараат', 1),
#  ('вровень', 1),
#  ('демократизм', 1),
#  ('миллениал', 1),
#  ('декор', 1),
#  ('бурден', 1),
#  ('усложнение', 1),
#  ('госсубсидия', 1),
#  ('абуфет', 1),
#  ('приузенский', 1),
#  ('ониси', 1),
#  ('бандана', 1),
#  ('мужеподобный', 1),
#  ('бандар', 1),
#  ('многорубежный', 1),
#  ('полумила', 1),
#  ('фельдфебель', 1),
#  ('йамхад', 1),
#  ('остроухов', 1),
#  ('тинтагель', 1),
#  ('слабовидящий', 1),
#  ('авалоне', 1),
#  ('лужнецкий', 1),
#  ('переустройство', 1),
#  ('девка', 1),
#  ('гэмпширский', 1),
#  ('лавочник', 1),
#  ('ВГ', 1),
#  ('обнаглеть', 1),
#  ('азизи', 1),
#  ('запасание', 1),
#  ('хокку', 1),
#  ('пиантадось', 1),
#  ('провизия', 1),
#  ('херас', 1),
#  ('фрик', 1),
#  ('евфросиния', 1),
#  ('мототехника', 1),
#  ('джезказган', 1),
#  ('никишина', 1),
#  ('квинс', 1),
#  ('сотбис', 1),
#  ('нитевый', 1),
#  ('селенгинск', 1),
#  ('расселина', 1),
#  ('клановый', 1),
#  ('канерв', 1),
#  ('суперпрограмма', 1),
#  ('двуокись', 1),
#  ('гробовой', 1),
#  ('реноме', 1),
#  ('австраль', 1),
#  ('прорисовывать', 1),
#  ('пылева', 1),
#  ('демагогия', 1),
#  ('пиратский', 1),
#  ('мопина', 1),
#  ('печение', 1),
#  ('райбстайн', 1),
#  ('околонулевой', 1),
#  ('талпатти', 1),
#  ('бельгийка', 1),
#  ('валлония', 1),
#  ('драконида', 1),
#  ('пойма', 1),
#  ('тричковский', 1),
#  ('имплант', 1),
#  ('горизонтально', 1),
#  ('райли', 1),
#  ('эган', 1),
#  ('спайка', 1),
#  ('доводка', 1),
#  ('пирская', 1),
#  ('помолисьзаницца', 1),
#  ('прикольно', 1),
#  ('сандра', 1),
#  ('флэгер', 1),
#  ('олтмен', 1),
#  ('саморазвитие', 1),
#  ('сословие', 1),
#  ('джилани', 1),
#  ('марконь', 1),
#  ('палаш', 1),
#  ('оправданность', 1),
#  ('дойла', 1),
#  ('теплоэнергия', 1),
#  ('эксклюзив', 1),
#  ('шагин', 1),
#  ('суперзвезда', 1),
#  ('трипс', 1),
#  ('разнестись', 1),
#  ('контрразведчик', 1),
#  ('эксимос', 1),
#  ('оппонентка', 1),
#  ('спрашиваться', 1),
#  ('щетка', 1),
#  ('пиарить', 1),
#  ('экоархитектура', 1),
#  ('конюшня', 1),
#  ('гриль', 1),
#  ('алпарслан', 1),
#  ('расправлять', 1),
#  ('бард', 1),
#  ('сотрясение', 1),
#  ('генпрокуратора', 1),
#  ('двухпутный', 1),
#  ('сегрегированный', 1),
#  ('неолиберальный', 1),
#  ('стотысячный', 1),
#  ('замызганный', 1),
#  ('мята', 1),
#  ('киллер', 1),
#  ('одинцов', 1),
#  ('ретропоезд', 1),
#  ('нормировать', 1),
#  ('преподавание', 1),
#  ('аптекарскийогород', 1),
#  ('басьян', 1),
#  ('прожаривать', 1),
#  ('кадык', 1),
#  ('ремер', 1),
#  ('лаухин', 1),
#  ('ЛДНР', 1),
#  ('анонсирование', 1),
#  ('фриз', 1),
#  ('сотрясаться', 1),
#  ('размораживание', 1),
#  ('бейли', 1),
#  ('нагайцев', 1),
#  ('мореходность', 1),
#  ('настенный', 1),
#  ('блазио', 1),
#  ('измученный', 1),
#  ('горавский', 1),
#  ('мелкосерийный', 1),
#  ('крестьянка', 1),
#  ('айюбидов', 1),
#  ('секретарша', 1),
#  ('шир', 1),
#  ('калифорниец', 1),
#  ('сакский', 1),
#  ('гончаровский', 1),
#  ('белозер', 1),
#  ('кататний', 1),
#  ('аэвт', 1),
#  ('утруждать', 1),
#  ('мульткомиссия', 1),
#  ('нефинансовый', 1),
#  ('сократ', 1),
#  ('холодницкий', 1),
#  ('сеника', 1),
#  ('неполитизированный', 1),
#  ('сао', 1),
#  ('горошина', 1),
#  ('нефтеразведка', 1),
#  ('лидингтон', 1),
#  ('наотмашь', 1),
#  ('опс', 1),
#  ('профилирование', 1),
#  ('трешка', 1),
#  ('геотаргетинга', 1),
#  ('среднетоннажный', 1),
#  ('состаривать', 1),
#  ('медиаменеджер', 1),
#  ('несбывшийся', 1),
#  ('хувейджи', 1),
#  ('нормотворческий', 1),
#  ('теннести', 1),
#  ('святая', 1),
#  ('дзэнкодзи', 1),
#  ('гринев', 1),
#  ('ГСС', 1),
#  ('пошевелить', 1),
#  ('абухадж', 1),
#  ('техцентр', 1),
#  ('бардем', 1),
#  ('безошибочный', 1),
#  ('чуров', 1),
#  ('обиденко', 1),
#  ('бакхр', 1),
#  ('псевдосенсация', 1),
#  ('многокультурный', 1),
#  ('уколова', 1),
#  ('колисниченко', 1),
#  ('григоришин', 1),
#  ('правоверный', 1),
#  ('бахрейнский', 1),
#  ('лужский', 1),
#  ('мыкола', 1),
#  ('льнопрядильный', 1),
#  ('пунктуация', 1),
#  ('конвейерный', 1),
#  ('всевластие', 1),
#  ('ых', 1),
#  ('сокри', 1),
#  ('сережа', 1),
#  ('прямоугольный', 1),
#  ('деодоро', 1),
#  ('выронить', 1),
#  ('разведуправление', 1),
#  ('эренбург', 1),
#  ('хесслер', 1),
#  ('орлеана', 1),
#  ('палиться', 1),
#  ('чинка', 1),
#  ('колодин', 1),
#  ('микролитражка', 1),
#  ('кучинскис', 1),
#  ('шираз', 1),
#  ('форсажный', 1),
#  ('тельнов', 1),
#  ('дыхнуть', 1),
#  ('краситель', 1),
#  ('нервозный', 1),
#  ('генерирование', 1),
#  ('просвечивание', 1),
#  ('кардифф', 1),
#  ('индивидуал', 1),
#  ('флер', 1),
#  ('гермонассать', 1),
#  ('итесь', 1),
#  ('киносмотр', 1),
#  ('каунас', 1),
#  ('возня', 1),
#  ('бьорн', 1),
#  ('замсекретарь', 1),
#  ('стеклоуглерод', 1),
#  ('акраб', 1),
#  ('разведпатруль', 1),
#  ('тиргартен', 1),
#  ('фемида', 1),
#  ('обвести', 1),
#  ('султанат', 1),
#  ('солонандрасана', 1),
#  ('соцвыплата', 1),
#  ('амнистировать', 1),
#  ('гривняк', 1),
#  ('семилопастный', 1),
#  ('скат', 1),
#  ('окриветь', 1),
#  ('отпускаться', 1),
#  ('обогревать', 1),
#  ('технадзор', 1),
#  ('бежа', 1),
#  ('черенок', 1),
#  ('информаторша', 1),
#  ('мемуары', 1),
#  ('могильщик', 1),
#  ('ММЗ', 1),
#  ('посмещение', 1),
#  ('пим', 1),
#  ('раскладываться', 1),
#  ('соорбитальный', 1),
#  ('неуказанный', 1),
#  ('недзвецки', 1),
#  ('вьетконг', 1),
#  ('магнус', 1),
#  ('блэкхокс', 1),
#  ('вихорь', 1),
#  ('окава', 1),
#  ('вещичка', 1),
#  ('сычуань', 1),
#  ('ласина', 1),
#  ('кса', 1),
#  ('непринятие', 1),
#  ('семистраничный', 1),
#  ('иждивенческий', 1),
#  ('высокоуважаемый', 1),
#  ('лавренюк', 1),
#  ('гугб', 1),
#  ('изрус', 1),
#  ('гемотрансфузия', 1),
#  ('лавировать', 1),
#  ('дюймовый', 1),
#  ('замкомандир', 1),
#  ('железныйтрон', 1),
#  ('спецпропаганда', 1),
#  ('портленд', 1),
#  ('еженощный', 1),
#  ('переснять', 1),
#  ('разоблачительный', 1),
#  ('субъектный', 1),
#  ('нацеплять', 1),
#  ('чуперок', 1),
#  ('гоу', 1),
#  ('герцогиня', 1),
#  ('академич', 1),
#  ('медресе', 1),
#  ('бесчувственный', 1),
#  ('селедка', 1),
#  ('афродита', 1),
#  ('стэйси', 1),
#  ('квитанция', 1),
#  ('гуглмобиль', 1),
#  ('синпхо', 1),
#  ('изумительный', 1),
#  ('ЦПК', 1),
#  ('гастарбайтер', 1),
#  ('мотивировочный', 1),
#  ('бартолон', 1),
#  ('психиатрия', 1),
#  ('теннесистка', 1),
#  ('преступать', 1),
#  ('мармей', 1),
#  ('помногу', 1),
#  ('муссирование', 1),
#  ('миргород', 1),
#  ('заретушировать', 1),
#  ('иммерсивный', 1),
#  ('ловиться', 1),
#  ('риверсайд', 1),
#  ('лизард', 1),
#  ('неистребимый', 1),
#  ('отщепенец', 1),
#  ('танатотранскриптом', 1),
#  ('дозаявка', 1),
#  ('антипод', 1),
#  ('касаткин', 1),
#  ('новомодный', 1),
#  ('СА', 1),
#  ('тарья', 1),
#  ('бобин', 1),
#  ('муханнада', 1),
#  ('троекуровский', 1),
#  ('проходная', 1),
#  ('сипеть', 1),
#  ('уклонист', 1),
#  ('дрессировщик', 1),
#  ('укрывательство', 1),
#  ('остоженка', 1),
#  ('деймос', 1),
#  ('мюриель', 1),
#  ('искалечивать', 1),
#  ('паолу', 1),
#  ('постантибиотический', 1),
#  ('джоржио', 1),
#  ('гриша', 1),
#  ('молин', 1),
#  ('перебронирование', 1),
#  ('выразительность', 1),
#  ('кореновск', 1),
#  ('хафса', 1),
#  ('гигакалория', 1),
#  ('динамовский', 1),
#  ('мироил', 1),
#  ('додеканезский', 1),
#  ('бопс', 1),
#  ('грузчик', 1),
#  ('циа', 1),
#  ('северпост', 1),
#  ('коситься', 1),
#  ('варьировать', 1),
#  ('меламедов', 1),
#  ('спецобработка', 1),
#  ('перебежать', 1)]

# %% [markdown]
# # stop words

# %%
stopwords
# Out:
# ['без',
#  'более',
#  'больше',
#  'будет',
#  'будто',
#  'бы',
#  'был',
#  'была',
#  'были',
#  'было',
#  'быть',
#  'вам',
#  'вас',
#  'ведь',
#  'весь',
#  'вдоль',
#  'вдруг',
#  'вместо',
#  'вне',
#  'вниз',
#  'внизу',
#  'внутри',
#  'во',
#  'вокруг',
#  'вот',
#  'впрочем',
#  'все',
#  'всегда',
#  'всего',
#  'всех',
#  'всю',
#  'вы',
#  'где',
#  'да',
#  'давай',
#  'давать',
#  'даже',
#  'для',
#  'до',
#  'достаточно',
#  'другой',
#  'его',
#  'ему',
#  'ее',
#  'её',
#  'ей',
#  'если',
#  'есть',
#  'ещё',
#  'еще',
#  'же',
#  'за',
#  'за исключением',
#  'здесь',
#  'из',
#  'из-за',
#  'или',
#  'им',
#  'иметь',
#  'иногда',
#  'их',
#  'как-то',
#  'когда',
#  'кроме',
#  'кто',
#  'куда',
#  'ли',
#  'либо',
#  'между',
#  'меня',
#  'мне',
#  'много',
#  'может',
#  'мое',
#  'моё',
#  'мои',
#  'мой',
#  'мы',
#  'на',
#  'навсегда',
#  'над',
#  'надо',
#  'наконец',
#  'нас',
#  'наш',
#  'не',
#  'него',
#  'неё',
#  'нее',
#  'ней',
#  'нет',
#  'ни',
#  'нибудь',
#  'никогда',
#  'ним',
#  'них',
#  'ничего',
#  'но',
#  'ну',
#  'об',
#  'однако',
#  'он',
#  'она',
#  'они',
#  'оно',
#  'опять',
#  'от',
#  'отчего',
#  'очень',
#  'перед',
#  'по',
#  'под',
#  'после',
#  'потом',
#  'потому',
#  'потому что',
#  'почти',
#  'при',
#  'про',
#  'раз',
#  'разве',
#  'свою',
#  'себя',
#  'сказать',
#  'снова',
#  'со',
#  'совсем',
#  'так',
#  'также',
#  'такие',
#  'такой',
#  'там',
#  'те',
#  'тебя',
#  'тем',
#  'теперь',
#  'то',
#  'тогда',
#  'того',
#  'тоже',
#  'той',
#  'только',
#  'том',
#  'тот',
#  'тут',
#  'ты',
#  'уже',
#  'хоть',
#  'хотя',
#  'чего',
#  'чего-то',
#  'чей',
#  'чем',
#  'через',
#  'что',
#  'что-то',
#  'чтоб',
#  'чтобы',
#  'чуть',
#  'чьё',
#  'чья',
#  'эта',
#  'эти',
#  'это',
#  'эту',
#  'этого',
#  'этом',
#  'этот',
#  'зачем',
#  'как',
#  'какая',
#  'какой',
#  'конечно',
#  'лучше',
#  'можно',
#  'моя',
#  'нельзя',
#  'сам',
#  'себе',
#  'сейчас',
#  'уж',
#  'хорошо',
#  'этой',
#  'который',
#  'риа',
#  'свой',
#  'ноль',
#  'один',
#  'два',
#  'три',
#  'четыре',
#  'пять',
#  'шесть',
#  'семь',
#  'восемь',
#  'девять',
#  'десять',
#  'а',
#  'б',
#  'в',
#  'г',
#  'д',
#  'е',
#  'ё',
#  'ж',
#  'з',
#  'и',
#  'й',
#  'к',
#  'л',
#  'м',
#  'н',
#  'о',
#  'п',
#  'р',
#  'с',
#  'т',
#  'у',
#  'ф',
#  'х',
#  'ц',
#  'ч',
#  'ш',
#  'щ',
#  'ъ',
#  'ы',
#  'ь',
#  'э',
#  'ю',
#  'я']
