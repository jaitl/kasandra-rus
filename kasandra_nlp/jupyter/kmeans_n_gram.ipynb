# %% [markdown]
# # Кластеризация новостей с помощью алгоритма KMeans
#
# Для представления текста в виде вектора используется tf-idf с n-gram, для нормализации слов используется Yandex MyStem,

# %% [markdown]
# # Модель новости

# %%
import json

class News:
    def __init__(self, id, date, annotation, title, content, url):
        self.id = id
        self.date = date
        self.annotation = annotation
        self.title = title
        self.content = content
        self.url = url
    
    @classmethod
    def from_json(cls, json_str):
        json_dict = json.loads(json_str)
        return cls(**json_dict)

# %% [markdown]
# # Загружаем новости для кластеризации

# %%
news = []
with open('/data/kasandra/news-1000.json', encoding="utf8") as f:
    for line in f:
        news.append(News.from_json(line))

list(map(lambda w: w.title, news[:5]))
# Out:
# ['На Алтае заработала первая в РФ система контроля космического пространства',
#  'ЛНР: Действия украинских диверсантов — одна из версий покушения на Плотницкого',
#  'Bild не публикует результаты России в медальном зачёте Олимпиады',
#  'Глава ЛНР связал покушение на свою жизнь с украинскими спецслужбами',
#  'Мэра города в США арестовали за попытку расплатиться наркотиками за секс с мужчинами']

# %% [markdown]
# # Загружаем стоп слова

# %%
stopwords = []

with open('../main/python/res/stopwords.txt', mode="r", encoding="utf8") as file:
    for line in file:
        stopwords.append(line.replace('\n', ''))

# %% [markdown]
# # Подключаем Yandex MyStem для нормализации текста

# %%
from pymystem3 import Mystem
import re

mystem = Mystem(mystem_bin='/data/mystem/mystem',
                entire_input=False)

# Оставляем только русские слова
r = re.compile('^[А-ЯЙа-яй]*$')

def lemmatize(text):
    return list(filter(r.match, mystem.lemmatize(text)))

# %% [markdown]
# ## Преобразуем текст в вектор с помощью TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(use_idf=True,
                                   tokenizer=lemmatize,
                                   stop_words=stopwords,
                                   ngram_range=(1,3))

tfidf_matrix = tfidf_vectorizer.fit_transform(map(lambda n: n.content, news))
idf = tfidf_vectorizer.idf_

# %% [markdown]
# Слова использующиеся в векторе

# %%
tfidf_vectorizer.get_feature_names()[:1000]
# Out:
# ['аба',
#  'аба ранее',
#  'аба ранее террорист',
#  'аба сообщаться',
#  'аба сообщаться погибший',
#  'абатов',
#  'абатов примерно',
#  'абатов примерно километр',
#  'аббас',
#  'аббас побережье',
#  'аббас побережье персидский',
#  'абдалла',
#  'абдалла бин',
#  'абдалла бин мусаид',
#  'абдалла салех',
#  'абдалла салех сообщать',
#  'абдеслам',
#  'абдеслам задерживать',
#  'абдеслам задерживать март',
#  'абдеслам занимать',
#  'абдеслам занимать должность',
#  'абдеслам получать',
#  'абдеслам получать власть',
#  'абдувахоб',
#  'абдувахоб маджидов',
#  'абдувахоб маджидов руслан',
#  'абдул',
#  'абдул рашид',
#  'абдул рашид садулаев',
#  'абдулкарим',
#  'абдулкарим арестовывать',
#  'абдулкарим арестовывать полиция',
#  'абдулович',
#  'абдулович искандер',
#  'абдулович искандер новость',
#  'абдулович искандер писатель',
#  'абдулрашид',
#  'абдулрашид садулаев',
#  'абдулрашид садулаев анзор',
#  'абдулрашид садулаев высокий',
#  'абдурашид',
#  'абдурашид виталий',
#  'абдурашид виталий дунайцев',
#  'абдурашид владимир',
#  'абдурашид владимир никитин',
#  'абдурашид кг',
#  'абдурашид кг встречаться',
#  'абдурашид миша',
#  'абдурашид миша алоян',
#  'абединять',
#  'абединять военнослужащий',
#  'абединять военнослужащий амира',
#  'аберкан',
#  'аберкан газета',
#  'аберкан газета подчеркивать',
#  'аберкан дата',
#  'аберкан дата судебный',
#  'аберкан приговаривать',
#  'аберкан приговаривать суд',
#  'абзалов',
#  'абзалов джебхат',
#  'абзалов джебхат ан',
#  'абзалов мнение',
#  'абзалов мнение аналитик',
#  'абзалов отряд',
#  'абзалов отряд боевик',
#  'абзац',
#  'абзац зверство',
#  'абзац зверство сирия',
#  'абзац правда',
#  'абзац правда никто',
#  'аблязин',
#  'аблязин давид',
#  'аблязин давид белявский',
#  'аблязин иван',
#  'аблязин иван стретович',
#  'аблязин определенный',
#  'аблязин определенный медальный',
#  'абонент',
#  'абонент традиционно',
#  'абонент традиционно недоступный',
#  'абонентский',
#  'абонентский комплекс',
#  'абонентский комплекс чегет',
#  'абр',
#  'абр пампа',
#  'абр пампа примерно',
#  'абрахамян',
#  'абрахамян выигрывать',
#  'абрахамян выигрывать сражение',
#  'абрахамян лишать',
#  'абрахамян лишать награда',
#  'абрахамян представлять',
#  'абрахамян представлять швеция',
#  'абрахамян спорный',
#  'абрахамян спорный решение',
#  'абросимов',
#  'абросимов александра',
#  'абросимов александра разаренов',
#  'абросимова',
#  'абросимова александр',
#  'абросимова александр брюханков',
#  'абсолютно',
#  'абсолютно безответственно',
#  'абсолютно безответственно относиться',
#  'абсолютно несправедливый',
#  'абсолютно несправедливый уверенный',
#  'абсолютно правый',
#  'абсолютно правый любой',
#  'абсолютно соответствовать',
#  'абсолютно соответствовать действительность',
#  'абсолютно точно',
#  'абсолютно точно соответствовать',
#  'абсолютно четкий',
#  'абсолютно четкий понятный',
#  'абсолютный',
#  'абсолютный большинство',
#  'абсолютный большинство житель',
#  'абсолютный большинство россиянин',
#  'абсолютный дискриминация',
#  'абсолютный дискриминация требование',
#  'абсолютный невосприятие',
#  'абсолютный невосприятие посол',
#  'абсолютный фаворитка',
#  'абсолютный фаворитка состязание',
#  'абсолютный чемпионка',
#  'абсолютный чемпионка мир',
#  'абсурд',
#  'абсурд бороться',
#  'абсурд бороться побеждать',
#  'абсурд граничить',
#  'абсурд граничить просто',
#  'абсурд причем',
#  'абсурд причем слово',
#  'абсурд спортсмен',
#  'абсурд спортсмен страна',
#  'абсурдизм',
#  'абсурдизм читать',
#  'абсурдизм читать русский',
#  'абсурдист',
#  'абсурдист даниил',
#  'абсурдист даниил хармс',
#  'абсурдный',
#  'абсурдный обман',
#  'абсурдный обман буквально',
#  'абсурдный подчеркивать',
#  'абсурдный подчеркивать москва',
#  'абсурдный россия',
#  'абсурдный россия страна',
#  'абсурдный утверждение',
#  'абсурдный утверждение проправительственный',
#  'абу',
#  'абу даби',
#  'абу даби уходить',
#  'абу дуа',
#  'абу дуа аль',
#  'абу мохаммед',
#  'абу мохаммед аль',
#  'абу мухаммад',
#  'абу мухаммад аль',
#  'абу мухаммед',
#  'абу мухаммед аль',
#  'абу умар',
#  'абу умар аш',
#  'абхазия',
#  'абхазия глава',
#  'абхазия глава президент',
#  'абхазия отмечаться',
#  'абхазия отмечаться совещание',
#  'абхазия рауль',
#  'абхазия рауль хаджимба',
#  'абхазия эльвира',
#  'абхазия эльвира арсалий',
#  'абхазский',
#  'абхазский народ',
#  'абхазский народ фазиль',
#  'абхазский язык',
#  'абхазский язык могила',
#  'абэ',
#  'абэ приказывать',
#  'абэ приказывать японский',
#  'аваков',
#  'аваков антон',
#  'аваков антон геращенко',
#  'аваков июнь',
#  'аваков июнь год',
#  'авакова',
#  'авакова расформирование',
#  'авакова расформирование подразделение',
#  'авакова убежденный',
#  'авакова убежденный польза',
#  'авангард',
#  'авангард беербаум',
#  'авангард беербаум лошадь',
#  'авантюрный',
#  'авантюрный борьба',
#  'авантюрный борьба создатель',
#  'аварийность',
#  'аварийность дорога',
#  'аварийность дорога россия',
#  'аварийный',
#  'аварийный посадка',
#  'аварийный посадка вода',
#  'аварийный посадка международный',
#  'аварийный посадка находиться',
#  'аварийный посадка принадлежать',
#  'аварийный технический',
#  'аварийный технический помощь',
#  'авария',
#  'авария военный',
#  'авария военный самолет',
#  'авария калифорния',
#  'авария калифорния подписываться',
#  'авария катастрофа',
#  'авария катастрофа самолет',
#  'авария лишать',
#  'авария лишать право',
#  'авария минимум',
#  'авария минимум взрыв',
#  'авария ряд',
#  'авария ряд участок',
#  'авг',
#  'авг гитарист',
#  'авг гитарист коллектив',
#  'авг информация',
#  'авг информация агентство',
#  'авг место',
#  'авг место происшествие',
#  'авг московский',
#  'авг московский река',
#  'авг наталья',
#  'авг наталья дембинский',
#  'авг никто',
#  'авг никто россия',
#  'авг новость',
#  'авг новость абсолютный',
#  'авг новость автомобиль',
#  'авг новость агентство',
#  'авг новость администрация',
#  'авг новость александр',
#  'авг новость алексей',
#  'авг новость американский',
#  'авг новость аналитик',
#  'авг новость археолог',
#  'авг новость бельгийский',
#  'авг новость боевик',
#  'авг новость бразильский',
#  'авг новость бургер',
#  'авг новость бывший',
#  'авг новость валерий',
#  'авг новость варшава',
#  'авг новость верховный',
#  'авг новость взрыв',
#  'авг новость виктория',
#  'авг новость владимир',
#  'авг новость внефракционный',
#  'авг новость военнослужащий',
#  'авг новость вооруженный',
#  'авг новость воскресение',
#  'авг новость воскресный',
#  'авг новость временно',
#  'авг новость время',
#  'авг новость выполнение',
#  'авг новость генеральный',
#  'авг новость глава',
#  'авг новость год',
#  'авг новость гражданин',
#  'авг новость движение',
#  'авг новость день',
#  'авг новость депутат',
#  'авг новость дмитрий',
#  'авг новость добавление',
#  'авг новость доклад',
#  'авг новость дэвид',
#  'авг новость европейский',
#  'авг новость евросоюз',
#  'авг новость египетский',
#  'авг новость екатеринбург',
#  'авг новость екатеринбуржец',
#  'авг новость житель',
#  'авг новость журналист',
#  'авг новость замгенпрокурор',
#  'авг новость заявление',
#  'авг новость иван',
#  'авг новость израильский',
#  'авг новость инсаф',
#  'авг новость институт',
#  'авг новость интернет',
#  'авг новость ирина',
#  'авг новость иркутский',
#  'авг новость исполнять',
#  'авг новость истребитель',
#  'авг новость камера',
#  'авг новость кандидат',
#  'авг новость киев',
#  'авг новость китай',
#  'авг новость кндр',
#  'авг новость колумнист',
#  'авг новость конец',
#  'авг новость концерн',
#  'авг новость кремль',
#  'авг новость ксения',
#  'авг новость курсант',
#  'авг новость лариса',
#  'авг новость лидер',
#  'авг новость лидия',
#  'авг новость маргарита',
#  'авг новость мария',
#  'авг новость мать',
#  'авг новость международный',
#  'авг новость меньший',
#  'авг новость министерство',
#  'авг новость министр',
#  'авг новость минобрнаука',
#  'авг новость мировой',
#  'авг новость михаил',
#  'авг новость модернизированный',
#  'авг новость москва',
#  'авг новость московский',
#  'авг новость мэр',
#  'авг новость народный',
#  'авг новость национальный',
#  'авг новость неизвестный',
#  'авг новость немецкий',
#  'авг новость обвинять',
#  'авг новость оборудование',
#  'авг новость объем',
#  'авг новость около',
#  'авг новость ольга',
#  'авг новость отдельный',
#  'авг новость открывать',
#  'авг новость отношение',
#  'авг новость официальный',
#  'авг новость пассажир',
#  'авг новость пассажирский',
#  'авг новость пенсионерка',
#  'авг новость перезапуск',
#  'авг новость персеиды',
#  'авг новость пилот',
#  'авг новость подсолнух',
#  'авг новость поедание',
#  'авг новость поисковый',
#  'авг новость покупатель',
#  'авг новость покушение',
#  'авг новость политический',
#  'авг новость полицейский',
#  'авг новость полиция',
#  'авг новость пользователь',
#  'авг новость польша',
#  'авг новость понедельник',
#  'авг новость попытка',
#  'авг новость последний',
#  'авг новость постановка',
#  'авг новость потенциал',
#  'авг новость правоохранитель',
#  'авг новость прайм',
#  'авг новость председатель',
#  'авг новость президент',
#  'авг новость принимать',
#  'авг новость причина',
#  'авг новость прокуратура',
#  'авг новость прокурор',
#  'авг новость пропуск',
#  'авг новость пьяный',
#  'авг новость район',
#  'авг новость республика',
#  'авг новость республиканец',
#  'авг новость ровно',
#  'авг новость росгвардия',
#  'авг новость российский',
#  'авг новость российско',
#  'авг новость россия',
#  'авг новость россиянка',
#  'авг новость руководство',
#  'авг новость самолет',
#  'авг новость семидесятисемилетний',
#  'авг новость сеть',
#  'авг новость склад',
#  'авг новость следователь',
#  'авг новость слово',
#  'авг новость сми',
#  'авг новость советник',
#  'авг новость социальный',
#  'авг новость спасатель',
#  'авг новость специальный',
#  'авг новость спецпредставитель',
#  'авг новость сумма',
#  'авг новость сша',
#  'авг новость террористический',
#  'авг новость треть',
#  'авг новость трое',
#  'авг новость турецкий',
#  'авг новость украина',
#  'авг новость украинский',
#  'авг новость управление',
#  'авг новость ученый',
#  'авг новость фон',
#  'авг новость французский',
#  'авг новость цб',
#  'авг новость ценный',
#  'авг новость центробанк',
#  'авг новость экс',
#  'авг новость элемент',
#  'авг подумать',
#  'авг подумать почему',
#  'авг результат',
#  'авг результат инцидент',
#  'авг речка',
#  'авг речка каменка',
#  'авг слово',
#  'авг слово спортсменка',
#  'авг спорт',
#  'авг спорт александр',
#  'авг спорт анатолий',
#  'авг спорт бразильский',
#  'авг спорт главный',
#  'авг спорт елена',
#  'авг спорт женский',
#  'авг спорт ильдар',
#  'авг спорт международный',
#  'авг спорт награда',
#  'авг спорт роман',
#  'авг спорт российский',
#  'авг спорт сайт',
#  'авг спорт семен',
#  'авг спорт спортивный',
#  'авг спорт спортсмен',
#  'авг спорт трехкратный',
#  'авг считать',
#  'авг считать оскорбительный',
#  'авг чтопроисходить',
#  'авг чтопроисходить самара',
#  'август',
#  'август август',
#  'август август август',
#  'август август данные',
#  'август август начинаться',
#  'август август подписываться',
#  'август август результат',
#  'август август сообщаться',
#  'август август участник',
#  'август активность',
#  'август активность вулкан',
#  'август американский',
#  'август американский инициатива',
#  'август амстердам',
#  'август амстердам ответный',
#  'август афганский',
#  'август афганский провинция',
#  'август блумсбери',
#  'август блумсбери являться',
#  'август боже',
#  'август боже пожалуйста',
#  'август болеть',
#  'август болеть российский',
#  'август бразильский',
#  'август бразильский время',
#  'август бридон',
#  'август бридон согласный',
#  'август ваш',
#  'август ваш браузер',
#  'август вашингтон',
#  'август вашингтон начинать',
#  'август вероятный',
#  'август вероятный молодой',
#  'август весело',
#  'август весело рио',
#  'август видеоролик',
#  'август видеоролик место',
#  'август владимир',
#  'август владимир путин',
#  'август восточный',
#  'август восточный часть',
#  'август впервые',
#  'август впервые сентябрь',
#  'август встреча',
#  'август встреча владимир',
#  'август встреча президент',
#  'август встречаться',
#  'август встречаться команда',
#  'август вступать',
#  'август вступать сила',
#  'август вход',
#  'август вход разговор',
#  'август выпускать',
#  'август выпускать обращение',
#  'август глава',
#  'август глава государство',
#  'август глава организация',
#  'август главный',
#  'август главный тренер',
#  'август го',
#  'август го вовсе',
#  'август год',
#  'август год алжирский',
#  'август год взять',
#  'август год временный',
#  'август год входить',
#  'август год июль',
#  'август год новый',
#  'август год оперативный',
#  'август год паралимпийский',
#  'август год погибать',
#  'август год полигон',
#  'август год преддверие',
#  'август год предлагать',
#  'август год президент',
#  'август год разделять',
#  'август год сборная',
#  'август год спустя',
#  'август год уходить',
#  'август годовщина',
#  'август годовщина создание',
#  'август далее',
#  'август далее статуя',
#  'август данные',
#  'август данные власть',
#  'август данные полиция',
#  'август данные сми',
#  'август данные цб',
#  'август действовать',
#  'август действовать оранжевый',
#  'август день',
#  'август день начало',
#  'август дефляция',
#  'август дефляция крайний',
#  'август диагноз',
#  'август диагноз сибирский',
#  'август должно',
#  'август должно заканчиваться',
#  'август дом',
#  'август дом улица',
#  'август допинговый',
#  'август допинговый скандал',
#  'август думать',
#  'август думать попокатепетль',
#  'август жестокий',
#  'август жестокий убийство',
#  'август заместитель',
#  'август заместитель фархан',
#  'август идентифицировать',
#  'август идентифицировать российский',
#  'август информация',
#  'август информация бельгийский',
#  'август информация сми',
#  'август информировать',
#  'август информировать сайт',
#  'август инцидент',
#  'август инцидент аэропорт',
#  'август инцидент происходить',
#  'август исполнение',
#  'август исполнение обязанность',
#  'август исполняться',
#  'август исполняться ровно',
#  'август каждый',
#  'август каждый день',
#  'август километр',
#  'август километр вяземский',
#  'август клуб',
#  'август клуб вернуться',
#  'август компания',
#  'август компания аэрофлот',
#  'август комплект',
#  'август комплект награда',
#  'август конструкция',
#  'август конструкция автобус',
#  'август кормушка',
#  'август кормушка покупать',
#  'август крайтор',
#  'август крайтор отобираться',
#  'август летний',
#  'август летний мужчина',
#  'август магазин',
#  'август магазин поступать',
#  'август международный',
#  'август международный аэропорт',
#  'август международный олимпийский',
#  'август местный',
#  'август местный сми',
#  'август минимум',
#  'август минимум спортсмен',
#  'август митинг',
#  'август митинг против',
#  'август мнение',
#  'август мнение разработчик',
#  'август многие',
#  'август многие заявлять',
#  'август многий',
#  'август многий стрессовый',
#  'август момент',
#  'август момент потеря',
#  'август мск',
#  'август мск предстоящий',
#  'август мужчина',
#  'август мужчина выстреливать',
#  'август мэр',
#  'август мэр ярославль',
#  'август накануне',
#  'август накануне время',
#  'август намечать',
#  'август намечать дорожный',
#  'август напоминать',
#  'август напоминать июль',
#  'август напоминать ранее',
#  'август настоящий',
#  'август настоящий момент',
#  'август национальный',
#  'август национальный антикоррупционный',
#  'август национальный управление',
#  'август начало',
#  'август начало сентябрь',
#  'август начинать',
#  'август начинать освещать',
#  'август начинать проводить',
#  'август начинаться',
#  'август начинаться голосование',
#  'август неизвестный',
#  'август неизвестный ранее',
#  'август немка',
#  'август немка грозить',
#  'август ничто',
#  'август ничто значить',
#  'август новость',
#  'август новость виктория',
#  'август ноябрь',
#  'август ноябрь прошлый',
#  'август оаэ',
#  'август оаэ москва',
#  'август обама',
#  'август обама вторник',
#  'август обычный',
#  'август обычный парень',
#  'август ожидать',
#  'август ожидать стоимость',
#  'август около',
#  'август около час',
#  'август олимпийский',
#  'август олимпийский игра',
#  'август оон',
#  'август оон вновь',
#  'август оперативный',
#  'август оперативный группа',
#  'август осень',
#  'август осень год',
#  'август отдельный',
#  'август отдельный неделя',
#  'август отдыхать',
#  'август отдыхать решать',
#  'август официальный',
#  'август официальный сайт',
#  'август охватывать',
#  'август охватывать страна',
#  'август память',
#  'август память радость',
#  'август паспорт',
#  'август паспорт содержать',
#  'август первый',
#  'август первый медаль',
#  'август период',
#  'август период гринвич',
#  'август плохой',
#  'август плохой дружить',
#  'август победитель',
#  'август победитель дебаттла',
#  'август подобный',
#  'август подобный загадка',
#  'август подписываться',
#  'август подписываться курс',
#  'август пока',
#  'август пока группировка',
#  'август пользователь',
#  'август пользователь иронизировать',
#  'август попо',
#  'август попо ласковый',
#  'август попов',
#  'август попов отмечать',
#  'август популярность',
#  'август популярность полуостров',
#  'август появляться',
#  'август появляться стихотворение',
#  'август предварительный',
#  'август предварительный данные',
#  'август предоставлять',
#  'август предоставлять трехлетний',
#  'август предполагать',
#  'август предполагать преступник',
#  'август предположительно',
#  'август предположительно совершать',
#  'август предыдущий',
#  'август предыдущий ремонт',
#  'август президент',
#  'август президент сша',
#  'август приводить',
#  'август приводить тасс',
#  'август приводить ущерб',
#  'август примета',
#  'август примета махачкалинский',
#  'август присутствовать',
#  'август присутствовать глава',
#  'август провинция',
#  'август провинция идлиб',
#  'август проводить',
#  'август проводить большой',
#  'август продолжительный',
#  'август продолжительный заявление',
#  'август проект',
#  'август проект название',
#  'август проект резолюция',
#  'август просмотр',
#  'август просмотр автор',
#  'август против',
#  'август против днепропетровский',
#  'август проходить',
#  'август проходить первый',
#  'август прочитывать',
#  'август прочитывать рэп',
#  'август путешественник',
#  'август путешественник преодолевать',
#  'август путин',
#  'август путин сильный',
#  'август радом',
#  'август раздел',
#  'август раздел объединять',
#  'август район',
#  'август район копейский',
#  'август рамка',
#  'август рамка серия',
#  'август рамка эмиссионный',
#  'август ранее',
#  'август ранее британский',
#  'август ранее раздача',
#  'август ранее сообщать',
#  'август ранее сообщаться',
#  'август результат',
#  'август результат происшествие',
#  'август российский',
#  'август российский военнослужащий',
#  'август россия',
#  'август россия традиционно',
#  'август самолет',
#  'август самолет должный',
#  'август связь',
#  'август связь проведение',
#  'август сентябрь',
#  'август сентябрь планироваться',
#  'август сентябрь порядок',
#  'август сентябрь продовольственный',
#  'август сентябрь россия',
#  'август сентябрь способный',
#  'август сентябрь считать',
#  'август сентябрь целое',
#  'август сессия',
#  'август сессия международный',
#  'август сирийский',
#  'август сирийский ввс',
#  'август сирийский провинция',
#  'август сирия',
#  'август сирия район',
#  'август складываться',
#  'август складываться правильный',
#  'август скорость',
#  'август скорость ветер',
#  'август следовать',
#  'август следовать логика',
#  'август смешно',
#  'август смешно нож',
#  'август смешно попокатепетль',
#  'август согласно',
#  'август согласно идея',
#  'август согласно регламент',
#  'август сообщать',
#  'август сообщать новость',
#  'август сообщаться',
#  'август сообщаться самолет',
#  'август соревнование',
#  'август соревнование паралимпиец',
#  'август сослуживец',
#  'август сослуживец посещать',
#  'август состояться',
#  'август состояться церемония',
#  'август спортсмен',
#  'август спортсмен данный',
#  'август стадион',
#  'август стадион маракан',
#  'август становиться',
#  'август становиться известно',
#  'август становиться первый',
#  'август старт',
#  'август старт олимпийский',
#  'август стихотворение',
#  'август стихотворение опубликовывать',
#  'август стоимость',
#  'август стоимость лицензия',
#  'август страна',
#  'август страна объявлять',
#  'август считать',
#  'август считать июльский',
#  'август сыграть',
#  'август сыграть гость',
#  'август тандем',
#  'август тандем трамп',
#  'август территория',
#  'август территория легендарный',
#  'август тренировка',
#  'август тренировка случаться',
#  'август удивительно',
#  'август удивительно подниматься',
#  'август улица',
#  'август улица бебель',
#  'август участвовать',
#  'август участвовать подразделение',
#  'август участник',
#  'август участник протест',
#  'август фаворит',
#  'август фаворит баскетбольный',
#  'август хороший',
#  'август хороший работа',
#  'август церемония',
#  'август церемония открытие',
#  'август цитировать',
#  'август цитировать слово',
#  'август часть',
#  'август часть алкоголь',
#  'август чувствовать',
#  'август чувствовать сердце',
#  'август швейцарский',
#  'август швейцарский ньон',
#  'авдеев',
#  'авдеев алексей',
#  'авдеев алексей черемисинов',
#  'аветисян',
#  'аветисян группа',
#  'аветисян группа удерживать',
#  'аветисян заявлять',
#  'аветисян заявлять член',
#  'аветисян отмечать',
#  'аветисян отмечать толчок',
#  'аветисян слово',
#  'аветисян слово группировка',
#  'авиабаза',
#  'авиабаза бундесвер',
#  'авиабаза бундесвер бюхель',
#  'авиабаза зависимость',
#  'авиабаза зависимость турция',
#  'авиабаза инджирлик',
#  'авиабаза инджирлик выяснять',
#  'авиабаза инджирлик против',
#  'авиабаза инджирлик проходить',
#  'авиабаза инджирлик сила',
#  'авиабаза инджирлик юг',
#  'авиабаза использоваться',
#  'авиабаза использоваться мочь',
#  'авиабаза латакия',
#  'авиабаза латакия обмен',
#  'авиабаза народ',
#  'авиабаза народ адана',
#  'авиабаза нато',
#  'авиабаза нато инджирлик',
#  'авиабаза находиться',
#  'авиабаза находиться провинция',
#  'авиабаза помогать',
#  'авиабаза помогать топливо',
#  'авиабаза самолет',
#  'авиабаза самолет совершать',
#  'авиабаза слух',
#  'авиабаза слух новый',
#  'авиабаза хмеймить',
#  'авиабаза хмеймить доставка',
#  'авиабаза хмеймить пункт',
#  'авиабаза штат',
#  'авиабаза штат невада',
#  'авиабилет',
#  'авиабилет организация',
#  'авиабилет организация чартерный',
#  'авиабомба',
#  'авиабомба боеприпасы',
#  'авиабомба боеприпасы вмф',
#  'авиабомба данные',
#  'авиабомба данные общий',
#  'авиабомба двенадцатый',
#  'авиабомба двенадцатый серия',
#  'авиагруппа',
#  'авиагруппа россия',
#  'авиагруппа россия сохранять',
#  'авиагруппа сирия',
#  'авиагруппа сирия попытка',
#  'авиадартс',
#  'авиадартс помогать',
#  'авиадартс помогать мирно',
#  'авиазавод',
#  'авиазавод первый',
#  'авиазавод первый полет',
#  'авиазавод подписываться',
#  'авиазавод подписываться курс',
#  'авиакатастрофа',
#  'авиакатастрофа дополнительный',
#  'авиакатастрофа дополнительный подробность',
#  'авиакатастрофа заявитель',
#  'авиакатастрофа заявитель иск',
#  'авиакомпания',
#  'авиакомпания борт',
#  'авиакомпания борт находиться',
#  'авиакомпания вылетать',
#  'авиакомпания вылетать индийский',
#  'авиакомпания вылетать индия',
#  'авиакомпания загораться',
#  'авиакомпания загораться аэропорт',
#  'авиакомпания замена',
#  'авиакомпания замена самолет',
#  'авиакомпания когалымавиа',
#  'авиакомпания когалымавиа лететь',
#  'авиакомпания когалымавиа совершать',
#  'авиакомпания марина',
#  'авиакомпания марина калаганский',
#  'авиакомпания направляться',
#  'авиакомпания направляться процедура',
#  'авиакомпания перелет',
#  'авиакомпания перелет стамбул',
#  'авиакомпания победа',
#  'авиакомпания победа рассматривать',
#  'авиакомпания прибывать',
#  'авиакомпания прибывать индия',
#  'авиакомпания самолет',
#  'авиакомпания самолет выполнять',
#  'авиакомпания совершать',
#  'авиакомпания совершать неудачный',
#  'авиакомпания сообщать',
#  'авиакомпания сообщать агентство',
#  'авиалазер',
#  'авиалазер элемент',
#  'авиалазер элемент национальный',
#  'авиалиния',
#  'авиалиния август',
#  'авиалиния август думать',
#  'авиалиния следовать',
#  'авиалиния следовать рейс',
#  'авианесущий',
#  'авианесущий крейсер',
#  'авианесущий крейсер адмирал',
#  'авиаперевозчик',
#  'авиаперевозчик изменение',
#  'авиаперевозчик изменение график',
#  'авиаперевозчик отмечаться',
#  'авиаперевозчик отмечаться среди',
#  'авиасообщение',
#  'авиасообщение год',
#  'авиасообщение год грузия',
#  'авиасообщение россия',
#  'авиасообщение россия украина',
#  'авиасообщение страна',
#  'авиасообщение страна переговоры',
#  'авиаудар',
#  'авиаудар ведомый',
#  'авиаудар ведомый сша',
#  'авиаудар деревня',
#  'авиаудар деревня север',
#  'авиаудар коалиция',
#  'авиаудар коалиция руководство',
#  'авиаудар международный',
#  'авиаудар международный коалиция',
#  'авиаудар результат',
#  'авиаудар результат самый',
#  'авиаудар сша',
#  'авиаудар сша погибать',
#  'авиаудара',
#  'авиаудара должный',
#  'авиаудара должный незамедлительно',
#  'авиаудара объект',
#  'авиаудара объект террорист',
#  'авиаудара позиция',
#  'авиаудара позиция группировка',
#  'авиаудара совершать',
#  'авиаудара совершать соответствие',
#  'авиаударов',
#  'авиаударов американский',
#  'авиаударов американский коалиция',
#  'авиаударов город',
#  'авиаударов город сирия',
#  'авиационный',
#  'авиационный администрация',
#  'авиационный администрация объединять',
#  'авиационный бомба',
#  'авиационный бомба разрабатывать',
#  'авиационный двигатель',
#  'авиационный двигатель затем',
#  'авиационный комитет',
#  'авиационный комитет мак',
#  'авиационный носитель',
#  'авиационный носитель самолет',
#  'авиационный паромный',
#  'авиационный паромный сообщение',
#  'авиационный портал',
#  'авиационный портал аэропорт',
#  'авиационный прибор',
#  'авиационный прибор устанавливаться',
#  'авиационный сообщение',
#  'авиационный сообщение рядом',
#  'авиационный удар',
#  'авиационный удар городской',
#  'авиационный центр']

# %% [markdown]
# # Выполняем кластеризацию с помощью алгоритма K-Means

# %%
from sklearn.cluster import KMeans

num_clusters = 200

km = KMeans(n_clusters=num_clusters)

km.fit(tfidf_matrix)

clusters = km.cluster_centers_
labels = km.labels_
labels[:100]
# Out:
# array([ 68,  36,  36,  36, 134,  17, 110, 117,  36, 143,  12,  30,  36,
#         59, 124, 138, 109,  36,  22,  91, 153, 192, 178,  36, 142,  36,
#        110,  43,  45,  68,  36, 105, 117,  16, 131,  92, 117,  38, 188,
#         43,  46, 107,  36, 117,  72,  36,  13, 117,  36,  74,  36,  36,
#         51,  93, 189,  36, 174,  61,  17,  36,  61,  38, 130,  36,  54,
#        160, 174,  55, 117,  93,  66,  66, 159,  84,  43, 129,  36,  61,
#        149, 114,  92,   7,  72,  61,  17, 190,  72,  38,  17,  75,  36,
#         66,  36,  93, 157,  78,  14, 185,  74,  92], dtype=int32)

# %% [markdown]
# # Назначаем кластер новости

# %%
import numpy as np

zipNews = zip(news, labels)

def assign_label_to_news(tuplezz):
    (nws, lbl) = tuplezz
    nws.label = lbl.item()
    return nws

newsLabels = list(map(assign_label_to_news, zipNews))
list(map(lambda n: [n.title, n.label], newsLabels))[:10]
# Out:
# [['На Алтае заработала первая в РФ система контроля космического пространства',
#   68],
#  ['ЛНР: Действия украинских диверсантов — одна из версий покушения на Плотницкого',
#   36],
#  ['Bild не публикует результаты России в медальном зачёте Олимпиады', 36],
#  ['Глава ЛНР связал покушение на свою жизнь с украинскими спецслужбами', 36],
#  ['Мэра города в США арестовали за попытку расплатиться наркотиками за секс с мужчинами',
#   134],
#  ['Народная милиция ЛНР назвала причастных к покушению на Плотницкого', 17],
#  ['Во время церемонии открытия ОИ-2016 был ограблен Дом болельщиков сборной России',
#   110],
#  ['В Глазго, предположительно из-за взрыва, обрушилась часть здания', 117],
#  ['Председатель Совмина ЛНР: Состояние Плотницкого после покушения стабильное',
#   36],
#  ['Трамп и Крым', 143]]

# %% [markdown]
# # Группируем новости по кластерам

# %%
from itertools import groupby

newsLabels = sorted(newsLabels, key=lambda n: n.label)

groupedNews = {}
for key, group in groupby(newsLabels, lambda n: n.label):
    groupedNews[str(key)] = list(map(lambda n: n.__dict__, group))

jsonData = json.dumps(groupedNews, ensure_ascii=False, sort_keys=True, indent=4, separators=(',', ': '))

# %% [markdown]
# # Информация о кластерах

# %%
for label, group in groupby(newsLabels, lambda n: n.label):
    groupList = list(group)
    print("Cluster: %s, count news: %s, titles:" % (label, len(groupList)))
    for gr in groupList:
        print("\t" + gr.title)
# Out:
# Cluster: 0, count news: 1, titles:
# 	День в истории: 3 августа
# Cluster: 1, count news: 3, titles:
# 	Каноист Крайтор не явился на контрольный заезд для допуска на Олимпиаду
# 	ICF допустила российского гребца-каноиста Андрея Крайтора на Олимпиаду
# 	ICF пересмотрела свое решение и допустила каноиста Крайтора на Олимпиаду
# Cluster: 2, count news: 9, titles:
# 	Барак Обама: Террористы-одиночки и малые группы могут совершить теракты в США
# 	Бюрократия терроризма: бывший боевик рассказал, как организована вербовка в ИГ
# 	Италия расследует причастность ИГ к управлению потоком беженцев в страну
# 	Новая кампания США в Ливии: борьба с ИГ или вмешательство во внутренние дела страны?
# 	В Вашингтоне офицер полиции арестован по подозрению в связях с ИГ
# 	Госдеп США опроверг данные о планах отправки сухопутных войск в Ливию
# 	Дональд Трамп выступил за союз России и США в борьбе с ИГ
# 	Во Франции задержали мужчину по делу о теракте в Ницце
# 	Выходец из Алжира угрожал взорвать торговый центр в немецком Бремене
# Cluster: 3, count news: 2, titles:
# 	СМИ назвали причину, которая помешала мятежникам сбить самолет Эрдогана
# 	СМИ рассказали, почему мятежникам не удалось сбить самолёт Эрдогана
# Cluster: 4, count news: 2, titles:
# 	В горах Алтая нашли 1500-летнюю мумию в "кроссовках"
# 	В горах Алтая нашли 1500-летнюю мумию в "кроссовках"
# Cluster: 5, count news: 8, titles:
# 	Российский яхтсмен Павел Созыкин допущен до Олимпийских игр в Рио
# 	Сегодня ночью состоится церемония открытия Олимпиады в Рио
# 	CAS отменил правило МОК о недопуске имевших допинговую историю российских спортсменов
# 	CAS отменил правило МОК о недопуске имевших допинговую историю российских спортсменов
# 	Глава ОКР: Решение IAAF — абсолютная дискриминация
# 	Российские пловцы Никита Лобинцев и Владимир Морозов допущены до Олимпиады
# 	Князь Монако Альбер II: Допуск россиян на ОИ — единственно возможное для МОК решение
# 	Глава МОК: Решение о допуске российских атлетов в Рио основано на справедливости
# Cluster: 6, count news: 3, titles:
# 	В провинции Идлиб сбит российский военно-транспортный вертолет Ми-8
# 	На борту сбитого в Сирии вертолета Ми-8 находились пять человек
# 	В сети появились фото с места падения российского вертолета в Сирии
# Cluster: 7, count news: 2, titles:
# 	National Interest рассказал, как американские СМИ искажают факты о России
# 	Колумнист Guardian: Запад видит пропаганду только в России, но не у себя
# Cluster: 8, count news: 19, titles:
# 	Ястребы Хиллари: зачем ей в команде любители повоевать
# 	WSJ: Клинтон заподозрили в помощи российской оборонке через "Сколково"
# 	Олланд заявил, что "выходки" Трампа вызывают тошноту
# 	Клинтон опережает Трампа по популярности, показал опрос
# 	ВЦИОМ: треть россиян ждут улучшения отношений с США в случае победы Трампа
# 	Клинтон не отказывается от дебатов, несмотря на возражения Трампа
# 	WP рассказала, как США используют подлодки для хакерских атак
# 	Трамп заявил, что Сандерс "продал душу дьяволу", поддержав Клинтон
# 	Трамп обрушился на Клинтон с резкой критикой сразу после ее речи
# 	Трамп пообещал Клинтон перестать быть "хорошим парнем"
# 	Пушков предсказал "море крови" в схватке Клинтон и Трампа
# 	"Российская угроза" и "злобный" Трамп: Клинтон пообещала защищать Америку
# 	Клинтон заявила о поддержке НАТО в борьбе с "российской угрозой"
# 	Два кандидата - две Америки
# 	Клуб первых джентльменов: чем занимаются мужья женщин-президентов
# 	Опрос: Клинтон опережает Трампа по популярности среди избирателей на 9%
# 	США сомневаются, что теракты ИГ можно связывать с "радикальным исламом"
# 	Ассанж сравнил голосование за главу США с выбором между холерой и гонореей
# 	WP: Клинтон превратила демократов в "антироссийскую" партию
# Cluster: 9, count news: 6, titles:
# 	Природа, разнообразие и радость: церемония открытия Игр в Рио
# 	Счастье из нищеты: в Рио-де-Жанейро открылись XXXI летние Олимпийские игры
# 	В Бразилии стартовали Олимпийские игры
# 	CAS отменил правило о недопуске на Игры-2016 атлетов с "допинговым прошлым"
# 	Рио-де-Жанейро в ожидании Олимпиады
# 	Генконсул опроверг участие российского дипломата в перестрелке в Рио
# Cluster: 10, count news: 4, titles:
# 	Ирина Яровая просит Минздрав РФ помочь спасшей детей жительнице Алеппо
# 	Россиянка в Сирии потеряла кисть руки и ногу, спасая детей от мины
# 	В Сирии россиянка потеряла кисть руки и ногу из-за попавшего в дом снаряда
# 	В Сирии россиянка потеряла кисть руки и ногу из-за попавшего в дом снаряда
# Cluster: 11, count news: 2, titles:
# 	О мудрости, глупости, зависти и счастье. Знаменитые цитаты Фазиля Искандера
# 	Валом повалят: пять причин встать в очередь на Айвазовского
# Cluster: 12, count news: 5, titles:
# 	«Верный друг»: соревнования кинологов в Подмосковье
# 	Танцевальная машина: китайские роботы установили мировой рекорд
# 	Камера, мотор: гоночный автомобиль сбил оператора с ног
# 	Ничего необычного, просто орангутан танцует брейк-данс
# 	Не повторять, опасно: россиянин стал звездой команды RedBull
# Cluster: 13, count news: 1, titles:
# 	Рейс Air Algerie из Алжира в Марсель пропал с радаров над Средиземным морем
# Cluster: 14, count news: 3, titles:
# 	«Гитлер вечно боялся растолстеть»: что мы узнали о Третьем рейхе из дневников нацистов
# 	«Гитлер вечно боялся растолстеть»: что мы узнали о Третьем рейхе из дневников нацистов
# 	СМИ опубликовали отрывки из найденных в Подольске дневников Гиммлера
# Cluster: 15, count news: 5, titles:
# 	Сдвиг Австралии может привести к неполадкам в работе GPS
# 	Автопроизводители прислали актёру Антону Ельчину письмо об отзыве машины после его смерти
# 	В Сингапуре протестируют беспилотное такси
# 	Прокатили: как обманывают в автосалонах
# 	Lamborghini жалко: как система ЭРА-ГЛОНАСС повлияет на продажи иномарок
# Cluster: 16, count news: 4, titles:
# 	Сегодня в Москве ожидается самый жаркий день в году
# 	СМИ: Генпрокуратура назвала самые коррумпированные регионы
# 	Посчитали по низам: о чем говорит рейтинг разгула коррупции в России
# 	СМИ: Чайка подписал приказ по борьбе с откатами и коррупцией в госзаказе
# Cluster: 17, count news: 7, titles:
# 	Народная милиция ЛНР назвала причастных к покушению на Плотницкого
# 	Глава ЛНР ранен в результате покушения
# 	ЛНР: Автомобиль Плотницкого был взорван бомбой мощностью до 15 кг тротила
# 	Глава ЛНР Плотницкий госпитализирован после покушения
# 	В ЛНР назвали причастных к покушению на Плотницкого
# 	Опубликовано видео, на котором показано, что осталось от машины главы ЛНР
# 	Спецмиссия ОБСЕ опубликовала оперативный отчет о покушении на главу ЛНР
# Cluster: 18, count news: 6, titles:
# 	Владимир Путин поздравил Барака Обаму с 55-летием
# 	Французский депутат назвал омерзительным вопрос киевского репортера о Крыме
# 	В Крым прибыла делегация французских парламентариев
# 	Тьерри Мариани призвал мировое сообщество признать Крым частью России
# 	Власти Крыма сообщили о тренировочных лагерях ИГ на юге Украины
# 	«У людей бывают убеждения, а не только интересы»: Мариани пообщался с украинской прессой
# Cluster: 19, count news: 4, titles:
# 	Эстонский депутат потребовал от России извинений за монету с «Бронзовым солдатом»
# 	Литву возмутили российские монеты с изображением Вильнюса
# 	Банк России объяснил Литве, что означают монеты с Вильнюсом
# 	Банк России ответил Литве, раскритиковавшей монеты с изображением Вильнюса
# Cluster: 20, count news: 2, titles:
# 	Тысячи литров вина разлили на улицах французского города Сет
# 	Во французском городе Сет неизвестные разлили тысячи литров вина на улицах города
# Cluster: 21, count news: 3, titles:
# 	Боевики казнили трех мирных жителей, пытавшихся покинуть Алеппо
# 	В Алеппо боевики применили химическое оружие, есть погибшие
# 	Ополчение Алеппо сообщило о применении боевиками химоружия
# Cluster: 22, count news: 4, titles:
# 	Подозреваемый в нападении на туристов предстал перед судом Лондона
# 	В одном из торговых центров Лондона неизвестные напали с ножом на мужчину
# 	Ни у кого из пострадавших при нападении в Лондоне нет ранений, угрожающих жизни
# 	Мэр Лондона Садик Хан призвал жителей быть бдительными после нападения в центре города
# Cluster: 23, count news: 7, titles:
# 	Сергей Шнуров ответил на иск Burger King
# 	Facebook нашёл способ борьбы с жёлтыми заголовками в ленте
# 	Burger King подаст в суд на Сергея Шнурова из-за стихотворения в Instagram
# 	Сергей Шнуров отреагировал на иск "Бургер Кинга" фразой "ни дня без суда!"
# 	Сергей Шнуров отреагировал на иск "Бургер Кинга" фразой "ни дня без суда!"
# 	"Бургер Кинг" подаст в суд на Шнурова
# 	Facebook и Google используют мультики для борьбы с террористами
# Cluster: 24, count news: 2, titles:
# 	СМИ: Неизвестные захватили лечебницу в Бурятии
# 	СМИ: Неизвестные захватили лечебницу в Бурятии
# Cluster: 25, count news: 2, titles:
# 	СМИ: в Бельгии террористка ИГ оказалась на свободе из-за судебной волокиты
# 	WSJ: боевики-одиночки отвлекают власти от предотвращения крупных терактов
# Cluster: 26, count news: 6, titles:
# 	IWF отстранила российских тяжелоатлетов от Олимпиады в Рио
# 	У разбитого корыта: всех российских тяжелоатлетов отстранили от Олимпиады
# 	Мутко: формально у сборной России еще нет одобрения на участие в Олимпиаде
# 	К Олимпиаде в Рио допустили 266 российских спортсменов
# 	Российских тяжелоатлетов отстранили от Олимпиады в Рио
# 	Апелляцию в CAS на отстранение тяжелоатлетов от Игр подадут в ближайшие дни
# Cluster: 27, count news: 4, titles:
# 	Foreign Policy: Украина переоценила собственную важность для Запада
# 	Киев приостановил поставки продукции 243 российских компаний
# 	На Украине задержали экс-руководителя фракции "Партии регионов"
# 	Крестный ход в Киеве завершился торжественным молебном
# Cluster: 28, count news: 3, titles:
# 	КНДР обвинила США в планировании упреждающего ядерного удара
# 	КНДР запустила баллистическую ракету
# 	КНДР обвинила США в подготовке к биохимической войне в Корее
# Cluster: 29, count news: 9, titles:
# 	Украинский дипломат рассказал, что в Киеве думают про слова Трампа о Крыме
# 	В парламенте Италии назвали "полуправдой" слова Порошенко о санкциях
# 	Трамп заявил, что попытка вернуть Крым может спровоцировать третью мировую
# 	Трамп вновь заявил, что готов рассмотреть вопрос о принадлежности Крыма
# 	Яценюк раскритиковал заявление Трампа по Крыму
# 	Мариани рассказал, когда можно будет начать обсуждения о признании Крыма
# 	Слуцкий: французские депутаты выучили по-русски выражение "Крым наш"
# 	Мариани: если бы Крым не присоединился к России, здесь был бы фронт
# 	Reuters: ЕС может снять санкции с одного из секторов экономики России
# Cluster: 30, count news: 2, titles:
# 	Легкомоторный самолёт упал в воды Ла-Манша на юго-востоке Англии
# 	Опубликовано видео горящего самолёта в аэропорту Дубая
# Cluster: 31, count news: 3, titles:
# 	В МИД РФ сказали, как модернизированная бомба США изменит ситуацию в мире
# 	Озеров: Россия готова минимизировать угрозу новой американской бомбы В61-12
# 	Озеров: Россия готова минимизировать угрозу новой американской бомбы В61-12
# Cluster: 32, count news: 6, titles:
# 	В аэропорту Тайваня из-за халатности погибли более тысячи попугаев
# 	Голландец попал в больницу после 10 дней ожидания подруги в аэропорту
# 	Пей и катись: бар на колесах и другой необычный транспорт
# 	Бабушка девочки, которую приняли за террористку: Случившееся отразилось на её здоровье
# 	В Китае прошли тестовые испытания портального автобуса
# 	В Китае испытали транспорт будущего
# Cluster: 33, count news: 4, titles:
# 	Прокуратура Польши возбудила дело против российского пилота
# 	В Минобороны Польши заявили о перехвате российского легкомоторного самолета
# 	СМИ рассказали о судьбе пилота перехваченного в Польше самолета
# 	В Минобороны Польши заявили о перехвате российского легкомоторного самолёта
# Cluster: 34, count news: 4, titles:
# 	На Ставрополье в результате ДТП погибли девять человек
# 	Фото не будет: почему ручные радары оказались под запретом
# 	"Ъ": ГИБДД запретила ручные радары в нескольких регионах
# 	СМИ сообщили о запрете инспекторам ГИБДД использовать ручные радары
# Cluster: 35, count news: 3, titles:
# 	СМИ назвали возможную причину пожара в Руане, в котором погибли 13 человек
# 	СМИ назвали возможную причину пожара в Руане, в котором погибли 13 человек
# 	В московском кафе от сердечной недостаточности скончался пьяный юноша
# Cluster: 36, count news: 174, titles:
# 	ЛНР: Действия украинских диверсантов — одна из версий покушения на Плотницкого
# 	Bild не публикует результаты России в медальном зачёте Олимпиады
# 	Глава ЛНР связал покушение на свою жизнь с украинскими спецслужбами
# 	Председатель Совмина ЛНР: Состояние Плотницкого после покушения стабильное
# 	На блошином рынке во Франции утраченную гравюру Дюрера продали за несколько евро
# 	В московском метро снова раздают воду из-за жары
# 	Джулиан Ассанж — RT: Саудовская Аравия может быть крупнейшим спонсором Клинтонов
# 	RT предложил прохожим в Рио определить олимпийскую столицу по фотографиям
# 	В Москве из-за жары продлён «оранжевый» уровень опасности
# 	В результате шторма «Эрл» в Мексике погибли шесть человек
# 	Посол Турции: Европа использует мятеж как повод не принять нас в ЕС
# 	Арабская коалиция под эгидой Саудовской Аравии активизирует боевые действия в Йемене
# 	Причиной пожара в баре во французском Руане стали свечи на торте
# 	Вооружённый мужчина захватил кафе в Германии
# 	Байдарочник на ОИ упал в воду после столкновения с затонувшим диваном
# 	Владимир Мутко: Борец Виктор Лебедев примет участие в Играх в Рио
# 	Утверждены выходные и праздничные дни на следующий год
# 	Президент ПКР: Сообщения об отстранении России от Паралимпиады являются слухами
# 	Ополчение Алеппо: Армия САР вторые сутки отражает штурм военных училищ города
# 	В Хиросиме прошла церемония памяти жертв ядерной бомбардировки
# 	ФБР обнаружило склад с оружием и пропагандой «Аль-Каиды» у жителя Детройта
# 	Сергей Лавров призвал Джона Керри активизировать борьбу с боевиками в Сирии
# 	Der Spiegel: Судьба Сирии находится в руках России
# 	Активисты Black Lives Matter заблокировали въезд в аэропорт Хитроу
# 	NASA разработало симулятор марсохода
# 	В Турции могут упразднить верховные военные суды
# 	Шимон Перес в интервью RT: Израиль должен признать государство Палестину
# 	СМИ сообщили о намерении Месси вернуться в сборную Аргентины
# 	Минобороны Турции: Армию страны реструктурируют, чтобы предотвратить новый мятеж
# 	Источник: Елена Исинбаева может возглавить ВФЛА после игр в Рио
# 	Новое правительство Перу вышло на зарядку вместе с президентом страны
# 	МИД РФ: США не готовы работать на равноправной основе с Россией по Сирии
# 	МЧС назвало причину падения Ил-76 под Иркутском
# 	Несколько зданий в Лондоне были эвакуированы из-за подозрительного предмета
# 	Пеле не сможет принять участия в церемонии открытия Олимпиады в Рио
# 	СМИ нашли видео откровенного танца американского полицейского, обвиняемого в расизме
# 	Дмитрий Аленичев покинул пост главного тренера «Спартака»
# 	Виталий Мутко: Трое из четырёх кандидатов на пост тренера сборной дали добро
# 	Полиция в Рио применила слезоточивый газ против активистов перед началом открытия игр
# 	Юрий Ушаков: Турция дала России письменные гарантии по безопасности туристов
# 	Советник Трампа: Состояние экономики США — худшее со времён Великой депрессии
# 	МОК допустил велогонщицу Ольгу Забелинскую к играм в Рио-де-Жанейро
# 	Сильвио Берлускони продал «Милан» инвесторам из Китая
# 	МИД РФ подтвердил, что среди экипажа захваченного талибами Ми-17 есть россиянин
# 	«Потому что из России»: что говорят жители и гости Рио о недопуске российских спортсменов
# 	Французские власти обязали владельцев халяльного супермаркета продавать вино и свинину
# 	В Дании предлагают ввести комендантский час в центрах для беженцев
# 	МОК допустил к Олимпиаде 16 российских борцов, среди них нет Лебедева
# 	В Лиге Европы «Спартак» проиграл кипрскому АЕК, «Краснодар» выиграл у «Биркиркары»
# 	Наталья Поклонская села за руль комбайна и приняла участие в сборе урожая
# 	Александр Жуков: Сейчас в Рио нет более чистой команды, чем сборная России
# 	Австрийская полиция не нашла свидетельств подготовки терактов в стране
# 	Канада приступила к ротации военных инструкторов на Украине
# 	Владимир Путин: Россия построит в Иране ещё 8 энергоблоков АЭС
# 	Николай Азаров назвал «мыльным пузырём» заявления Генпрокуратуры Украины
# 	Беспилотный автомобиль Google в очередной раз попал в ДТП
# 	«Поезд идёт, а что нам оставалось делать?»: мужчина о спасении ребёнка в Сочи
# 	Сборная России по теннису в полном составе допущена к Олимпиаде в Рио
# 	МОК допустил трёх российских лучниц к Олимпиаде
# 	В Бергамо грузовой Boeing выехал на дорогу после посадки
# 	Томас Бах: Санкции попавшимся на допинге после Олимпиады-2016 будет выносить CAS
# 	Во Франции местные власти запретили вечеринку у бассейна в буркини
# 	СМИ сообщили, что бразильские спортсмены не проходили допинг-контроль перед Олимпиадой
# 	Сборная России по теннису в полном составе допущена к Олимпиаде в Рио
# 	Представитель Эрдогана: Турция признательна РФ за поддержку после попытки переворота
# 	Пловцы Морозов и Лобинцев получили допуски к Олимпиаде
# 	В Рио открылся Дом болельщиков сборной России на Олимпиаде
# 	Врачи разрешили Пеле принять участие в церемонии зажжения олимпийского огня
# 	Сроки отключения горячей воды летом сократят до недели
# 	Российские бадминтонисты допущены к Олимпиаде в Рио
# 	Женская сборная России по гандболу допущена к Олимпиаде в полном составе
# 	МОК допустил до Олимпиады сборную России по велоспорту, кроме трёх спортсменов
# 	Бельгийская полиция задержала двух граждан Франции, угрожавших взорвать вокзал
# 	Танцующий фламинго был жестоко убит посетителем зоопарка во Флориде
# 	«Аэрофлот» отменил два рейса в Дубай и обратно на 4 и 5 августа
# 	Новак Джокович приветствовал участие российских спортсменов в Олимпиаде
# 	Emirates рассчитывает наладить график полётов после ЧП в Дубае в течение 36 часов
# 	СМИ: Взявший заложников во Франции заключённый требует перевода в другую тюрьму
# 	Публикацию результатов ЕГЭ рекомендуют сделать открытой
# 	Российские дзюдоисты допущены до Олимпиады в полном составе
# 	Ричард Паунд: WADA должно получить право отстранять спортсменов за допинг
# 	Главы России и Китая проведут двустороннюю встречу на саммите G20
# 	Виталий Чуркин: Стороны сирийского конфликта должны обсудить бумаги де Мистуры
# 	700 человек эвакуировали из-за пожара на Канарских островах
# 	На Олимпиаду в Рио могут отправиться до 12 тыс. российских болельщиков
# 	Российский байдарочник Александр Дьяченко, отстранённый от Олимпиады, подаёт иск в CAS
# 	«Яндекс.Навигатор» заговорил голосом Василия Уткина
# 	Песков: Москва не будет ослаблять усилия по возвращению Ярошенко, осуждённого в США
# 	СМИ: Взявший заложников во Франции заключённый требует перевода в другую тюрьму
# 	Владимир Путин не поедет на открытие Олимпиады в Рио-де-Жанейро
# 	В Турции парикмахер выстриг портрет Эрдогана на голове помощника
# 	На станции московского метро «Орехово» нашли гранату
# 	Сборная России по синхронному плаванию допущена комиссией МОК к Олимпиаде в полном составе
# 	Россия направила Латвии приглашение на консультации оборонных ведомств
# 	Неизвестный захватил заложников в следственном изоляторе на западе Франции
# 	Жительница Уссурийска прописала в собственном доме около 900 иностранцев
# 	В Париже группа людей, выкрикивающих исламистские лозунги, подожгла автобус
# 	В Санкт-Петербурге установят мемориальную доску адмиралу Колчаку
# 	Пользователи соцсетей сообщили о новой украинской монете с отъезжающим на колёсах Крымом
# 	МИД КНР: Пекин поддержал инициативу России по созданию Большого евразийского партнёрства
# 	Die Welt: Немецкие гаубицы для защиты от России пришлись Литве по душе
# 	В Испании в ходе перестрелки между цыганскими семьями пострадали пять человек
# 	Неизвестный захватил заложников в следственном изоляторе на западе Франции
# 	Детям чиновников предлагают запретить получение образования за рубежом
# 	В Кремле рассказали о главных темах предстоящей встречи Путина и Эрдогана
# 	В Олимпийской деревне в Рио воры обокрали датскую делегацию
# 	Клинт Иствуд: Выбирая между Клинтон и Трампом, я предпочёл бы Трампа
# 	Организаторы Игр в Рио бесплатно раздадут школьникам 240 тыс. билетов
# 	Для решения конфликтов при торговле через интернет в России могут создать онлайн-арбитраж
# 	«Эпоха греха»: Папа Римский раскритиковал пропаганду гендерной свободы среди детей
# 	Виталий Кличко подписал решение о переименовании Московского проспекта в проспект Бандеры
# 	МИД: Россия не будет ввязываться в гонку вооружений, но позаботится о своей безопасности
# 	МИД РФ предупредил о последствиях перехода США на модернизированные ядерные заряды
# 	На 71-м км МКАД горит фура
# 	Страны ЕАЭС начнут маркировать шубы чипами с 12 августа
# 	В Канаде потерявшийся кот вернулся к хозяевам спустя 19 месяцев
# 	Российского яхтсмена Павла Созыкина допустили до Олимпиады
# 	Олег Ляшко обвинил Надежду Савченко в сговоре с российскими властями
# 	Отстранённая от Олимпиады российская пловчиха Устинова подала иск в CAS
# 	В аэропорту Дубая горит самолёт
# 	Учёные обнаружили в центре Млечного Пути пустыню
# 	Атмосферный спутник «Сова» будут использовать для освоения Севера и Сибири
# 	Несмотря ни на что: американские военные заявили, что истребитель F-35А готов к бою
# 	Дарья Клишина ещё не получила разрешения IAAF для выступлений на Олимпиаде
# 	В МИД РФ разъяснили цели гуманитарной операции в Алеппо
# 	В Стамбуле беременную журналистку избили за откровенную одежду
# 	У суда в Киеве произошли столкновения между полицией и членами добровольческих батальонов
# 	Литва раскритиковала выпущенные в России монеты со скульптурами из Вильнюса
# 	Президент Никарагуа объявил свою жену кандидатом в вице-президенты страны
# 	Отечественные GoPro для космонавтов испытают в открытом космосе
# 	Художник «одел» граффити с полуобнажённой Хиллари Клинтон в никаб
# 	Дональд Трамп получил от своего сторонника медаль за боевое ранение
# 	В Неваде разбился американский истребитель-бомбардировщик, пилот госпитализирован
# 	Надежда Савченко снова объявила голодовку
# 	Дмитрий Медведев: У России есть шансы стать самой технологически передовой страной
# 	Названы самые коррумпированные регионы России
# 	Песков: Владимир Путин никогда не разговаривал с Дональдом Трампом
# 	Минздрав РФ: Угрозы распространения сибирской язвы с территории Ямала нет
# 	Создатели «Игры престолов» объявили выборы
# 	Глава ОКР: Российских спортсменов отстраняют от Олимпиады бездоказательно
# 	Томас Бах: МОК может отстранить от Олимпиады ещё нескольких российских спортсменов
# 	СМИ: Сборная США по баскетболу будет проживать в Рио на круизном лайнере
# 	Суд отклонил иск Кувейта на $1 млрд против МОК за отстранение от Олимпиады
# 	Власти: Около 50 жителей покинули оккупированный район Алеппо по гуманитарному коридору
# 	Le Quotidien: Платье с Владимиром Путиным и ангелами символизирует союз арабов с русскими
# 	Генсек ООН примет участие в олимпийской эстафете
# 	В Саудовской Аравии впервые женщина заняла высокий спортивный пост
# 	Теннисистка Светлана Кузнецова пожаловалась на плохие тренировочные условия в Рио
# 	В результате обрушения моста в Индии пропали без вести 22 человека
# 	Смартфоны Samsung обошли по популярности конкурентов из Apple на рынке Северной Америки
# 	Глава WADA: Мы услышали предложение Томаса Баха о пересмотре антидопинговой политики
# 	Деньги назад: в 2017 году в России появится система tax free
# 	Нил Ушаков призвал Латвию готовиться к частичной отмене санкций против России
# 	IPC может решить судьбу российских паралимпийцев в эти выходные
# 	В России обнаружены шокирующие фрагменты дневников Гиммлера
# 	Российские самолёты МС-21 планируют запустить в серийное производство в 2018 году
# 	Дмитрий Песков прокомментировал подготовку США к производству новой ядерной бомбы
# 	СК начал проверку по факту гибели предполагаемого бывшего десантника в Парке Горького
# 	Барак Обама: Дональд Трамп не обладает квалификацией для работы президентом США
# 	Спутники «Глонасс» оснастят водородными атомными часами
# 	Пеле получил предложение зажечь олимпийский огонь
# 	Томас Бах призвал пересмотреть деятельность WADA
# 	Дипломы всех российских студентов могут начать проверять на плагиат
# 	Суд отказал ФСИН в замене Навальному условного срока на реальный
# 	В Крыму развернут батальон ВДВ в 2017 году
# 	Владимир Путин поздравил десантников с днём ВДВ
# 	Виталий Мутко не исключает самых серьёзных мер в связи с ситуацией с тяжёлой атлетикой
# 	СМИ: Леонардо Ди Каприо будет собирать средства на предвыборную кампанию Хиллари Клинтон
# 	«Краснодар» в 1 туре Чемпионата России выиграл у «Томи», «Рубин» и «Амкар» сыграли вничью
# 	ОРКК намерена создать биопринтер для 3D-печати органов на МКС
# 	Власти Китая эвакуировали более 300 тыс. человек из-за тайфуна «Нида»
# 	МИД РФ: Лишняя тысяча военных в Афганистане не поможет США выполнить задачи
# 	Банк России выпустил памятные монеты номиналом в 3 и 25 рублей
# 	Минобороны готово к консультациям с Прибалтикой и Польшей по военной деятельности у границ
# Cluster: 37, count news: 1, titles:
# 	Полиция Армении взяла под контроль продажу оружия в стране
# Cluster: 38, count news: 5, titles:
# 	Источник: Пропавший с радаров рейс Air Algerie приземлился в аэропорту Алжира
# 	Пропавший с радаров рейс Air Algerie вернулся в Алжир из-за неисправности
# 	Пропавший с радаров самолет Air Algerie приземлился в аэропорту Алжира
# 	Самолет Air Algerie пропал с радаров над Средиземным морем
# 	В России испытали первый атмосферный спутник «Сова»
# Cluster: 39, count news: 1, titles:
# 	Бывший мэр Ярославля признан виновным во взяточничестве
# Cluster: 40, count news: 3, titles:
# 	Следователи не нашли "рабов" на лесопилке в Братске
# 	Житель Подмосковья нашел в стройматериалах записку "Нас держат без воды"
# 	Следователи проверяют информацию о рабах на лесопилке под Иркутском
# Cluster: 41, count news: 4, titles:
# 	IAAF объяснила, почему не допустила Исинбаеву к Олимпиаде
# 	Исинбаева призвала россиян выступить в Рио так, чтобы весь мир содрогнулся
# 	Исинбаевой окончательно отказали в участии в Олимпиаде
# 	Исинбаева объяснила, почему расплакалась на встрече с Путиным
# Cluster: 42, count news: 3, titles:
# 	Канцлер Австрии назвал переговоры с Турцией о вступлении в ЕС «дипломатической фикцией»
# 	МИД Австрии призвал Евросоюз "не падать на колени" перед Турцией
# 	Источник: ЕС направит мигрантов в «третьи страны» в случае разрыва соглашения с Турцией
# Cluster: 43, count news: 6, titles:
# 	В Бельгии неизвестный ранил двоих полицейских мачете
# 	Атаковавший полицейских в Бельгии скончался от ранений
# 	В Бельгии неизвестный зарубил мачете сотрудницу полиции прямо у отделения
# 	В Бельгии неизвестный ранил мачете двоих полицейских
# 	Полицейский в Дагестане случайно застрелил мужчину
# 	В США полицейские застрелили мать 5-летнего ребёнка, угрожавшую им оружием
# Cluster: 44, count news: 2, titles:
# 	В Кабуле возле отеля, где могут находиться иностранцы, идет бой
# 	Напавших на отель в Кабуле боевиков ликвидировали
# Cluster: 45, count news: 2, titles:
# 	Источник: Самолёт с отказавшим двигателем успешно приземлился в аэропорту Внуково
# 	В аэропорту Внуково успешно приземлился Boeing с отказавшим двигателем
# Cluster: 46, count news: 5, titles:
# 	Тени прошлого: что надо знать об инфекционных болезнях
# 	Сибирская язва на Ямале: чем грозит первая за 75 лет вспышка болезни
# 	Источник: Две станции метро в Москве проверяют после сообщений об угрозе взрыва
# 	На Ямале из очага сибирской язвы госпитализированы 86 человек, из них 51 — дети
# 	Тени прошлого: что надо знать об инфекционных болезнях
# Cluster: 47, count news: 7, titles:
# 	"Оказалось, что мы не братья": в Турции протестуют против базы НАТО
# 	СМИ: на юге Турции прогремел взрыв, есть пострадавшие
# 	Турецкие силовики заблокировали авиабазу "Инджирлик"
# 	Суд Стамбула арестовал 17 журналистов за связь с проповедником Гюленом
# 	Протестующие сожгли флаг США перед военной базой НАТО в Турции
# 	В Турции закрывают все военные училища
# 	В Пентагоне окружение силовиками базы НАТО в Турции назвали «мирной демонстрацией»
# Cluster: 48, count news: 6, titles:
# 	Китайцы в России: ТОП-10 самых популярных автомобилей
# 	Голубь устроил гонки на скоростной трассе
# 	В Китае бронемашина протаранила автомобиль. ВИДЕО
# 	Пробег длиною в сто лет: самые известные модели автомобилей ЗИЛ
# 	Русские сарафаны и смокинг для женщин: история моды от Ива Сен-Лорана
# 	День в истории: 2 августа
# Cluster: 49, count news: 2, titles:
# 	Источник: тела россиян со сбитого в Сирии Ми-8 находятся в руках "ан-Нусры"
# 	Источник: тела россиян со сбитого в Сирии Ми-8 находятся в руках "ан-Нусры"
# Cluster: 50, count news: 6, titles:
# 	Марокканского боксера арестовали за домогательства к уборщицам в Рио
# 	CAS допустил российскую пловчиху Юлию Ефимову к участию в Олимпиаде
# 	Допуск получен: на Олимпиаду в Рио поедут более 270 российских спортсменов
# 	Всю сборную России по боксу допустили к Олимпиаде в Рио
# 	AIBA допустила до Олимпиады 11 российских боксёров
# 	FINA не подтвердила допуск российских пловцов на Олимпиаду
# Cluster: 51, count news: 3, titles:
# 	В Киеве опровергли слухи о вербовке Савченко Россией
# 	В Киеве опровергли идею о том, что Россия завербовала Савченко
# 	Депутат Рады возложил на Путина вину за грязные подъезды украинских домов
# Cluster: 52, count news: 7, titles:
# 	Депутат Рады обвинила командиров "Торнадо" в изнасилованиях маленьких детей
# 	Поножовщину в Лондоне устроил 19-летний юноша
# 	"ВКонтакте" запустит новый раздел новостей об Олимпиаде
# 	Неизвестный устроил резню в центре Лондона, есть жертвы
# 	Новая реальность для Запада: эксперты RT о том, почему теракты в Европе совершают одиночки
# 	В центре Лондона мужчина напал на прохожих, погибла женщина, есть раненые
# 	Из России с любовью: Эдвард Сноуден прожил в Москве уже три года
# Cluster: 53, count news: 7, titles:
# 	Опубликовано видео, как захватившие здание ППС в Ереване, сдаются властям
# 	Вооруженные захватчики здания полка ППС в Ереване решили сдаться
# 	В Ереване сообщили об освобождении всех находившихся в заложниках медиков
# 	Захватившие здание полка ППС в Ереване открыли огонь, погиб полицейский
# 	СНБ Армении дала вооруженной группе в Ереване полчаса на то, чтобы сдаться
# 	Столкновения полиции с митингующими произошли в ереванском районе Сари Тах
# 	Число пострадавших после разгона демонстрации в Ереване выросло до 60
# Cluster: 54, count news: 3, titles:
# 	На западе Германии вооруженный мужчина захватил кафе
# 	Спецназ провёл рейд после сообщений о захвате заложников в Ньюарке
# 	Спецназ провёл рейд после сообщений о захвате заложников в Ньюарке
# Cluster: 55, count news: 3, titles:
# 	В США прогнозируют крах экономики Украины из-за «Северного потока — 2»
# 	В США предрекли коллапс экономики Украины из-за "Северного потока-2"
# 	Власти Нигерии начали выплачивать боевикам деньги в обмен на прекращение терактов
# Cluster: 56, count news: 3, titles:
# 	Матиос рассказал, сколько на Украине "воров в законе"
# 	В Израиле разрешили приговаривать к тюремному сроку детей младше 14 лет
# 	В Израиле суды будут давать тюремные сроки детям младше 14 лет за тяжкие преступления
# Cluster: 57, count news: 4, titles:
# 	Прокуратура Крыма прокомментировала ситуацию с исполняющим обязанности прокурора
# 	Указом Владимира Путина помилованы двое осуждённых
# 	Глава Росреестра Васильев стал врио губернатора Кировской области
# 	Путин досрочно прекратил полномочия губернатора Севастополя Меняйло
# Cluster: 58, count news: 4, titles:
# 	В Киеве обещали "перевернуть вверх ногами" все аргументы РФ по делу о долге
# 	Москва попросила Лондонский суд ускорить рассмотрение иска по долгу Украины
# 	Дело "акционеров ЮКОСа": победа здравого смысла во Франции и Германии
# 	Суд в Индии подтвердил отзыв экс-акционерами ЮКОСа исков к РФ
# Cluster: 59, count news: 7, titles:
# 	Как мировые лидеры посещали Олимпиады
# 	Режиссёр церемонии открытия Олимпиады: Шоу будет ярким, несмотря на малый бюджет
# 	В Рио-де-Жанейро открылись летние Олимпийские игры
# 	Показательные выступления десантников на международных соревнованиях
# 	Пеле предложили зажечь огонь Олимпийских игр-2016
# 	Сергей Тетюхин официально назначен знаменосцем сборной России на открытии Олимпиады
# 	На форме американских олимпийцев увидели российский триколор
# Cluster: 60, count news: 2, titles:
# 	Паралимпийская чемпионка намерена пойти на эвтаназию после Игр в Рио
# 	Паралимпийская чемпионка из Бельгии намерена совершить эвтаназию после Игр-2016
# Cluster: 61, count news: 13, titles:
# 	Разыгран первый комплект наград на Олимпиаде в Рио
# 	Олимпийские игры в Рио стартуют с "кабинетной" победы России в МОК
# 	Прогноз "Р-Спорт": Россия претендует на 68 медалей Олимпийских игр в Рио
# 	Дзюдоист Мудранов принес России первую золотую медаль на Олимпиаде в Рио
# 	Сборная России после первого дня Олимпиады занимает 6-е место в медальном зачёте
# 	В Рио едва не утонул пресс-атташе Федерации современного пятиборья России
# 	День в истории: 4 августа
# 	Marketwatch объяснил, зачем Россия и Китай скупают золото
# 	«Закрыть глаза на давление и выигрывать»: российские бадминтонисты об играх в Рио
# 	Goldman Sachs предсказал число медалей российской сборной на Играх в Рио
# 	Олимпийский прогноз: сколько медалей смогут завоевать российские атлеты в Рио
# 	Спортивная несправедливость: кого и как лишали олимпийских медалей
# 	Сергей Шойгу поздравил десантников с днём ВДВ
# Cluster: 62, count news: 1, titles:
# 	Брифинг Минобороны РФ по ситуации в Сирии
# Cluster: 63, count news: 2, titles:
# 	В США назвали намерение Асада вернуть контроль над Сирией "фантастикой"
# 	Ребрендинг "Джебхат ан-Нусры": зачем крысы хотят сойти за кроликов?
# Cluster: 64, count news: 3, titles:
# 	Microsoft ответил Apple на замену эмоджи с оружием
# 	Эмоджи-толерантность: Apple борется с насилием и неравенством с помощью смайликов
# 	Apple заменит эмоджи с изображением револьвера на водяной пистолет
# Cluster: 65, count news: 2, titles:
# 	Австрия и Индия изъявили желание участвовать в Армейских международных играх в 2017 году
# 	В Ейске стартовал международный конкурс «Чистое небо-2016»
# Cluster: 66, count news: 7, titles:
# 	В сети появились первые фото и видео с места взрыва машины главы ЛНР
# 	В Луганске взорвана машина главы ЛНР Плотницкого
# 	СМИ сообщили о состоянии главы ЛНР, на которого было совершено покушение
# 	В Подмосковье автомобиль насмерть сбил полуторагодовалую девочку и скрылся
# 	В Луганске подорвали машину главы ЛНР Плотницкого
# 	Очевидцы рассказали подробности покушения на главу ЛНР
# 	В сети появились первые фото и видео с места взрыва машины главы ЛНР
# Cluster: 67, count news: 8, titles:
# 	Пенсионер-грибник выжил, пролежав двое суток в лесу в Хабаровском крае
# 	Рядом с авиабазой в штате Невада разбился истребитель
# 	Два пассажирских самолёта в Индии едва избежали столкновения
# 	Разбившийся в Кузбассе Ан-2 сгорел, выживших нет
# 	В Кузбассе нашли пропавший Ан-2, самолет разбился в горах
# 	Под Пензой при крушении планера погиб летчик-испытатель
# 	Прокуратура выясняет, как родственники в Сибири "похоронили" живую бабушку
# 	На китайскую провинцию обрушится сильнейший тайфун с 1983 года
# Cluster: 68, count news: 8, titles:
# 	На Алтае заработала первая в РФ система контроля космического пространства
# 	В России представят прототип экзоскелета для применения в медицине
# 	Sky News рассказал о контрабанде оружия с Украины в Западную Европу
# 	Будущее наступило: эксперты рассказали об использовании лазерного оружия
# 	Российская армия приняла на вооружение образцы лазерного оружия
# 	В Минобороны рассказали о принятом на вооружение в России лазерном оружии
# 	Физики с помощью закрученного луча лазера хотят в разы ускорить интернет
# 	СМИ: с американской военной базы в Штутгарте украли оружие
# Cluster: 69, count news: 5, titles:
# 	Волейболист Тетюхин внес российский флаг на стадион в Рио на открытии ОИ
# 	Российские волейболистки победили команду Аргентины на старте Олимпиады
# 	Зрители освистали и. о. президента Бразилии Темера во время церемонии открытия игр в Рио
# 	Волейболист Тетюхин внес российский флаг на стадион в Рио на открытии ОИ
# 	В московском Парке Горького утонул бывший десантник
# Cluster: 70, count news: 4, titles:
# 	Антикоррупционное бюро Украины не пускает следователей Генпрокуратуры для обыска
# 	Юрий Луценко обвинил антикоррупционное бюро Украины в незаконной прослушке
# 	Дело о пропавших обысках: как поссорились антикоррупционное бюро Украины и прокуратура
# 	Генпрокурора Украины обвинили в пособничестве взяточничеству
# Cluster: 71, count news: 2, titles:
# 	Мода на спорт: выбери лучшую форму олимпийской сборной
# 	Тетя Валя и дядя Коля: выбери лучшего ведущего "Спокойной ночи, малыши!"
# Cluster: 72, count news: 4, titles:
# 	Главком ВКС РФ: Мы «ломаем хребет» международному терроризму в Сирии
# 	Главком Бондарев: ВКС РФ стали самым мощным видом Вооружённых сил страны
# 	Главком ВКС РФ: Мы «ломаем хребет» международному терроризму в Сирии
# 	Сергей Шойгу поздравил военнослужащих с 320-летием ВМФ
# Cluster: 73, count news: 3, titles:
# 	Умерла актриса Зинаида Шарко
# 	Скончалась актриса Зинаида Шарко
# 	В США умер звезда фильма "Большой Лебовски" Дэвид Хаддлстон
# Cluster: 74, count news: 5, titles:
# 	Источник: Курбан Бердыев намерен покинуть ФК «Ростов»
# 	Сын Фабио Капелло прокомментировал сообщения о том, что тренер может возглавить «Спартак»
# 	Аленичев ушел с поста главного тренера московского "Спартака"
# 	СМИ узнали о двухлетнем контракте «Спартака» с Курбаном Бердыевым
# 	Футболисты киевского «Динамо» будут играть в вышиванках
# Cluster: 75, count news: 4, titles:
# 	Власти Ирана подтвердили казнь физика-ядерщика за шпионаж
# 	СМИ сообщили о казни вернувшегося из США иранского ученого-ядерщика
# 	WSJ: США тайно послали в Иран самолет с $400 млн, чтобы спасти американцев
# 	СМИ: Россия и Иран планируют провести совместные военные учения
# Cluster: 76, count news: 7, titles:
# 	Опубликовано видео пассажиров в Улан-Удэ, несогласных с заменой самолёта на Ан-24
# 	В сети появилось видео "бунта" пассажиров в аэропорту Улан-Удэ
# 	Пассажиры в Улан-Удэ отказались лететь из-за замены самолёта на Ан-24
# 	В аэропорту Улан-Удэ пассажиры устроили "бунт" из-за замены самолета
# 	Пассажиры в Улан-Удэ отказались лететь из-за замены самолёта на Ан-24
# 	Полицейские наказали дебошира, снятого с рейса Южно-Сахалинск - Москва
# 	Авиакомпания «Победа» может организовать платное питание на борту
# Cluster: 77, count news: 3, titles:
# 	Президент МОК объяснил допуск России к Олимпиаде принципом справедливости
# 	Судьбу российских олимпийцев решит особая "тройка" МОК
# 	МОК выдвинул условия, при которых пересмотрит дело российских тяжелоатлетов
# Cluster: 78, count news: 8, titles:
# 	Немецкий политик увидел аналогию в действиях Эрдогана и Гитлера
# 	Доступные тайны: сколько стоят ваши данные в интернете
# 	Переворот в цифрах: во что Турции обошлась попытка свержения Эрдогана
# 	СМИ рассказали, что Юнкер уже 30 лет записывает в блокнот имена предателей
# 	Турецкая газета опубликовала фото Меркель в образе Гитлера
# 	Таиланд стал самым популярным направлением у российских туристов
# 	Эрдоган обвинил главу Центрального командования США в поддержке мятежников
# 	Итальянский ученый рассказал о скрытом смысле "Тайной вечери" Да Винчи
# Cluster: 79, count news: 2, titles:
# 	СБУ обещает "сюрприз" при освобождении пленных в Донбассе
# 	В СБУ пообещали сюрприз при обмене пленными в Донбассе
# Cluster: 80, count news: 2, titles:
# 	Путин рассказал, когда лучше брать ипотеку
# 	Владимир Путин посоветовал россиянам брать ипотеку прямо сейчас
# Cluster: 81, count news: 2, titles:
# 	В Екатеринбурге школьницу выгнали из автобуса, приняв за террористку
# 	Житель Екатеринбурга во время прогулки поймал выпавшую с 8 этажа девочку
# Cluster: 82, count news: 2, titles:
# 	МОК допустил Юлию Ефимову до Олимпийских игр в Рио
# 	Елена Исинбаева может возглавить ВФЛА после Олимпиады
# Cluster: 83, count news: 2, titles:
# 	В Турции выдали ордера на арест 100 сотрудников главного военного госпиталя
# 	В Анкаре прошла акция протеста против визита главы комитета начштабов ВС США
# Cluster: 84, count news: 13, titles:
# 	В Сан-Франциско ветеран Великой Отечественной получил орден Красной Звезды
# 	Дональд Трамп ответил экс-главе ЦРУ на обвинения в «вербовке» Путиным
# 	В Twitter разгромили агитационное видео Клинтон против Трампа и Путина
# 	Экс-директор ЦРУ: Владимир Путин завербовал Дональда Трампа
# 	Трамп назвал экс-главу ЦРУ "пешкой Обамы и Клинтон"
# 	"Заговор против Америки": как в США делают из Трампа "агента России"
# 	Трамп заявил, что Обама стал худшим президентом в истории США
# 	Коэн: на Трампа нападают из-за его желания предотвратить конфронтацию с РФ
# 	Клинтон обвинила российскую разведку во взломе серверов Демпартии
# 	Газета New York Post опубликовала снимки обнаженной жены Трампа
# 	СМИ: следствие подозревает ГРУ в кибератаке на сервера штаба Клинтон
# 	На Западе шуточный призыв Трампа к России сочли госизменой
# 	Кремль: Обвинения Клинтон в причастности РФ к кибератаке на США не имеют конкретики
# Cluster: 85, count news: 4, titles:
# 	Архиепископ Руана предал огласке последние слова убитого террористами священника
# 	Полиция Парижа штурмует церковь с протестующими против сноса здания
# 	В Бельгии беженец ранил ножом священника
# 	Корсика намерена снова требовать независимости, если не будут закрыты мечети на острове
# Cluster: 86, count news: 2, titles:
# 	Евросоюз обеспокоен переговорами по "Турецкому потоку"
# 	Россия и Турция обсуждают строительство двух ниток "Турецкого потока"
# Cluster: 87, count news: 9, titles:
# 	Экс-бухгалтер "Славянки" Ротанова потеряла сознание, услышав приговор суда
# 	Мэр Ярославля Урлашов получил 12 с половиной лет колонии строгого режима
# 	СМИ: Москва готова обменять Ярошенко на осужденных в России американцев
# 	Экс-мэр Ярославля Урлашов получил 12,5 лет строгого режима
# 	Москвичка украла 3,5 млн рублей и потратила их на зоопарк, такси и еду
# 	"Охотники за привидениями" вышли в лидеры кинопроката в РФ за выходные
# 	Прокурор поддержал просьбу ФСИН поместить Навального в колонию
# 	Грабитель, избивший россиянку в США, получил от 17 лет до пожизненного
# 	Суд оправдал всех "приморских партизан"
# Cluster: 88, count news: 2, titles:
# 	С автоматами наперевес: в Бурятии захватили здание лечебницы
# 	МВД сообщило об освобождении захваченной лечебницы в Бурятии
# Cluster: 89, count news: 1, titles:
# 	Дмитрий Песков: Поручения президента по итогам раскопок в Кремле — беспрецедентный процесс
# Cluster: 90, count news: 2, titles:
# 	Варшаву возмутило выражение "польский концлагерь" в издании Ватикана
# 	Варшава возмутилась тем, что Ватикан назвал «польским» концлагерь Освенцим
# Cluster: 91, count news: 5, titles:
# 	«Россия вернулась»: западные СМИ о российском оружии
# 	Американский генерал: Россия за 20 лет сделала рывок в военных технологиях
# 	NI назвал главные российские ракетоносцы ближайших десятилетий
# 	Латвия нашла у своих берегов российскую подлодку
# 	Путин посетил крейсер "Аврора"
# Cluster: 92, count news: 11, titles:
# 	NY Times: Успех русских в Сирии вынуждает Вашингтон прислушиваться к Москве
# 	Алеппо: многострадальная жемчужина Леванта
# 	Тактика торговли телами убитых не поможет боевикам в Алеппо
# 	Израильские СМИ сообщили о залетевшем из Сирии российском беспилотнике
# 	Обама заранее обвинил Россию в возможном срыве перемирия в Сирии
# 	Российский дипломат заявил о гибели десятков мирных сирийцев от ударов США
# 	Каннингем: США разыгрывают спектакль, пока Россия борется с терроризмом
# 	Турция потребовала немедленно прекратить атаки на сирийский Алеппо
# 	Сирийское ополчение сообщает, что боевики в Алеппо складывают оружие
# 	Генштаб: Террористы казнили в Алеппо четырёх человек, пытавшихся выйти через гумкоридоры
# 	Россия, в отличие от коалиции США, не назначает цели для авиаударов в городской черте САР
# Cluster: 93, count news: 5, titles:
# 	В районе Мариуполя зафиксировано землетрясение магнитудой 4,9
# 	В районе Мариуполя произошло землетрясение
# 	В сети появилось видео, зафиксировавшее момент землетрясения на Украине
# 	В России запущен самый мощный в стране блок атомной станции
# 	Землетрясение магнитудой 6,0 произошло в Аргентине
# Cluster: 94, count news: 8, titles:
# 	CAS отменил правило МОК о двойном наказании за допинг
# 	Запрет на публикацию GIF-файлов с олимпийским контентом удивил пользователей соцсетей
# 	На сайте Олимпиады опубликован состав сборной России
# 	Бах: МОК принял тяжелое решение по отстранению Степановой
# 	В МОК заявили о необходимости создания другой организации вместо WADA
# 	Глава МОК рассказал о тройном фильтре для допуска россиян на Олимпиаду
# 	Глава МОК назвал условие для участия сборной России в Олимпиаде
# 	Чрезвычайная комиссия: МОК внезапно усложнил допуск россиян на Олимпиаду
# Cluster: 95, count news: 6, titles:
# 	Посол Турции назвал Россию определяющим игроком в сирийском урегулировании
# 	В Турции рассказали, чего ждут от предстоящей встречи Путина и Эрдогана
# 	Эрдоган рассказал, почему написал Путину письмо
# 	Эрдоган рассказал, о чем хотел бы поговорить на встрече с Путиным в августе
# 	Эрдоган назвал темы, которые хотел бы обсудить на встрече с Путиным
# 	Вилли Виммер: российский Су-24 над Сирией сбили при участии самолетов НАТО
# Cluster: 96, count news: 2, titles:
# 	Российских футболистов сняли с детского турнира в Норвегии из-за драки
# 	Тренер россиян рассказал, из-за чего на турнире Norway Cup началась драка
# Cluster: 97, count news: 3, titles:
# 	Рэп-баттлы и юный Ленин: новые технологии в кампаниях российских политиков
# 	Миронов проведет предвыборные рэп-дебаты под псевдонимом OxxxyMironov
# 	Битва OxxxyМиронова: лидеры российских политических партий проведут рэп-дебаты
# Cluster: 98, count news: 7, titles:
# 	Лондон проиграл Нью-Йорку и Гонконгу в рейтинге самых дорогих городов мира
# 	Психологи рассказали о плюсах холостяцкой жизни
# 	Третий раунд противостояния с Западом: начинается новый год продэмбарго
# 	Евросоюз ввел антидемпинговые пошлины для российских металлургов
# 	Минфин США предупредил о росте госдолга на 383 миллиарда долларов
# 	Сенатор Бокова предложила способ защиты страны от киберугроз извне
# 	В АТОР рассказали, сколько денег потеряла Турция на российских туристах
# Cluster: 99, count news: 5, titles:
# 	В Британии арестованы ещё девять активистов Black Lives Matter
# 	Передайте за проезд: в Сибири и на Урале появятся платные дороги
# 	СМИ: До 2030 года в России появится более 20 тыс. км новых автомагистралей
# 	В Саратовской области планируют открыть производство фуа-гра
# 	На высоте: в Крыму начали сооружать судоходную часть моста через Керченский пролив
# Cluster: 100, count news: 3, titles:
# 	Умер Фазиль Искандер
# 	Фазиль Искандер похоронен на Новодевичьем кладбище в Москве
# 	В столице Абхазии установят памятник Фазилю Искандеру
# Cluster: 101, count news: 3, titles:
# 	Археологи нашли древнейшую в Москве надпись
# 	Хорошо забытое старое: Кремль возвращает свой исторический облик
# 	Хорошо забытое старое: Кремль возвращает свой исторический облик
# Cluster: 102, count news: 4, titles:
# 	Дмитрий Медведев выступил на форуме «Территория смыслов на Клязьме»
# 	Дмитрий Медведев выступил на форуме «Территория смыслов на Клязьме»
# 	Пресс-конференция Тьерри Мариани и Леонида Слуцкого — прямая трансляция
# 	Французская делегация дала пресс-конференцию в Севастополе
# Cluster: 103, count news: 3, titles:
# 	Источник: Под Нижним Новгородом горит склад ракетно-артиллерийского вооружения
# 	В Нижегородской области загорелся склад артиллерийского вооружения
# 	Пожар произошёл в строящемся корпусе Морозовской детской больницы в Москве
# Cluster: 104, count news: 6, titles:
# 	ИГ через Telegram призвало боевиков атаковать авиабазы США на Ближнем Востоке
# 	Госдеп отказался отвечать на вопрос RT о поддержке боевиков, совершивших химатаку в Сирии
# 	Москвичка получила 5 лет за экстремизм в соцсетях и попытку сбежать в ИГ
# 	Родившиеся в ЕС, выросшие в ИГ: боевики готовят новое поколение террористов
# 	Россия открывает горячую линию по вопросам помощи жителям Алеппо
# 	«Раньше мы жили как в тюрьме»: жители Алеппо об условиях до гуманитарной операции
# Cluster: 105, count news: 2, titles:
# 	Игры будущего: какие виды спорта могут стать олимпийскими
# 	В программу игр-2020 в Токио включили пять новых видов спорта
# Cluster: 106, count news: 4, titles:
# 	МИД РФ подтвердил запрос об обмене лётчика Константина Ярошенко на американских граждан
# 	Порошенко предложили признать МВФ террористической организацией
# 	Foreign Policy: Самым главным врагом Украины могут оказаться её собственные лидеры
# 	Посол на Украине: "мягкую силу" меняют на "принуждение к миру"
# Cluster: 107, count news: 4, titles:
# 	МОК допустил возможность визита Елены Исинбаевой на Олимпиаду
# 	Исинбаева рассказала, почему ее не допустили к Олимпиаде в Рио
# 	Исинбаева: Меня не допустили до игр в Рио, потому что я живу и тренируюсь в России
# 	Прыгунья Дарья Клишина выступит на Олимпиаде без разрешения комиссии МОК
# Cluster: 108, count news: 2, titles:
# 	В Кремле ответили на обвинения Обамы в адрес России по ситуации в Сирии
# 	В Госдуме ответили на обвинения Обамы в адрес России
# Cluster: 109, count news: 7, titles:
# 	Активисты оспорят в суде планы переноса советских памятников в Польше
# 	МИД Польши отреагировал на проект резолюции Верховной рады о «геноциде украинцев»
# ...
# 	В ДНР заявили о возможном возобновлении военных действий в Донбассе
# 	Постпред Украины при ООН заявил, что в Донбассе воюют 15-летние подростки
# 	В Киеве запустили прямую линию для доносов на жителей Донбасса
# Cluster: 138, count news: 2, titles:
# 	Игра на понижение: что стоит за отказом Киева принять нового посла России
# 	Игра на понижение: что стоит за отказом Киева принять нового посла России
# Cluster: 139, count news: 4, titles:
# 	Ъ: в России создадут мессенджер для госорганов
# 	СМИ: в России нет оборудования, необходимого для исполнения "пакета Яровой"
# 	Иранские хакеры взломали Telegram и получили доступ к номерам 15 млн пользователей
# 	Огласите весь список: зачем россиян внесут в единый реестр
# Cluster: 140, count news: 3, titles:
# 	Мутко рассказал про правильную и неправильную антидопинговую политику
# 	ФСБ сообщила о масштабной кибератаке на российские организации
# 	WADA удалило письмо Родченкова из отчета Макларена
# Cluster: 141, count news: 1, titles:
# 	Генетики выяснили, как подсолнух поворачивается к Солнцу
# Cluster: 142, count news: 8, titles:
# 	Афганец выдал замуж свою шестилетнюю дочь в обмен на козла и еду
# 	Константин Игропуло рассказал RT, как спас ребёнка в Сочи
# 	Российский гандболист спас девочку, упавшую с шестиметровой высоты
# 	Российский гандболист в Сочи спас девочку, сорвавшуюся с 6-метровой высоты
# 	Екатеринбуржец рассказал подробности спасения выпавшей из окна девочки
# 	Екатеринбуржец, спасший выпавшую из окна девочку, отказался от награды
# 	Под Уфой пьяный сторож изнасиловал двух маленьких девочек
# 	Эксперты признали няню-убийцу Бобокулову невменяемой
# Cluster: 143, count news: 2, titles:
# 	Трамп и Крым
# 	Трамп и Крым
# Cluster: 144, count news: 3, titles:
# 	Социологи выяснили, как ведут себя россияне во время семейных ссор
# 	Беженцы устроили массовую драку в центре регистрации в Германии. ВИДЕО
# 	В сети появилось видео массовой драки в центре регистрации беженцев в Германии
# Cluster: 145, count news: 2, titles:
# 	«Массандра» получила право на защищённое географическое указание «Крым»
# 	СМИ: В России могут появиться новые винодельческие регионы
# Cluster: 146, count news: 3, titles:
# 	В Бельгии нарушителям иммиграционного законодательства грозит штраф в €200
# 	СМИ: Граждане Украины и Ирака чаще всего обращаются с просьбой об убежище в Чехии
# 	Президент Чехии выступил против расселения в стране беженцев
# Cluster: 147, count news: 5, titles:
# 	ЦБ отозвал лицензии у двух банков
# 	"Бархатный сезон": в России впервые за пять лет зафиксировали дефляцию
# 	Пробила дно: экономисты ВШЭ рассказали о фронтальной рецессии в России
# 	Центробанк сохранил ключевую ставку на уровне 10,5% годовых
# 	Символы для новых купюр: Центробанк определил 49 городов-претендентов
# Cluster: 148, count news: 3, titles:
# 	Чуркин остался впечатлен встречей с Трампом 30-летней давности
# 	Трамп надеется, что Путин его зауважает
# 	Трамп заявил, что в случае избрания рассмотрит вопрос признания Крыма
# Cluster: 149, count news: 2, titles:
# 	Драгоценности раздора: артефакты, которые бывшие владельцы требуют вернуть
# 	Ученые выяснили, что породило "голоса в голове" у Жанны д'Арк
# Cluster: 150, count news: 1, titles:
# 	В бразильский штат ввели войска из-за роста преступности перед Олимпиадой
# Cluster: 151, count news: 1, titles:
# 	За рулём «Формулы-1»: Берни Экклстоун рассказал RT, как надо руководить гонками
# Cluster: 152, count news: 3, titles:
# 	Раритетная копия комикса о Супермене продана за $1 млн
# 	Магаданский губернатор предложил в придачу к дальневосточному и колымские гектары
# 	Трутнев поручил разработать процедуру приёма заявок от детей на «дальневосточный гектар»
# Cluster: 153, count news: 6, titles:
# 	В Домодедово досрочно приземлился самолёт из-за больного ребёнка на борту
# 	Пассажиры загоревшегося самолета в Дубае перед эвакуацией забирали багаж
# 	На кадрах с экстренной посадкой лайнера в Дубае виден взрыв
# 	Причиной ЧП в аэропорту Дубая стала неудачная посадка самолета Emirates
# 	Самолёт взорвался в аэропорту Дубая
# 	Один человек погиб при тушении самолета в аэропорту Дубая
# Cluster: 154, count news: 1, titles:
# 	Директор компании в Татарстане объявил о вакансии охотника за покемонами
# Cluster: 155, count news: 10, titles:
# 	Бельгийских врачей обучат борьбе с алкозависимостью
# 	В Турции после мятежа аннулированы более 74 тыс. паспортов
# 	Турецкая журналистка приняла чит-коды для компьютерной игры за шифр мятежников
# 	Около 60 тыс. человек отстранены от работы в Турции после попытки госпереворота
# 	Эрдоган: Запад оказывает поддержку терроризму и стоит на стороне переворотов
# 	В давке на фестивале пива в Косово пострадали более 40 человек
# 	Эрдоган: те, кого волнует судьба мятежников, не могут быть друзьями Анкары
# 	СМИ: Анкара перехватила переписку сторонников Гюлена задолго до путча
# 	В Турции арестованы ещё шестеро журналистов по делу о попытке госпереворота
# 	В Турции задержаны мятежники, атаковавшие отель Эрдогана во время переворота
# Cluster: 156, count news: 2, titles:
# 	Астрономы вычислили, когда Земля лишится второй Луны
# 	Начался самый яркий звездопад года
# Cluster: 157, count news: 3, titles:
# 	Дмитрий Рогозин: «Алмаз-Антей» разработал новые зенитные ракеты
# 	"Алмаз-Антей" разработал зенитные ракеты нового поколения
# 	Рогозин заявил, что подлодки "Борей" могут прорвать любую систему ПРО
# Cluster: 158, count news: 2, titles:
# 	Источники назвали возможного кандидата на должность посла России на Украине
# 	Путин отправил в отставку посла России на Украине Зурабова
# Cluster: 159, count news: 3, titles:
# 	Облава на «Розовую пантеру»: в Испании задержаны международные похитители драгоценностей
# 	В Британии в купленном за пять фунтов старинном стуле нашли драгоценности
# 	Достопримечательности Петергофа воссоздали из золота и драгоценных камней
# Cluster: 160, count news: 4, titles:
# 	Марс на прослушке: в 2021 году люди услышат звуки Красной планеты
# 	Марс на прослушке: в 2021 году люди услышат звуки Красной планеты
# 	Власти США разрешили частной компании отправить экспедицию на Луну
# 	Китайский луноход завершил работу на Луне
# Cluster: 161, count news: 2, titles:
# 	Шахтёры продолжают голодовку в украинском Минэнерго из-за долгов по зарплате
# 	Киев обвинил Москву в отказе помочь в период летней пиковой жары
# Cluster: 162, count news: 2, titles:
# 	Владимир Путин: Россия не будет навязывать рецепты по решению карабахского конфликта
# 	Владимир Путин: Нельзя использовать террористические группировки в политических интересах
# Cluster: 163, count news: 3, titles:
# 	ФИФА подтвердила, что начала расследование в отношении 11 российских футболистов
# 	Газзаев пообещал российскому футболу перемены
# 	Валерий Газзаев выдвинут на пост президента РФС
# Cluster: 164, count news: 4, titles:
# 	Ассанж в эксклюзивном интервью RT — о «русском следе» во взломе серверов Демпартии США
# 	Источники: Исполнительный директор национального комитета Демпартии США ушла в отставку
# 	Власти США расследуют третий случай атаки хакеров на Демократическую партию
# 	Джулиан Ассанж анонсировал новые отставки у демократов в связи с публикацией WikiLeaks
# Cluster: 165, count news: 2, titles:
# 	Спортивный врач: Обвинения в адрес российских атлетов не выдерживают критики
# 	Российские ватерполистки в интервью RT: Нас проверяют на допинг каждое утро
# Cluster: 166, count news: 4, titles:
# 	МИД Австрии вызвал для разъяснений турецкого посла
# 	Главы МИД Турции и Австрии поспорили в Twitter
# 	Швейцария отказалась вступать в Евросоюз
# 	Власти Турции настаивают на введении безвизового режима с ЕС в октябре
# Cluster: 167, count news: 2, titles:
# 	Организатора концерта группы "Ленинград" оштрафовали за мат со сцены
# 	Организатора концерта группы «Ленинград» в Новосибирске оштрафовали за мат
# Cluster: 168, count news: 1, titles:
# 	Стало известно, когда продемонстрируют российского боевого робота «Нерехта-2»
# Cluster: 169, count news: 9, titles:
# 	Звезды по осени считают: в Крыму ждут обвала цен на отели
# 	Поклонская села за руль комбайна и раскритиковала ситуацию в Северном Крыму
# 	Правительство изменило правила финансирования экстренной помощи туристам
# 	В России зафиксирована недельная дефляция
# 	Кит проплыл под лодкой с туристами
# 	Отдых в Крыму
# 	СМИ выяснили, когда закончится телесериал "Игра престолов"
# 	Google вернул на свою карту реальные названия населенных пунктов Крыма
# 	NYT: "феномен войны" обрушил турбизнес Европы
# Cluster: 170, count news: 5, titles:
# 	Сирийская группировка назвала условия выдачи тел россиян со сбитого Ми-8
# 	Атака на Ми-8 в Сирии: по предварительным данным, все военные погибли
# 	Генштаб: Вертолёт ВКС РФ был сбит в Сирии над районом, подконтрольным «Фронту ан-Нусра»
# 	Дмитрий Песков: Все находившиеся на борту сбитого в Сирии российского вертолёта погибли
# 	Минобороны: В ходе гуманитарной операции в Сирии сбит вертолёт ВКС РФ
# Cluster: 171, count news: 5, titles:
# 	Минобрнауки обещает сделать все, чтобы рабочих мест для ученых стало больше
# 	Минобрнауки опровергло информацию о сокращении ученых и научных сотрудников
# 	Дмитрий Ливанов: Сделаем всё, чтобы число рабочих мест для учёных в РФ не сокращалось
# 	McDonald’s откажется от искусственных консервантов в борьбе за клиентов
# 	СМИ: В российских вузах пройдут массовые сокращения
# Cluster: 172, count news: 3, titles:
# 	Валерий Спиридонов создает первый в мире автопилот для инвалидных кресел
# 	Валерий Спиридонов рассказал об автопилоте для инвалидных кресел
# 	В России разработали приложение, позволяющее обработать видео в стиле известных картин
# Cluster: 173, count news: 3, titles:
# 	В Таджикистане убили российского военнослужащего
# 	Крупнейшая кража криптовалюты: хакеры похитили биткоины на $60 млн
# 	Французский заключённый лишился прав из-за того, что полицейские ездили на его машине
# Cluster: 174, count news: 6, titles:
# 	Дзюдоист Мудранов рассказал, чем отличается от Кокорина и Мамаева
# 	В первый день ОИ россияне поборются за медали в пяти видах спорта
# 	Россияне в воскресенье претендуют на медали в шести видах спорта
# 	В первый день ОИ россияне поборются за медали в пяти видах спорта
# 	Утверждены выходные и праздничные дни на 2017 год
# 	Впервые на аренах: что нового увидят зрители на Олимпиаде в Рио
# Cluster: 175, count news: 3, titles:
# 	Минобороны Израиля продемонстрировало новейший бронетранспортёр
# 	NI рассказал, сможет ли американский ракетный комплекс TOW уничтожить Т-14
# 	NI: российские "Терминаторы" станут танками новой эры
# Cluster: 176, count news: 4, titles:
# 	СМИ: ЕСПЧ дал ход жалобе против украинских властей из-за крушения Boeing
# 	На Украине обвинили российские спецслужбы в убийстве Шеремета
# 	В МВД Украины обвинили российские спецслужбы в убийстве Павла Шеремета
# 	Украинский сайт «Миротворец» зарегистрировали как СМИ
# Cluster: 177, count news: 1, titles:
# 	СМИ: В Турции могут появиться две новые провинции
# Cluster: 178, count news: 2, titles:
# 	Дзюдоист Беслан Мудранов принёс России первое золото на Олимпиаде в Рио
# 	Мудранов заявил, что не исполнял гимн на награждении, так как не умеет петь
# Cluster: 179, count news: 4, titles:
# 	Биологи раскрыли главный секрет существования ДНК
# 	Растительные белки продлевают жизнь, выяснили ученые
# 	Космонавты приготовят кефир на борту МКС
# 	Ученые выяснили, почему зарядка продлевает жизнь
# Cluster: 180, count news: 2, titles:
# 	Росгвардия отказалась помогать выселять должников
# 	Росгвардия сможет помогать приставам в выселении должников и сносе зданий
# Cluster: 181, count news: 4, titles:
# 	В канцелярии президента Польши заявили, что не опасаются России
# 	Польша отказалась возобновлять приграничный режим с Россией
# 	Власти регионов Польши ожидают возобновления местного безвизового режима с Россией
# 	Россия и Польша будут вместе разводить зубров в Калининградской области
# Cluster: 182, count news: 1, titles:
# 	Уроки «объективности» от The Times: британская газета снова критикует RT за предвзятость
# Cluster: 183, count news: 2, titles:
# 	В Кремле прокомментировали сообщения СМИ об отставке правительства
# 	Песков о возможной отставке правительства: С завидным постоянством гадают на кофейной гуще
# Cluster: 184, count news: 3, titles:
# 	Ученые нашли следы легендарного "великого потопа" в Китае
# 	В Приамурье обследовали более 30 км берега реки, где течением унесло детей
# 	Последние мамонты Земли вымерли от жажды, заявляют палеонтологи
# Cluster: 185, count news: 2, titles:
# 	Археологи обнаружили древнее захоронение в Ивановской области
# 	Археологи обнаружили руины замка, который мог принадлежать королю Артуру
# Cluster: 186, count news: 5, titles:
# 	Возобновлено движение через границу Украины с Крымом
# 	Телеканал NBC во время трансляции открытия Олимпиады "вернул" Крым Украине
# 	Украина приостановила пропуск людей и машин в Крым на трех КПП
# 	В Крыму заявили, что международная блокада полуострова прорвана
# 	Постпредство Украины: Россия заблокировала заявление Киева в Совбезе ООН
# Cluster: 187, count news: 10, titles:
# 	NY Times: в США многие годы принимали допинг, но на это закрывали глаза
# 	Томас Бах: МОК послал спортсменам РФ сигнал, что успеха добьются только чистые
# 	МОК допустил до Олимпиады всю сборную России по конному спорту
# 	Александр Жуков: МОК допустил к Олимпиаде около 270 российских спортсменов
# 	Томас Бах: Могу посмотреть в глаза всем российским спортсменам, моя совесть чиста
# 	Томас Бах: Могу посмотреть в глаза всем российским спортсменам, моя совесть чиста
# 	СМИ уличили WADA в бездоказательности обвинений российских спортсменов
# 	Всемирное антидопинговое вранье
# 	Пловчиха Ефимова расплакалась, когда узнала, что CAS допустил ее до ОИ
# 	WADA обещает назвать новые имена "грязных" российских спортсменов
# Cluster: 188, count news: 3, titles:
# 	Британский пловец побил мировой рекорд на Олимпиаде в Рио
# 	Российский курсант стал лучшим на конкурсе снайперов
# 	Российский стрелок выиграл на международном конкурсе снайперов
# Cluster: 189, count news: 3, titles:
# 	В Самаре загорелся магазин, 15 человек эвакуированы
# 	Посиневшая река Каменка озадачила москвичей
# 	Московская река Каменка окрасилась в ярко-синий цвет
# Cluster: 190, count news: 3, titles:
# 	Достопримечательности, которые должен увидеть уважающий себя турист
# 	Хоть раз в жизни: Красная площадь вошла в топ-30 мест Европы, которые следует увидеть
# 	Кремль вошел в топ-30 мест Европы, которые нужно увидеть хоть раз в жизни
# Cluster: 191, count news: 4, titles:
# 	Кадыров назвал ролик ИГ "пустышкой, за которой нет никаких реальных сил"
# 	Боевикам "прижали хвост": в Кремле ответили на угрозы ИГ
# 	Боевики ИГ опубликовали видео с угрозами в адрес России
# 	Козлят прокатили на Lamborghini
# Cluster: 192, count news: 1, titles:
# 	В оргкомитет ОИ-2016 подтвердили уничтожение подозрительного объекта рядом с велотрассой
# Cluster: 193, count news: 1, titles:
# 	Виталий Чуркин: Назначение генсеком ООН кандидата из восточной Европы — приоритет для РФ
# Cluster: 194, count news: 2, titles:
# 	Дмитрий Овсянников заявил о готовности к прямым выборам губернатора Севастополя
# 	Врио губернатора Севастополя Овсянников отправил правительство города в отставку
# Cluster: 195, count news: 2, titles:
# 	Макфол: многие американцы будут в шоке от киберпотенциала русских
# 	Майкл Макфол: У России огромные возможности в области киберразведки
# Cluster: 196, count news: 3, titles:
# 	Список допущенных к Олимпиаде российских спортсменов
# 	МОК допустил к Олимпиаде 29 российских пловцов
# 	Сборная России по прыжкам в воду допущена к Олимпиаде в полном составе
# Cluster: 197, count news: 2, titles:
# 	В Египте уничтожили главаря группировки, подозреваемой во взрыве на А321
# 	В Египте ликвидирован лидер группировки «Ансар Бейт аль-Макдис», причастной к взрыву А321
# Cluster: 198, count news: 3, titles:
# 	Ринго Старр рассказал, почему он является сторонником брексита
# 	В Британии разгорелся скандал вокруг наградного списка Кэмерона
# 	Лидер «Лиги Севера»: Большинство итальянцев поддержат выход страны из ЕС
# Cluster: 199, count news: 5, titles:
# 	Комиссия Паунда не нашла вмешательства властей России в легкую атлетику
# 	Глава WADA: Я с радостью узнал о создании комиссии ОКР по борьбе с допингом
# 	Автор фильма о допинге в РФ пытался спровоцировать на скандал почётного президента ОКР
# 	Глава WADA: Российские власти непричастны к допинговому скандалу в лёгкой атлетике
# 	Глава антидопинговой комиссии: недопуск на ОИ произошел по нашей вине

# %% [markdown]
# # Сохранение в файл

# %%
import datetime

file_path = '/data/kasandra/results/tfidf_kmeans_%s' % datetime.datetime.now().timestamp()

with open(file_path, mode="w+", encoding="utf8") as file:
    file.write(jsonData)
    
file_path
