# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .getOrCreate()

# %%
df = spark.read.json("/data/kasandra/year/lenta.rbc.kp.vesti.2016.normalized.json")
# Displays the content of the DataFrame to stdout
df.show()
# Out:
# +--------------------+-------------+--------------------+--------+--------------------+--------------------+
# |             content|         date|                  id|siteType|               title|                 url|
# +--------------------+-------------+--------------------+--------+--------------------+--------------------+
# |россия январь год...|1451599745000|efe5ae9b-adf2-423...|   LENTA|Россия приостанов...|http://lenta.ru/n...|
# |закон процентный ...|1451615366000|b3a86565-e170-4bb...|   LENTA|Водители получили...|http://lenta.ru/n...|
# |новый год детство...|1451620832000|7bad0e83-15b9-438...|      KP|Уфимка нашла себе...|http://www.kp.ru/...|
# |ой весело гулятьс...|1451622906000|6e3a050a-aec8-4e1...|      KP|10 простых шагов,...|http://www.kp.ru/...|
# |шерлок холмс режи...|1451625008000|3a1c2ef3-0af2-42c...|      KP|Фильмы на праздни...|http://www.kp.ru/...|
# |россия ночь прово...|1451626508000|b7db806a-2584-403...|      KP|Самое главное за ...|http://www.kp.ru/...|
# |последний императ...|1451628316000|8762838c-598e-417...|   VESTI|"Император" верну...|http://www.vesti....|
# |россия увеличиват...|1451633401000|b708345b-c159-47d...|   VESTI|С 1 января минима...|http://www.vesti....|
# |новый год станови...|1451633707000|7f250d93-d9fb-4e5...|      KP|20 самых ярких фо...|http://www.kp.ru/...|
# |вступать сила пос...|1451633935000|dbaa5e08-481b-4b7...|   LENTA|В России с 1 янва...|http://lenta.ru/n...|
# |год доходить сша ...|1451634236000|4a85aac3-55f0-4e1...|   VESTI|Между ликованием ...|http://www.vesti....|
# |хороший представи...|1451634887000|250ea132-fc0e-4d7...|   VESTI|Кубинские пионеры...|http://www.vesti....|
# |каникулы вовсе об...|1451635045000|b9d68ece-d07f-460...|      KP|10 вещей, которые...|http://www.kp.ru/...|
# |новогодний торжес...|1451635815000|a0a30b99-6621-44d...|   VESTI|Новый год в Париж...|http://www.vesti....|
# |глава мчс владими...|1451637787000|ec706ba0-f7b9-405...|   VESTI|Глава МЧС отметил...|http://www.vesti....|
# |январь год исполн...|1451638606000|6a1b5b0c-666f-4b6...|   VESTI|Главному символу ...|http://www.vesti....|
# |новый год приноси...|1451638850000|943c654d-29da-449...|   LENTA|     Грядут перемены|http://lenta.ru/a...|
# |франция награждат...|1451639947000|10b817f6-2585-465...|   VESTI|Во Франции ордено...|http://www.vesti....|
# |канск новогодний ...|1451640151000|53ef3647-5228-455...|      KP|В Красноярском кр...|http://www.kp.ru/...|
# |около человек эва...|1451640460000|2fb56294-0413-428...|   VESTI|50 петербуржцев э...|http://www.vesti....|
# +--------------------+-------------+--------------------+--------+--------------------+--------------------+
# only showing top 20 rows

# %%
content = df.rdd.map(lambda x: x.content.split())
content.take(5)
# Out:
# [['россия',
#   'январь',
#   'год',
#   'вступать',
#   'сила',
#   'постановление',
#   'правительство',
#   'приостановка',
#   'безвизовый',
#   'режим',
#   'турция',
#   'прямо',
#   'связанный',
#   'безопасность',
#   'рф',
#   'гражданин',
#   'турция',
#   'налаживать',
#   'трафик',
#   'боевик',
#   'различный',
#   'направление',
#   'заявлять',
#   'глава',
#   'мид',
#   'россия',
#   'сергей',
#   'лавров',
#   'анкара',
#   'начало',
#   'декабрь',
#   'прошлый',
#   'год',
#   'заявлять',
#   'собираться',
#   'вводить',
#   'виза',
#   'россиянин',
#   'качество',
#   'ответный',
#   'мера',
#   'решение',
#   'москва',
#   'диппредставительство',
#   'турция',
#   'россия',
#   'указывать',
#   'считать',
#   'российский',
#   'народ',
#   'дружественный',
#   'желать',
#   'продолжение',
#   'добрый',
#   'отношение',
#   'материал',
#   'тема',
#   'ноябрь',
#   'уязвлять',
#   'турция',
#   'именно',
#   'российский',
#   'политик',
#   'предлагать',
#   'наказывать',
#   'анкара',
#   'отношение',
#   'москва',
#   'анкара',
#   'ухудшаться',
#   'турецкий',
#   'ввс',
#   'сбивать',
#   'бомбардировщик',
#   'су',
#   'российский',
#   'авиагруппа',
#   'сирия',
#   'россия',
#   'вводить',
#   'ряд',
#   'санкция',
#   'против',
#   'турция',
#   'экономический',
#   'гуманитарный',
#   'сфера',
#   'безвизовый',
#   'режим',
#   'турция',
#   'россия',
#   'действовать',
#   'год',
#   'соглашение',
#   'подписывать',
#   'год',
#   'первоначально',
#   'речь',
#   'идти',
#   'поездка',
#   'продолжительность',
#   'день',
#   'затем',
#   'срок',
#   'пребывание',
#   'турция',
#   'россиянин',
#   'наличие',
#   'загранпаспорт',
#   'виза',
#   'увеличиваться',
#   'день',
#   'турок',
#   'порядок',
#   'оставаться',
#   'прежний'],
#  ['закон',
#   'процентный',
#   'скидка',
#   'штраф',
#   'нарушение',
#   'пдд',
#   'вступать',
#   'сила',
#   'россия',
#   'январь',
#   'год',
#   'принимать',
#   'госдума',
#   'год',
#   'сообщать',
#   'коммерсант',
#   'январь',
#   'госавтоинспекция',
#   'передавать',
#   'государственный',
#   'информационный',
#   'система',
#   'государственный',
#   'муниципальный',
#   'платеж',
#   'гис',
#   'ГМП',
#   'информация',
#   'начисление',
#   'половинный',
#   'сумма',
#   'штраф',
#   'означать',
#   'пользователь',
#   'процесс',
#   'уплата',
#   'изменяться',
#   'водитель',
#   'потребоваться',
#   'вводить',
#   'номер',
#   'постановление',
#   'номер',
#   'право',
#   'свидетельство',
#   'регистрация',
#   'банк',
#   'автоматически',
#   'выставлять',
#   'счет',
#   'скидка',
#   'оплата',
#   'производиться',
#   'течение',
#   'день',
#   'правонарушение',
#   'материал',
#   'тема',
#   'июнь',
#   'штраф',
#   'скидка',
#   'госдума',
#   'рассматривать',
#   'законопроект',
#   'процентный',
#   'скидка',
#   'штраф',
#   'нарушитель',
#   'пдд',
#   'льгота',
#   'смочь',
#   'воспользоваться',
#   'нарушитель',
#   'управляющий',
#   'машина',
#   'нетрезвый',
#   'вид',
#   'виновник',
#   'дтп',
#   'пострадавший',
#   'водитель',
#   'год',
#   'превышать',
#   'скорость',
#   'проезжать',
#   'красный',
#   'свет',
#   'льготный',
#   'период',
#   'действовать',
#   'течение',
#   'сутки',
#   'день',
#   'вынесение',
#   'постановление',
#   'день',
#   'система',
#   'появляться',
#   'новый',
#   'данные',
#   'уплата',
#   'процентный',
#   'сумма',
#   'штраф',
#   'гибдд',
#   'отмечать',
#   'важно',
#   'банк',
#   'указывать',
#   'корректный',
#   'время',
#   'обработка',
#   'платеж',
#   'например',
#   'водитель',
#   'заплатить',
#   'полштраф',
#   'терминал',
#   'поздно',
#   'вечер',
#   'последний',
#   'день',
#   'льготный',
#   'период',
#   'банк',
#   'передавать',
#   'информация',
#   'гис',
#   'ГМП',
#   'утро',
#   'гибдд',
#   'счесть',
#   'скидка',
#   'заканчиваться',
#   'штраф',
#   'уплачивать',
#   'законопроект',
#   'скидка',
#   'своевременный',
#   'оплата',
#   'штраф',
#   'вносить',
#   'госдума',
#   'март',
#   'год',
#   'автор',
#   'становиться',
#   'зампред',
#   'думский',
#   'комитет',
#   'конституционный',
#   'законодательство',
#   'единоросс',
#   'вячеслав',
#   'лысак'],
#  ['новый',
#   'год',
#   'детство',
#   'любимый',
#   'праздник',
#   'говорить',
#   'уфимка',
#   'нафис',
#   'аблкарамов',
#   'загадывать',
#   'муж',
#   'бой',
#   'куранты',
#   'муж',
#   'загадывать',
#   'минута',
#   'мечта',
#   'становиться',
#   'исполняться',
#   'удивительный',
#   'история',
#   'происходить',
#   'канун',
#   'год',
#   'марсель',
#   'аблкарам',
#   'приезжать',
#   'встречать',
#   'новый',
#   'год',
#   'брат',
#   'уфа',
#   'жить',
#   'черкесск',
#   'род',
#   'уфа',
#   'жить',
#   'родня',
#   'декабрь',
#   'брат',
#   'собираться',
#   'компания',
#   'друг',
#   'число',
#   'нафис',
#   'поэтому',
#   'рад',
#   'большой',
#   'компания',
#   'цель',
#   'друг',
#   'познакомить',
#   'поделиться',
#   'нафис',
#   'происходить',
#   'совершенно',
#   'случайно',
#   'марсель',
#   'выделять',
#   'среди',
#   'остальной',
#   'серьезный',
#   'особо',
#   'разговорчивый',
#   'внимание',
#   'поначалу',
#   'обращать',
#   'садиться',
#   'стол',
#   'нафис',
#   'марсель',
#   'оказываться',
#   'друг',
#   'напротив',
#   'друг',
#   'ровно',
#   'двенадцать',
#   'договариваться',
#   'писать',
#   'желание',
#   'бумажка',
#   'сжигать',
#   'бросать',
#   'бокал',
#   'пить',
#   'куранты',
#   'впопыхах',
#   'девушка',
#   'успевать',
#   'написать',
#   'слово',
#   'хотеть',
#   'хороший',
#   'муж',
#   'марсель',
#   'хотеть',
#   'жена',
#   'происходить',
#   'волшебство',
#   'молодой',
#   'человек',
#   'разговориться',
#   'веселие',
#   'продолжаться',
#   'елка',
#   'завязываться',
#   'беседа',
#   'новогодний',
#   'каникулы',
#   'нафис',
#   'марсель',
#   'компания',
#   'друг',
#   'ездить',
#   'вместе',
#   'кататься',
#   'тюбинг',
#   'город',
#   'конец',
#   'январь',
#   'марсель',
#   'нужно',
#   'возвращаться',
#   'домой',
#   'черкесск',
#   'обменяться',
#   'телефон',
#   'становиться',
#   'созваниваться',
#   'общаться',
#   'скайп',
#   'месяц',
#   'март',
#   'поехать',
#   'гость',
#   'лето',
#   'вместе',
#   'отдыхать',
#   'геленджик',
#   'вспоминать',
#   'нафис',
#   'расстояние',
#   'звонок',
#   'спустя',
#   'месяц',
#   'день',
#   'знакомство',
#   'следующий',
#   'новый',
#   'год',
#   'переезжать',
#   'уфа',
#   'любимая',
#   'молодой',
#   'сразу',
#   'становиться',
#   'вместе',
#   'жить',
#   'прочитывать',
#   'ник',
#   'лето',
#   'год',
#   'сыграть',
#   'свадьба',
#   'год',
#   'семья',
#   'аблкарамов',
#   'рождаться',
#   'дочка',
#   'аделя',
#   'называть',
#   'девочка',
#   'марсель',
#   'месяц',
#   'нафис',
#   'сыночек',
#   'ильгам',
#   'первый',
#   'брак',
#   'год',
#   'именно',
#   'представлять',
#   'будущее',
#   'муж',
#   'хороший',
#   'ответственный',
#   'надежный',
#   'внешне',
#   'совпадать',
#   'мечта',
#   'поделиться',
#   'нафис',
#   'самый',
#   'хороший',
#   'муж',
#   'свет',
#   'новый',
#   'год',
#   'особенный',
#   'праздник',
#   'день',
#   'знакомство',
#   'компетентно',
#   'психолог',
#   'алиса',
#   'курамшин',
#   'правило',
#   'загадывание',
#   'желание',
#   'стоить',
#   'пользоваться',
#   'желание',
#   'формулировать',
#   'позитивно',
#   'обходиться',
#   'слово',
#   'бросать',
#   'переставать',
#   'нужный',
#   'светлый',
#   'цель',
#   'впереди',
#   'мрачный',
#   'прошлое',
#   'бежать',
#   'бросать',
#   'курить',
#   'начинать',
#   'вести',
#   'зож',
#   'положительный',
#   'вариант',
#   'снижать',
#   'вес',
#   'зож',
#   'оптимизация',
#   'вес',
#   'режим',
#   'питание',
#   'физический',
#   'развитие',
#   'прочее',
#   'желание',
#   'должный',
#   'касаться',
#   'лично',
#   'здоровье',
#   'родные',
#   'близкие',
#   'ребенок',
#   'учиться',
#   'хороший',
#   'желание',
#   'касаться',
#   'человек',
#   'мочь',
#   'написать',
#   'хотеть',
#   'помогать',
#   'родные',
#   'близкие',
#   'здоровый',
#   'хотеть',
#   'радоваться',
#   'успех',
#   'ребенок',
#   'желание',
#   'должный',
#   'зона',
#   'ваш',
#   'возможность',
#   'хотеть',
#   'полететь',
#   'космос',
#   'лишний',
#   'миллион',
#   'доллар',
#   'карман',
#   'одышка',
#   'подъем',
#   'четвертый',
#   'этаж',
#   'исполнение',
#   'желание',
#   'становиться',
#   'проблематичный',
#   'загадывать',
#   'желание',
#   'здоровый',
#   'сердце',
#   'пример',
#   'желание',
#   'должный',
#   'пугать',
#   'некоторые',
#   'загадывать',
#   'верить',
#   'исполнение',
#   'хотеть',
#   'получать',
#   'миллион',
#   'сидеть',
#   'тысяча',
#   'хотеть',
#   'анджелина',
#   'джоли',
#   'лишь',
#   'спик',
#   'ин',
#   'май',
#   'харт',
#   'масштаб',
#   'должный',
#   'радовать',
#   'мельчить',
#   'стоить',
#   'главное',
#   'верить',
#   'сбываться',
#   'делать',
#   'шаг',
#   'навстречу',
#   'желание',
#   'исполнение',
#   'самый',
#   'заветный',
#   'мечтание'],
#  ['ой',
#   'весело',
#   'гуляться',
#   'новый',
#   'год',
#   'шампанское',
#   'пляска',
#   'елка',
#   'салат',
#   'лампочка',
#   'нарядный',
#   'дед',
#   'мороз',
#   'веселый',
#   'вообще',
#   'веселый',
#   'хотеться',
#   'выпивать',
#   'здоровье',
#   'счастие',
#   'новый',
#   'год',
#   'правда',
#   'первый',
#   'день',
#   'самый',
#   'новый',
#   'год',
#   'правило',
#   'получаться',
#   'радостный',
#   'нездоровый',
#   'головной',
#   'боль',
#   'тошнота',
#   'прочий',
#   'радость',
#   'похмелье',
#   'возвращать',
#   'грешный',
#   'земля',
#   'заставлять',
#   'торжественный',
#   'клятва',
#   'капля',
#   'менее',
#   'относиться',
#   'число',
#   'абсолютный',
#   'трезвенник',
#   'время',
#   'время',
#   'приходиться',
#   'сталкиваться',
#   'алкоголь',
#   'следствие',
#   'бороться',
#   'похмелье',
#   'стоить',
#   'запоминать',
#   'несколько',
#   'простой',
#   'шаг',
#   'выживание',
#   'праздник',
#   'шаг',
#   'преодолевать',
#   'тошнота',
#   'шаг',
#   'первый',
#   'совершать',
#   'смочь',
#   'добираться',
#   'остальной',
#   'спасительный',
#   'пункт',
#   'помнить',
#   'рвота',
#   'тошнота',
#   'естественный',
#   'защита',
#   'ваш',
#   'организм',
#   'немыслимый',
#   'доза',
#   'алкоголь',
#   'угощать',
#   'накануне',
#   'алкоголь',
#   'распадаться',
#   'токсин',
#   'организм',
#   'пытаться',
#   'скоро',
#   'убирать',
#   'пусть',
#   'эстетичный',
#   'хотеться',
#   'поэтому',
#   'забывать',
#   'вчера',
#   'ночь',
#   'новогодний',
#   'принцесса',
#   'отправляться',
#   'санузел',
#   'тошниться',
#   'здоровье',
#   'тошнота',
#   'рвота',
#   'отсутствовать',
#   'попить',
#   'водичка',
#   'стакан',
#   'теплый',
#   'вода',
#   'небольшой',
#   'глоточек',
#   'трудно',
#   'человек',
#   'пара',
#   'час',
#   'назад',
#   'пить',
#   'плясать',
#   'утро',
#   'смочь',
#   'промывать',
#   'желудок',
#   'понимать',
#   'насколько',
#   'становиться',
#   'легко',
#   'справляться',
#   'утренний',
#   'тошнота',
#   'помогать',
#   'чай',
#   'свежий',
#   'имбирь',
#   'нарезать',
#   'кусочек',
#   'корень',
#   'имбирь',
#   'заливать',
#   'несколько',
#   'стакан',
#   'вода',
#   'прокипятить',
#   'крышка',
#   'около',
#   'минута',
#   'пить',
#   'мед',
#   'медленный',
#   'глоток',
#   'шаг',
#   'очищаться',
#   'сорбент',
#   'потреблять',
#   'жидкостифото',
#   'похмелье',
#   'иной',
#   'сильный',
#   'отравление',
#   'продукт',
#   'распад',
#   'алкоголь',
#   'первый',
#   'задача',
#   'вывести',
#   'самый',
#   'продукт',
#   'организм',
#   'поэтому',
#   'помощь',
#   'сорбент',
#   'звучный',
#   'словечко',
#   'называться',
#   'вещество',
#   'способный',
#   'оттягивать',
#   'токсин',
#   'затем',
#   'выводить',
#   'организм',
#   'самый',
#   'простой',
#   'активированный',
#   'уголь',
#   'черный',
#   'белый',
#   'современный',
#   'полифепан',
#   'полисорб',
#   'фильтрум',
#   'смект',
#   'принимать',
#   'момент',
#   'почувствовать',
#   'сильно',
#   'навеселе',
#   'ложиться',
#   'спать',
#   'утро',
#   'алкоголь',
#   'всасываться',
#   'кровь',
#   'эффект',
#   'сорбент',
#   'снижаться',
#   'равный',
#   'хороший',
#   'ничто',
#   'активированный',
#   'уголь',
#   'брать',
#   'расчет',
#   'таблетка',
#   'кг',
#   'вес',
#   'разминать',
#   'порошок',
#   'размешивать',
#   'стакан',
#   'вода',
#   'выпивать',
#   'несколько',
#   'час',
#   'повторять',
#   'процедура',
#   'полифепан',
#   'ст',
#   'ложка',
#   'лекарство',
#   'запивать',
#   'мя',
#   'стакан',
#   'вода',
#   'час',
#   'повторять',
#   'процедура',
#   'полисорб',
#   'ст',
#   'ложка',
#   'лекарство',
#   'размешивать',
#   'стакан',
#   'вода',
#   'повторять',
#   'процедура',
#   'каждый',
#   'час',
#   'фильтрум',
#   'принимать',
#   'таблетка',
#   'запивать',
#   'мя',
#   'стакан',
#   'вода',
#   'смект',
#   'пакетик',
#   'размешивать',
#   'стакан',
#   'вода',
#   'повторять',
#   'процедура',
#   'час',
#   'важно',
#   'час',
#   'прием',
#   'любой',
#   'сорбент',
#   'необходимо',
#   'опорожнять',
#   'кишечник',
#   'иначе',
#   'скопиться',
#   'сорбент',
#   'начинать',
#   'отдавать',
#   'собранный',
#   'токсин',
#   'обратно',
#   'организм',
#   'ваш',
#   'состояние',
#   'ухудшаться',
#   'шаг',
#   'устранять',
#   'головной',
#   'боль',
#   'вчера',
#   'вокал',
#   'караоке',
#   'развлекать',
#   'квартал',
#   'сегодня',
#   'скрип',
#   'половица',
#   'раскалывать',
#   'ваш',
#   'бедный',
#   'голова',
#   'часть',
#   'шум',
#   'ухо',
#   'светобоязнь',
#   'головной',
#   'боль',
#   'привет',
#   'обильный',
#   'возлияние',
#   'накануне',
#   'устранять',
#   'симптом',
#   'помогать',
#   'аспирин',
#   'алка',
#   'зельцер',
#   'антипохмелина',
#   'зоракс',
#   'антипохмельный',
#   'средство',
#   'продаваться',
#   'любой',
#   'аптека',
#   'рецепт',
#   'предпочтение',
#   'отдавать',
#   'шипучий',
#   'форма',
#   'поскольку',
#   'быстро',
#   'всасываться',
#   'организм',
#   'новомодный',
#   'выкрутасы',
#   'принимать',
#   'обычный',
#   'цитрамон',
#   'помнить',
#   'причина',
#   'ваш',
#   'сегодняшний',
#   'головной',
#   'боль',
#   'недостаток',
#   'глюкоза',
#   'кровь',
#   'некрепкий',
#   'сладкий',
#   'чай',
#   'пара',
#   'ложечка',
#   'мед',
#   'горсть',
#   'изюм',
#   'сладкий',
#   'фрукт',
#   'смочь',
#   'съедать',
#   'помогать',
#   'справляться',
#   'взрыв',
#   'мозг',
#   'шаг',
#   'бороться',
#   'обезвоживание',
#   'сухость',
#   'рот',
#   'неутолимый',
#   'желание',
#   'выпивать',
#   'море',
#   'признак',
#   'жестокий',
#   'похмелье',
#   'алкоголь',
#   'чрезмерный',
#   'доза',
#   'вызывать',
#   'обезвоживание',
#   'необходимо',
#   'восстанавливать',
#   'баланс',
#   'подходить',
#   'лечебный',
#   'столовая',
#   'минеральный',
#   'вода',
#   'бутылка',
#   'сутки',
#   'мало',
#   'употребление',
#   'выпускать',
#   'газ',
#   'лишний',
#   'раздражитель',
#   'ваш',
#   'травмированный',
#   'шампанское',
#   'висок',
#   'текила',
#   'нужный',
#   'подчеркивать',
#   'желудок',
#   'минералка',
#   'запасаться',
#   'пить',
#   'обычный',
#   'чистый',
#   'вода',
#   'обязательно',
#   'добавлять',
#   'несколько',
#   'капля',
#   'лимонный',
#   'сок',
#   'выдавливать',
#   'апельсин',
#   'чистый',
#   'свежевыжатый',
#   'апельсиновый',
#   'сок',
#   'приветствоваться',
#   'немой',
#   'высокий',
#   'концентрация',
#   'фруктовый',
#   'кислота',
#   'становиться',
#   'дополнительный',
#   'раздражитель',
#   'желудок',
#   'сок',
#   'разбавлять',
#   'вода',
#   'шаг',
#   'употреблять',
#   'натуральный',
#   'ферментировать',
#   'продукт',
#   'зря',
#   'страждущий',
#   'время',
#   'народ',
#   'похмелье',
#   'пить',
#   'рассол',
#   'ферментировать',
#   'продукт',
#   'содержать',
#   'витамин',
#   'молочный',
#   'кислота',
#   'действительно',
#   'помогать',
#   'восстанавливать',
#   'нарушать',
#   'организм',
#   'метаболизм',
#   'хмурый',
#   'похмельный',
#   'утро',
#   'мочь',
#   'помогать',
#   'простой',
#   'действенный',
#   'вещь',
#   'моченый',
#   'яблоко',
#   'квашеный',
#   'капуста',
#   'огурец',
#   'натуральный',
#   'кефир',
#   'низкий',
#   'степень',
#   'жирность',
#   'тан',
#   'айран',
#   'кой',
#   'случай',
#   'употреблять',
#   'никакой',
#   'маринад',
#   'уксус',
#   'усугублять',
#   'ваш',
#   'состояние',
#   'стакан',
#   'огуречный',
#   'капустный',
#   'рассол',
#   'говориться',
#   'выше',
#   'лекарство',
#   'мочь',
#   'доползать',
#   'кухня',
#   'спасать',
#   'пряный',
#   'нежирный',
#   'куриный',
#   'бульон',
#   'острый',
#   'сборная',
#   'солянка',
#   'рассольник',
#   'холодный',
#   'отварной',
#   'мясо',
#   'соленый',
#   'огурчикомфото',
#   'михаил',
#   'шаг',
#   'подбирать',
#   'антипохмельный',
#   'меню',
#   'итак',
#   'спустя',
#   'час',
#   'промывать',
#   'желудок',
#   'снимать',
#   'головной',
#   'боль',
#   'отведывать',
#   'сорбент',
#   'наверняка',
#   'захотеться',
#   'поесть',
#   'оставаться',
#   'ночь',
#   'майонезный',
#   'салат',
#   'отдавать',
#   'враг',
#   'жирный',
#   'тяжелый',
#   'пища',
#   'болезный',
#   'нужный',
#   'самый',
#   'время',
#   'вспомнить',
#   'острый',
#   'горячий',
#   'закуска',
#   'рекомендовать',
#   'случай',
#   'классик',
#   'многий',
#   'городской',
#   'заведение',
#   'именно',
#   'январь',
#   'включать',
#   'репертуар',
#   'целый',
#   'комплекс',
#   'антипохмельный',
#   'блюдо',
#   'сила',
#   'идти',
#   'туда',
#   'мочь',
#   'доползать',
#   'кухня',
#   'спасать',
#   'пряный',
#   'нежирный',
#   'куриный',
#   'бульон',
#   'острый',
#   'сборная',
#   'солянка',
#   'рассольник',
#   'холодный',
#   'отварной',
#   'мясо',
#   'соленый',
#   'огурчик',
#   'знаменитый',
#   'кавказский',
#   'хаш',
#   'смочь',
#   'приготавливать',
#   'натуральный',
#   'ягодный',
#   'желе',
#   'просто',
#   'выдавливать',
#   'сок',
#   'стакан',
#   'клюква',
#   'брусника',
#   'отдельно',
#   'стакан',
#   'вода',
#   'прогревать',
#   'ст',
#   'ложка',
#   'желатин',
#   'затем',
#   'смешать',
#   'вместе',
#   'добавлять',
#   'вкус',
#   'мед',
#   'минута',
#   'убирать',
#   'холодильник',
#   'взмах',
#   'получать',
#   'сразу',
#   'антипохмельный',
#   'лекарство',
#   'большой',
#   'порция',
#   'витамин',
#   'легкий',
#   'питательный',
#   'пища',
#   'обволакивающий',
#   'раздраженный',
#   'желудок',
#   'продукт',
#   'шаг',
#   'отказываться',
#   'похмельный',
#   'рюмка',
#   'наверняка',
#   'глядеть',
#   'ваш',
#   'страдание',
#   'находиться',
#   'добрый',
#   'человек',
#   'предлагать',
#   'лечить',
#   'подобный',
#   'подобный',
#   'попросту',
#   'опохмеляться',
#   'враг',
#   'терапия',
#   'отказываться',
#   'сразу',
#   'ваш',
#   'организм',
#   'пытаться',
#   'справляться',
#   'алкогольный',
#   'интоксикация',
#   'добавлять',
#   'работа',
#   'сердце',
#   'печень',
#   'поджелудочный',
#   'трудиться',
#   'авральный',
#   'режим',
#   'хотеть',
#   'прямо',
#   'праздник',
#   'загреметь',
#   'больничный',
#   'койка',
#   'испытывать',
#   'прочность',
#   'наблюдение',
#   'нарколог',
#   'похмельный',
#   'терапия',
#   'большинство',
#   'случай',
#   'приводить',
#   'запой',
#   'накануне',
#   'пить',
#   'видеть',
#   'край',
#   'никакой',
#   'гарантия',
#   'сегодня',
#   'смочь',
#   'вовремя',
#   'останавливаться',
#   'шаг',
#   'принимать',
#   'контрастный',
#   'душ',
#   'называть',
#   'народный',
#   'метод',
#   'попариться',
#   'похмелье',
#   'баня',
#   'вспоминать',
#   'сердце',
#   'благодаря',
#   'ваш',
#   'загул',
#   'испытывать',
#   'перегрузка',
#   'артериальный',
#   'внутричерепной',
#   'давление',
#   'время',
#   'похмелье',
#   'повышать',
#   'баня',
#   'высокий',
#   'температура',
#   'ухудшать',
#   'ваш',
#   'состояние',
#   'повреждать',
#   'перепел',
#   'контрастный',
#   'душ',
#   'самый',
#   'удобный',
#   'цикл',
#   'секунда',
#   'горячий',
#   'холодный',
#   'вода',
#   'причем',
#   'начинать',
#   'нужно',
#   'горячий',
#   'затем',
#   'переключать',
#   'холодный',
#   'повторять',
#   'образ',
#   'помогать',
#   'организм',
#   'избавляться',
#   'отек',
#   'вызывать',
#   'застой',
#   'жидкость',
#   'взбадривать',
#   'нервный',
#   'система',
#   'смывать',
#   'токсин',
#   'выделяться',
#   'пора',
#   'кожа',
#   'заодно',
#   'понижать',
#   'кровяной',
#   'давление',
#   'вчера',
#   'весело',
#   'шаг',
#   'идти',
#   'дышать',
#   'свежий',
#   'воздух',
#   'почувствовать',
#   'мочь',
#   'стоять',
#   'нога',
#   'сразу',
#   'выбираться',
#   'свежий',
#   'воздух',
#   'прогулка',
#   'эффективно',
#   'выход',
#   'дом',
#   'принимать',
#   'любой',
#   'комплексный',
#   'витамин',
#   'выпивать',
#   'чай',
#   'шиповник',
#   'улица',
#   'попробовать',
#   'активно',
#   'проходиться',
#   'поиграть',
#   'снежок',
#   'расчищать',
#   'дорожка',
#   'снег',
#   'подвигаться',
#   'кислород',
#   'попадать',
#   'организм',
#   'обеспечивать',
#   'активный',
#   'работа',
#   'внутренний',
#   'орган',
#   'продукт',
#   'распад',
#   'алкоголь',
#   'выводиться',
#   'быстро',
#   'физический',
#   'нагрузка',
#   'должный',
#   'умеренный',
#   'активный',
#   'тренировка',
#   'фитнес',
#   'упад',
#   'первый',
#   'день',
#   'похмелье',
#   'противопоказанный',
#   'шаг',
#   'восстанавливать',
#   'нервный',
#   'система',
#   'снимать',
#   'депрессия',
#   'угнетенный',
#   'состояние',
#   'раздражительность',
#   'нервозность',
#   'чувство',
#   'вина',
#   'верный',
#   'спутник',
#   'тяжелый',
#   'похмелье',
#   'возникать',
#   'дефицит',
#   'магний',
#   'вызывать',
#   'алкогольный',
#   'интоксикация',
#   'устранять',
#   'симптом',
#   'помогать',
#   'простой',
#   'успокаивающий',
#   'средство',
#   'глицин',
#   'новый',
#   'пассит',
#   'настой',
#   'зверобой',
#   'пустырник',
#   'стакан',
#   'теплый',
#   'молоко',
#   'прекрасно',
#   'подходить',
#   'натуральный',
#   'домашний',
#   'антидепрессант',
#   'какао',
#   'принимать',
#   'постараться',
#   'ложиться',
#   'спать',
#   'ничто',
#   'помогать',
#   'организм',
#   'справляться',
#   'похмельный',
#   'мука',
#   'совесть',
#   'здоровый',
#   'крепкий',
#   'сон',
#   'читать',
#   'простой',
#   'способ',
#   'переедать',
#   'праздничный',
#   'стол',
#   'день',
#   'новогодний',
#   'каникулы',
#   'значит',
#   'перемещение',
#   'стол',
#   'стол',
#   'лежание',
#   'диван',
#   'способствовать',
#   'стройность',
#   'фигура',
#   'проводить',
#   'талия',
#   'становиться',
#   'мучительно',
#   'тесно',
#   'красивый',
#   'платье',
#   'подробность'],
#  ['шерлок',
#   'холмс',
#   'режиссер',
#   'даглас',
#   'маккиннон',
#   'роль',
#   'бенедикт',
#   'камбербэтч',
#   'мартин',
#   'фримэн',
#   'английский',
#   'шерлок',
#   'сериал',
#   'хороший',
#   'развал',
#   'технически',
#   'безукоризненный',
#   'великолепие',
#   'удерживать',
#   'придумывать',
#   'год',
#   'сколько',
#   'назад',
#   'персонаж',
#   'сэр',
#   'артур',
#   'конан',
#   'дойла',
#   'пусть',
#   'характер',
#   'главный',
#   'действующий',
#   'лицо',
#   'совершенно',
#   'развиваться',
#   'состав',
#   'играющий',
#   'актер',
#   'настолько',
#   'прекрасный',
#   'следить',
#   'изо',
#   'сила',
#   'пытаться',
#   'придавать',
#   'смысл',
#   'сценарий',
#   'каждый',
#   'новый',
#   'серия',
#   'намного',
#   'интересный',
#   'происходить',
#   'экран',
#   'событие',
#   'последний',
#   'разумеется',
#   'являться',
#   'результат',
#   'очередной',
#   'мозговой',
#   'штурм',
#   'сценарист',
#   'например',
#   'видеть',
#   'сидеть',
#   'офис',
#   'профессиональный',
#   'британский',
#   'парень',
#   'пить',
#   'кофе',
#   'нордический',
#   'высчитывать',
#   'лэптоп',
#   'планшет',
#   'удивлять',
#   'миллион',
#   'фанат',
#   'сериал',
#   'новый',
#   'год',
#   'сделать',
#   'невеста',
#   'ватсон',
#   'убийца',
#   'убивать',
#   'холмс',
#   'посылать',
#   'сербия',
#   'перенести',
#   'серия',
#   'действие',
#   'время',
#   'конан',
#   'дойла',
#   'последний',
#   'собственно',
#   'проделывать',
#   'прямо',
#   'сегодня',
#   'драматургия',
#   'сверхуспешный',
#   'сериал',
#   'факт',
#   'многое',
#   'хороший',
#   'драматургия',
#   'голливудский',
#   'блокбастер',
#   'последний',
#   'нагромождение',
#   'бессмыслица',
#   'нивелироваться',
#   'запредельный',
#   'ритм',
#   'наворот',
#   'компьютерный',
#   'график',
#   'иронический',
#   'подмигивание',
#   'высокоинтеллектуальный',
#   'аудитория',
#   'писаться',
#   'столько',
#   'телефильм',
#   'сколько',
#   'точно',
#   'самоидентификация',
#   'противный',
#   'хитрый',
#   'персонаж',
#   'циничный',
#   'обаяние',
#   'понятный',
#   'дело',
#   'ох',
#   'далеко',
#   'первый',
#   'пятница',
#   'суббота',
#   'воскресение',
#   'джентльмен',
#   'предпочитать',
#   'блондинка',
#   'режиссер',
#   'ховард',
#   'хоукс',
#   'роль',
#   'мэрилин',
#   'монро',
#   'джейн',
#   'рассел',
#   'именно',
#   'классический',
#   'картина',
#   'ховард',
#   'хоукс',
#   'впервые',
#   'прозвучать',
#   'песня',
#   'перепевать',
#   'мулен',
#   'руж',
#   'николь',
#   'кидман',
#   'бриллиант',
#   'хороший',
#   'друг',
#   'девушка',
#   'фильм',
#   'становиться',
#   'экранизация',
#   'знаменитый',
#   'бродвейский',
#   'мюзикл',
#   'мэрилин',
#   'монро',
#   'джейн',
#   'рассел',
#   'изображать',
#   'мелкий',
#   'старлетка',
#   'городишко',
#   'литтл',
#   'рок',
#   'намереваться',
#   'покорять',
#   'подмостки',
#   'париж',
#   'оказываться',
#   'теплоход',
#   'плыть',
#   'франция',
#   'покорять',
#   'содержаться',
#   'палуба',
#   'джентльмен',
#   'каковой',
#   'норовить',
#   'подарить',
#   'бриллиант',
#   'весьма',
#   'жизненный',
#   'история',
#   'первый',
#   'пятница',
#   'аватар',
#   'режиссер',
#   'джеймс',
#   'кэмерон',
#   'роль',
#   'сэм',
#   'уортингтон',
#   'мишель',
#   'родригес',
#   'сигурни',
#   'уивер',
#   'слово',
#   'аватар',
#   'становиться',
#   'известно',
#   'качество',
#   'название',
#   'самый',
#   'кассовый',
#   'фильм',
#   'время',
#   'народ',
#   'именоваться',
#   'человеческий',
#   'ипостась',
#   'индуистский',
#   'бог',
#   'вишну',
#   'спускаться',
#   'грешный',
#   'земля',
#   'джеймс',
#   'кэмерон',
#   'аватар',
#   'искусственно',
#   'сгенерировать',
#   'существо',
#   'неразрывный',
#   'связывать',
#   'оригинал',
#   'сто',
#   'год',
#   'предположение',
#   'режиссер',
#   'фантаст',
#   'человек',
#   'научаться',
#   'изготавливать',
#   'существо',
#   'запускать',
#   'далекий',
#   'планета',
#   'вроде',
#   'выдумывать',
#   'пандор',
#   'землянин',
#   'время',
#   'успешно',
#   'расправляться',
#   'собственный',
#   'планета',
#   'обнаруживать',
#   'некий',
#   'ценный',
#   'минерал',
#   'пандор',
#   'населять',
#   'невиданный',
#   'красота',
#   'похожий',
#   'индеец',
#   'длинноногий',
#   'синекожий',
#   'существо',
#   'львиный',
#   'нос',
#   'мускулистый',
#   'хвост',
#   'бывший',
#   'морпех',
#   'джек',
#   'салли',
#   'сэм',
#   'уортингтон',
#   'обезножить',
#   'бой',
#   'отечество',
#   'оказываться',
#   'пандор',
#   'вид',
#   'аватара',
#   'резвый',
#   'сильный',
#   'смышленый',
#   'миссия',
#   'добиваться',
#   'отступление',
#   'лицо',
#   'захватчик',
#   'судьба',
#   'полюбить',
#   'дивный',
#   'мир',
#   'человек',
#   'жить',
#   'полный',
#   'гармония',
#   'природа',
#   'дочка',
#   'вождь',
#   'племя',
#   'центр',
#   'история',
#   'корневой',
#   'американский',
#   'миф',
#   'капитан',
#   'джон',
#   'смит',
#   'покахонтас',
#   'аватар',
#   'задавать',
#   'стандарт',
#   'современный',
#   'трехмерный',
#   'кино',
#   'ничто',
#   'случайный',
#   'нездешний',
#   'красота',
#   'планета',
#   'пандор',
#   'кэмерон',
#   'разворачивать',
#   'галлюциногенный',
#   'великолепие',
#   'разрушать',
#   'грязный',
#   'рука',
#   'землянин',
#   'первый',
#   'суббота']]
