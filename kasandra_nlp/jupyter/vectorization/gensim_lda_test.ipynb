# %%
import json
import numpy as np
from itertools import groupby
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import make_pipeline

from gensim.sklearn_api import LdaTransformer
import scipy
import logging, gensim, bz2
from gensim import corpora
from collections import defaultdict
from scipy.sparse import csr_matrix

# %%
class News:
    def __init__(self, id, date, title, content, url, siteType):
        self.id = id
        self.date = date
        self.title = title
        self.content = content
        self.url = url
        self.siteType = siteType
    
    @classmethod
    def from_json(cls, json_str):
        json_dict = json.loads(json_str)
        return cls(**json_dict)

# %%
news = []
with open('/data/10k.test.normalized.json', encoding="utf8") as f:
    for line in f:
        news.append(News.from_json(line))

# %%
words = []
for n in news:
    words.extend(n.content.split())
counts = Counter(words)
one_time = [k for k, v in dict(counts).items() if v == 1]
print("total words: %s" % (len(words) - len(one_time)))
# Out:
# total words: 2717122

# %%
stopwords = set(one_time)

# %%
content = list(map(lambda x: x.content, news))

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
texts = [[word for word in document.lower().split()] for document in content]

# %%
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [[token for token in text if frequency[token] > 1] for text in texts]

# %%
dictionary = corpora.Dictionary(texts)
# Out:
# 2017-12-03 17:40:41,629 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2017-12-03 17:40:44,520 : INFO : built Dictionary(43455 unique tokens: ['экстремист', 'исламский', 'государство', 'обезглавливать', 'второй']...) from 10000 documents (total 2717157 corpus positions)

# %%
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
lda = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=100, update_every=1, chunksize=10000, passes=1)
# Out:
# 2017-12-03 17:42:02,679 : INFO : using symmetric alpha at 0.01
# 2017-12-03 17:42:02,680 : INFO : using symmetric eta at 2.3012311586698885e-05
# 2017-12-03 17:42:02,688 : INFO : using serial LDA version on this node
# 2017-12-03 17:42:52,465 : INFO : running online (single-pass) LDA training, 100 topics, 1 passes over the supplied corpus of 10000 documents, updating model once every 10000 documents, evaluating perplexity every 10000 documents, iterating 50x with a convergence threshold of 0.001000
# 2017-12-03 17:42:52,466 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2017-12-03 17:46:24,648 : INFO : -16.408 per-word bound, 86956.6 perplexity estimate based on a held-out corpus of 10000 documents with 2717157 words
# 2017-12-03 17:46:24,648 : INFO : PROGRESS: pass 0, at document #10000/10000
# 2017-12-03 17:48:00,611 : INFO : topic #55 (0.010): 0.010*"год" + 0.006*"россия" + 0.005*"становиться" + 0.004*"человек" + 0.004*"мочь" + 0.004*"украина" + 0.004*"сообщать" + 0.004*"страна" + 0.004*"дело" + 0.003*"время"
# 2017-12-03 17:48:00,612 : INFO : topic #73 (0.010): 0.012*"год" + 0.008*"россия" + 0.005*"страна" + 0.005*"мочь" + 0.004*"первый" + 0.003*"время" + 0.003*"становиться" + 0.003*"фото" + 0.003*"цена" + 0.003*"самый"
# 2017-12-03 17:48:00,614 : INFO : topic #99 (0.010): 0.011*"год" + 0.009*"украина" + 0.006*"россия" + 0.005*"заявлять" + 0.005*"глава" + 0.004*"президент" + 0.004*"страна" + 0.004*"российский" + 0.003*"дело" + 0.003*"решение"
# 2017-12-03 17:50:45,200 : INFO : topic #24 (0.010): 0.012*"год" + 0.005*"россия" + 0.004*"мочь" + 0.004*"время" + 0.003*"самый" + 0.003*"цена" + 0.003*"страна" + 0.003*"становиться" + 0.003*"руб" + 0.003*"человек"
# [(66,
#   '0.007*"год" + 0.007*"человек" + 0.006*"россия" + 0.004*"мочь" + 0.004*"страна" + 0.004*"становиться" + 0.003*"время" + 0.003*"говорить" + 0.003*"рассказывать" + 0.002*"мир"'),
#  (62,
#   '0.008*"год" + 0.006*"россия" + 0.005*"человек" + 0.004*"мочь" + 0.003*"время" + 0.003*"становиться" + 0.003*"страна" + 0.003*"российский" + 0.003*"сообщать" + 0.003*"рубль"'),
#  (80,
#   '0.010*"год" + 0.006*"россия" + 0.006*"ребенок" + 0.005*"мочь" + 0.005*"украина" + 0.004*"президент" + 0.004*"страна" + 0.004*"становиться" + 0.003*"самый" + 0.003*"российский"'),
#  (15,
#   '0.012*"год" + 0.008*"россия" + 0.005*"человек" + 0.004*"мочь" + 0.004*"время" + 0.004*"новый" + 0.003*"страна" + 0.003*"первый" + 0.003*"данные" + 0.003*"день"'),
#  (84,
#   '0.011*"год" + 0.010*"россия" + 0.005*"российский" + 0.005*"война" + 0.004*"руб" + 0.004*"украина" + 0.004*"человек" + 0.004*"страна" + 0.004*"мочь" + 0.003*"говорить"'),
#  (47,
#   '0.007*"год" + 0.005*"человек" + 0.004*"российский" + 0.004*"фото" + 0.004*"мочь" + 0.003*"самый" + 0.003*"рассказывать" + 0.003*"становиться" + 0.003*"сообщать" + 0.003*"россия"'),
#  (88,
#   '0.008*"россия" + 0.006*"человек" + 0.005*"год" + 0.004*"мочь" + 0.004*"время" + 0.004*"самолет" + 0.004*"украина" + 0.004*"глава" + 0.003*"день" + 0.003*"говорить"'),
#  (76,
#   '0.009*"россия" + 0.007*"украина" + 0.006*"цена" + 0.006*"год" + 0.004*"страна" + 0.004*"человек" + 0.003*"мочь" + 0.003*"становиться" + 0.003*"время" + 0.003*"президент"'),
#  (42,
#   '0.009*"год" + 0.009*"россия" + 0.006*"украина" + 0.005*"мочь" + 0.004*"время" + 0.004*"российский" + 0.004*"становиться" + 0.003*"президент" + 0.003*"человек" + 0.003*"говорить"'),
#  (24,
#   '0.012*"год" + 0.005*"россия" + 0.004*"мочь" + 0.004*"время" + 0.003*"самый" + 0.003*"цена" + 0.003*"страна" + 0.003*"становиться" + 0.003*"руб" + 0.003*"человек"')]

# %%
def get_doc_topic(corpus, model): 
    doc_topic = list() 
    for doc in corpus: 
        doc_topic.append(model.__getitem__(doc, eps=0)) 
    return csr_matrix(doc_topic)

# %%
res = get_doc_topic(corpus, lda)

# %%
len(res[0])
# Out:
# 100

# %%
lda_r = LdaTransformer(num_topics=100, id2word=dictionary)

# %%
lda_r_res = lda_r.fit_transform(corpus)
# Out:
# 2017-12-03 18:11:07,473 : INFO : using symmetric alpha at 0.01
# 2017-12-03 18:11:07,474 : INFO : using symmetric eta at 2.3012311586698885e-05
# 2017-12-03 18:11:07,480 : INFO : using serial LDA version on this node
# 2017-12-03 18:11:53,160 : INFO : running online (single-pass) LDA training, 100 topics, 1 passes over the supplied corpus of 10000 documents, updating model once every 2000 documents, evaluating perplexity every 10000 documents, iterating 50x with a convergence threshold of 0.001000
# 2017-12-03 18:11:53,161 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2017-12-03 18:11:53,162 : INFO : PROGRESS: pass 0, at document #2000/10000
# 2017-12-03 18:12:09,602 : INFO : merging changes from 2000 documents into a model of 10000 documents
# 2017-12-03 18:12:15,085 : INFO : topic #43 (0.010): 0.009*"россия" + 0.008*"год" + 0.005*"человек" + 0.004*"президент" + 0.004*"украина" + 0.004*"украинский" + 0.004*"рубль" + 0.004*"время" + 0.003*"военный" + 0.003*"российский"
# 2017-12-03 18:12:15,086 : INFO : topic #33 (0.010): 0.016*"год" + 0.008*"россия" + 0.006*"мочь" + 0.005*"становиться" + 0.004*"человек" + 0.003*"российский" + 0.003*"рынок" + 0.003*"цена" + 0.003*"страна" + 0.003*"время"
# 2017-12-03 18:12:15,087 : INFO : topic #0 (0.010): 0.009*"год" + 0.008*"украина" + 0.005*"россия" + 0.005*"украинский" + 0.004*"заявлять" + 0.004*"сообщать" + 0.004*"мочь" + 0.004*"путин" + 0.004*"время" + 0.003*"глава"
# 2017-12-03 18:12:15,088 : INFO : topic #90 (0.010): 0.009*"год" + 0.007*"украина" + 0.005*"человек" + 0.005*"становиться" + 0.005*"ребенок" + 0.004*"украинский" + 0.004*"российский" + 0.004*"время" + 0.004*"мочь" + 0.003*"россия"
# 2017-12-03 18:12:15,089 : INFO : topic #31 (0.010): 0.014*"россия" + 0.010*"год" + 0.006*"человек" + 0.005*"время" + 0.004*"мочь" + 0.004*"сообщать" + 0.004*"страна" + 0.004*"место" + 0.003*"февраль" + 0.003*"москва"
# 2017-12-03 18:12:15,102 : INFO : topic diff=66.173832, rho=1.000000
# 2017-12-03 18:12:15,103 : INFO : PROGRESS: pass 0, at document #4000/10000
# 2017-12-03 18:12:29,497 : INFO : merging changes from 2000 documents into a model of 10000 documents
# 2017-12-03 18:12:32,952 : INFO : topic #58 (0.010): 0.015*"украина" + 0.008*"дело" + 0.007*"россия" + 0.007*"российский" + 0.007*"глава" + 0.006*"сообщать" + 0.005*"март" + 0.005*"убийство" + 0.005*"год" + 0.005*"сми"
# 2017-12-03 18:12:32,954 : INFO : topic #98 (0.010): 0.012*"газ" + 0.011*"иран" + 0.007*"сатирик" + 0.007*"газпром" + 0.006*"россия" + 0.006*"тегеран" + 0.006*"год" + 0.006*"ядерный" + 0.005*"российский" + 0.005*"мочь"
# 2017-12-03 18:13:03,922 : INFO : topic #87 (0.010): 0.017*"ребенок" + 0.012*"малыш" + 0.011*"продукт" + 0.009*"молоко" + 0.008*"вкусный" + 0.007*"содержать" + 0.007*"фрутоняня" + 0.006*"детский" + 0.006*"напиток" + 0.006*"сахар"
# 2017-12-03 18:13:03,923 : INFO : topic #3 (0.010): 0.013*"год" + 0.008*"мисс" + 0.008*"летний" + 0.008*"модель" + 0.006*"пилотировать" + 0.006*"звезда" + 0.006*"становиться" + 0.005*"время" + 0.005*"фильм" + 0.005*"девушка"
# 2017-12-03 18:13:03,924 : INFO : topic #81 (0.010): 0.036*"победа" + 0.019*"москва" + 0.015*"парад" + 0.015*"россия" + 0.013*"май" + 0.013*"российский" + 0.011*"летие" + 0.010*"президент" + 0.009*"участие" + 0.008*"торжество"
# 2017-12-03 18:13:03,926 : INFO : topic #34 (0.010): 0.014*"война" + 0.013*"год" + 0.008*"человек" + 0.005*"мочь" + 0.005*"время" + 0.004*"страна" + 0.004*"россия" + 0.004*"становиться" + 0.004*"говорить" + 0.004*"немец"
# 2017-12-03 18:13:03,943 : INFO : topic diff=5.537569, rho=0.500000
# 2017-12-03 18:13:28,090 : INFO : -10.468 per-word bound, 1416.7 perplexity estimate based on a held-out corpus of 2000 documents with 489183 words
# 2017-12-03 18:13:28,090 : INFO : PROGRESS: pass 0, at document #10000/10000
# 2017-12-03 18:13:38,238 : INFO : merging changes from 2000 documents into a model of 10000 documents
# 2017-12-03 18:13:40,452 : INFO : topic #14 (0.010): 0.035*"памятник" + 0.031*"конкурс" + 0.017*"плисецкая" + 0.012*"жюри" + 0.011*"театр" + 0.011*"опера" + 0.011*"красота" + 0.011*"оперный" + 0.010*"пермь" + 0.009*"год"
# 2017-12-03 18:13:40,454 : INFO : topic #11 (0.010): 0.013*"невеста" + 0.008*"пират" + 0.007*"христос" + 0.006*"год" + 0.005*"никитчук" + 0.005*"затапливать" + 0.005*"космический" + 0.005*"ким" + 0.005*"зрелищный" + 0.005*"человек"
# 2017-12-03 18:13:40,455 : INFO : topic #6 (0.010): 0.082*"фриске" + 0.072*"фифа" + 0.039*"блаттер" + 0.022*"футбол" + 0.017*"шепелев" + 0.015*"чемпионат" + 0.013*"мозг" + 0.012*"болезнь" + 0.011*"чм" + 0.010*"мир"
# 2017-12-03 18:13:40,456 : INFO : topic #70 (0.010): 0.011*"плутон" + 0.009*"год" + 0.008*"мочь" + 0.006*"человек" + 0.005*"компания" + 0.005*"интернет" + 0.005*"получать" + 0.004*"ребенок" + 0.004*"работа" + 0.004*"станция"
# 2017-12-03 18:13:40,456 : INFO : topic #67 (0.010): 0.033*"малышев" + 0.024*"меламед" + 0.008*"аудиторский" + 0.008*"удалец" + 0.006*"алемары" + 0.006*"выборный" + 0.006*"диагностировать" + 0.005*"понур" + 0.005*"угон" + 0.005*"некоммерческий"
# 2017-12-03 18:13:40,469 : INFO : topic diff=4.573204, rho=0.447214

# %%
sparse_res = csr_matrix(lda_r_res)
